# %%
import gymnasium as gym
import numpy as np
from stable_baselines3.common.env_util import make_vec_env as make_vec_env_sb3
from copy import deepcopy
import torch
from torch.distributions import Normal,MultivariateNormal
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.utils.data import Dataset, DataLoader
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
import imageio
import pandas as pd
from tqdm import tqdm
from PIL import Image
from stable_baselines3.dqn.policies import MlpPolicy
import matplotlib.pyplot as plt
import os

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !nvidia-smi
# clean up memory forcefully
torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# Mon May 13 00:40:47 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  | 00000000:01:00.0 Off |                  N/A |
# | 17%   56C    P2              90W / 250W |   3086MiB / 11264MiB |     98%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    228304      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    229850      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    277377      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    280712      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    319688      C   ...iu/miniconda3/envs/myenv/bin/python      300MiB |
# |    0   N/A  N/A    328416      C   ...iu/miniconda3/envs/myenv/bin/python      204MiB |
# |    0   N/A  N/A    377684      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   1475780      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   2544023      C   ...u/miniconda3/envs/myenv2/bin/python      184MiB |
# |    0   N/A  N/A   2546464      C   ...u/miniconda3/envs/myenv2/bin/python      192MiB |
# |    0   N/A  N/A   2573624      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2573704      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2584185      C   ...181/miniconda3/envs/copy/bin/python      194MiB |
# |    0   N/A  N/A   2587146      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2587643      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# +---------------------------------------------------------------------------------------+
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
class CustomDataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32,device=device)
        self.actions = torch.tensor(actions, dtype=torch.float32,device=device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, output_dim,init_w=3e-3,log_std_min=-20,log_std_max=2):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 32)


        self.fc2 = nn.Linear(32, 32)
        self.log_std = nn.Linear(32, output_dim)
        self.mu=nn.Linear(32,output_dim)
        self.log_std_min=log_std_min
        self.log_std_max=log_std_max
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        torch.nn.init.kaiming_normal_(self.fc2.weight)
        self.mu.weight.data.uniform_(-init_w,init_w)
        self.mu.bias.data.uniform_(-init_w,init_w)
        self.log_std.weight.data.uniform_(-init_w,init_w)
        self.log_std.bias.data.uniform_(-init_w,init_w)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = self.mu(x) # Only apply if action bounds are [-1, 1]
        log_std = self.log_std(x)  # Ensure std is positive
        log_std=torch.clamp(log_std,self.log_std_min,self.log_std_max)

        return mu, log_std
# Out:
# Using device: cuda

# %%
# from imitation.util.util import make_vec_env

# observations= np.load("../dataset/obs.npy", allow_pickle=True)
# actions = np.load("../dataset/actions.npy", allow_pickle=True)

# observations=observations.squeeze()
# actions=actions.squeeze()

# print(observations.shape, actions.shape)
# print(observations[0], actions[0])
import pickle
import numpy as np
#　read /mnt/nfs/work/c98181/TDIL/saved_expert_transition/Walker2d-v3/sac/episode_num1_6123.pkl
# "states", "actions", "rewards", "next_states", "dones".
with open("/mnt/nfs/work/c98181/TDIL/saved_expert_transition/Ant-v3/sac/episode_num1_8524.pkl", "rb") as f:
    data = pickle.load(f)

    obs_list = data["states"]
    actions_list = data["actions"]
    observations=np.array(obs_list)
    actions=np.array(actions_list)
    # shape
    print(observations.shape)
    print(actions.shape)

# env=gym.make("Walker2d-v3",exclude_current_positions_from_observation=False,render_mode="rgb_array")
env=gym.make("Ant-v3",render_mode="rgb_array")
# Out:
# (1000, 111)
# (1000, 8)
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Ant-v3 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_env.py:211: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(

# %%
class mydataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32).to(device)
        self.actions = torch.tensor(actions, dtype=torch.float32).to(device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

# %%
policy_network = PolicyNetwork(111,8).to(device)
prev = PolicyNetwork(111,8).to(device)
prev.load_state_dict(policy_network.state_dict())
prev.eval()

optimizer = torch.optim.Adam(policy_network.parameters(), lr=0.0003,weight_decay=1e-4)

# Training loop
num_epochs = 100
batch_size = 32

dataset = mydataset(observations=observations, actions=actions)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

loss_graph=[]
greedy_rewards=[]
sample_rewards=[]
margin_graph=[]
positive_reward_graph=[]
negative_reward_graph=[]
log_interval = len(observations)//1
num_test = 10
now_log=0
now_pos=0
greedy_score=0
sample_score=0
for epoch in range(num_epochs):
    policy_network.train()

    # Compute the log probabilities of the actions
    pbar=tqdm(dataloader,position=0,leave=True)
    now_log=0

    for step, (obs_batch,act_batch) in enumerate(pbar):
        # obs_batch = torch.tensor(np.array(obs_batch), dtype=torch.float32).to(device)
        # act_batch = torch.tensor(np.array(act_batch), dtype=torch.float32).to(device)

        now_log+=obs_batch.shape[0]
        now_pos+=obs_batch.shape[0]
        
        mu, log_std = policy_network(obs_batch)
        std=log_std.exp()
        dist = Normal(mu, std)
        z_model=dist.rsample()
        model_action=torch.tanh(z_model)
        z_expert=torch.atanh(torch.clamp(act_batch, -0.999999, 0.999999))
        epsilon=1e-6


        policy_rejected_logps =dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
        policy_chosen_logps = dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        with torch.no_grad():
          prev_mu, prev_log_std = prev(obs_batch)
          prev_std=prev_log_std.exp()
          prev_dist = Normal(prev_mu, prev_std)

          reference_rejected_logps =prev_dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
          reference_chosen_logps = prev_dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        pi_logratios = policy_chosen_logps - policy_rejected_logps
        ref_logratios = reference_chosen_logps - reference_rejected_logps

        chosen_KL = (policy_chosen_logps - reference_chosen_logps).mean().clamp(min=0)
        reject_KL = (policy_rejected_logps - reference_rejected_logps).mean().clamp(min=0)

       

        chosen_logratios = policy_chosen_logps - reference_chosen_logps
        reject_logratios = policy_rejected_logps - reference_rejected_logps

        # logits = chosen_logratios - reject_logratios

        if epoch < -1:
          loss = - (policy_chosen_logps).mean()
        else:
          beta = 1
          losses=torch.pow(chosen_logratios-0.5,2)+torch.pow(reject_logratios+0.5,2)
          loss = losses.mean()
        #   losses = torch.cat((1 - F.logsigmoid(beta * (chosen_logratios - reject_KL)), 1 - F.logsigmoid(beta * (chosen_KL - reject_logratios))), 0)
        #   loss = losses.mean()
        # Optimize the policy
        optimizer.zero_grad()



        loss.backward()

        optimizer.step()
        pbar.set_description((f"Epoch [{epoch+1}/{num_epochs}]"))
        positive_reward = chosen_logratios.detach().mean().item()
        negative_reward = reject_logratios.detach().mean().item()
        margin = positive_reward - negative_reward
        loss_graph.append(loss.detach().item())
        margin_graph.append(margin)
        positive_reward_graph.append(positive_reward)
        negative_reward_graph.append(negative_reward)



        total_reward=0
        if now_log>=log_interval:
            now_log-=log_interval
            
            policy_network.eval()  # 切换到评估模式

            

            total_reward=0
            # test the policy and save as the first test as gif
            # frames = []
            for _ in range(num_test):
                state,_ = env.reset()
                done = False

                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(mu)   
                        action.squeeze_()

                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/greedy/"+image_path, frames)

            greedy_score=total_reward/num_test
            total_reward=0
            frames = []
            # test the policy and save as the first test as gif
            for _ in range(num_test):
                state,_ = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(Normal(mu,std).sample())
                        action.squeeze_()
                       
                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/sample/"+image_path, frames)

            sample_score=total_reward/num_test
            greedy_rewards.append(greedy_score)
            sample_rewards.append(sample_score)
            policy_network.train()  # 切换回训练模式
        pbar.set_postfix({"loss":loss.detach().item(), "positive_reward": positive_reward, "negative_reward": negative_reward, "margin": positive_reward - negative_reward,"greedy_score":greedy_score,"sample_score":sample_score})
    # prev.load_state_dict(policy_network.state_dict())
    # prev.eval()
         

env.close()
# Out:
# Epoch [1/100]:  75%|███████▌  | 24/32 [00:00<00:00, 53.25it/s, loss=0.464, positive_reward=0.124, negative_reward=0.038, margin=0.0862, greedy_score=0, sample_score=0]     /tmp/ipykernel_2588031/2032227647.py:117: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025847094/work/torch/csrc/utils/tensor_new.cpp:275.)
#   state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
# Epoch [1/100]: 100%|██████████| 32/32 [00:35<00:00,  1.12s/it, loss=0.43, positive_reward=0.137, negative_reward=0.00734, margin=0.13, greedy_score=997, sample_score=-436]
# Epoch [2/100]: 100%|██████████| 32/32 [00:35<00:00,  1.12s/it, loss=0.446, positive_reward=0.162, negative_reward=0.0453, margin=0.117, greedy_score=995, sample_score=-450]
# Epoch [3/100]: 100%|██████████| 32/32 [00:37<00:00,  1.16s/it, loss=0.462, positive_reward=0.163, negative_reward=0.0522, margin=0.111, greedy_score=994, sample_score=-410]
# Epoch [4/100]: 100%|██████████| 32/32 [00:35<00:00,  1.11s/it, loss=0.446, positive_reward=0.145, negative_reward=0.0244, margin=0.12, greedy_score=995, sample_score=-432]
# Epoch [5/100]: 100%|██████████| 32/32 [00:36<00:00,  1.13s/it, loss=0.45, positive_reward=0.159, negative_reward=0.0242, margin=0.135, greedy_score=995, sample_score=-430]
# Epoch [6/100]: 100%|██████████| 32/32 [00:32<00:00,  1.02s/it, loss=0.436, positive_reward=0.134, negative_reward=-.017, margin=0.151, greedy_score=992, sample_score=-438]
# Epoch [7/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.441, positive_reward=0.178, negative_reward=0.0416, margin=0.137, greedy_score=995, sample_score=-456]
# Epoch [8/100]: 100%|██████████| 32/32 [00:29<00:00,  1.10it/s, loss=0.413, positive_reward=0.161, negative_reward=0.0115, margin=0.15, greedy_score=995, sample_score=-467]
# Epoch [9/100]: 100%|██████████| 32/32 [00:30<00:00,  1.03it/s, loss=0.437, positive_reward=0.146, negative_reward=-.00581, margin=0.152, greedy_score=994, sample_score=-437]
# Epoch [10/100]: 100%|██████████| 32/32 [00:32<00:00,  1.03s/it, loss=0.453, positive_reward=0.182, negative_reward=0.0439, margin=0.138, greedy_score=991, sample_score=-429]
# Epoch [11/100]: 100%|██████████| 32/32 [00:33<00:00,  1.03s/it, loss=0.428, positive_reward=0.186, negative_reward=0.0261, margin=0.16, greedy_score=999, sample_score=-450]
# Epoch [12/100]: 100%|██████████| 32/32 [00:32<00:00,  1.02s/it, loss=0.458, positive_reward=0.165, negative_reward=0.00851, margin=0.157, greedy_score=995, sample_score=-473]
# Epoch [13/100]: 100%|██████████| 32/32 [00:34<00:00,  1.08s/it, loss=0.413, positive_reward=0.191, negative_reward=0.021, margin=0.169, greedy_score=995, sample_score=-447]
# Epoch [14/100]: 100%|██████████| 32/32 [00:33<00:00,  1.04s/it, loss=0.444, positive_reward=0.175, negative_reward=0.0439, margin=0.131, greedy_score=996, sample_score=-435]
# Epoch [15/100]: 100%|██████████| 32/32 [00:33<00:00,  1.04s/it, loss=0.431, positive_reward=0.157, negative_reward=0.0222, margin=0.135, greedy_score=997, sample_score=-469]
# Epoch [16/100]: 100%|██████████| 32/32 [00:33<00:00,  1.03s/it, loss=0.456, positive_reward=0.159, negative_reward=0.0454, margin=0.114, greedy_score=998, sample_score=-442]
# Epoch [17/100]: 100%|██████████| 32/32 [00:33<00:00,  1.04s/it, loss=0.44, positive_reward=0.162, negative_reward=0.039, margin=0.123, greedy_score=995, sample_score=-435]
# Epoch [18/100]: 100%|██████████| 32/32 [00:31<00:00,  1.03it/s, loss=0.457, positive_reward=0.157, negative_reward=0.0559, margin=0.101, greedy_score=996, sample_score=-445]
# Epoch [19/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.422, positive_reward=0.175, negative_reward=0.00775, margin=0.167, greedy_score=993, sample_score=-441]
# Epoch [20/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.432, positive_reward=0.165, negative_reward=0.0162, margin=0.149, greedy_score=995, sample_score=-442]
# Epoch [21/100]: 100%|██████████| 32/32 [00:31<00:00,  1.00it/s, loss=0.472, positive_reward=0.159, negative_reward=0.000777, margin=0.158, greedy_score=997, sample_score=-457]
# Epoch [22/100]: 100%|██████████| 32/32 [00:38<00:00,  1.20s/it, loss=0.419, positive_reward=0.156, negative_reward=-.0324, margin=0.188, greedy_score=998, sample_score=-454]
# Epoch [23/100]: 100%|██████████| 32/32 [00:35<00:00,  1.11s/it, loss=0.444, positive_reward=0.152, negative_reward=-.000764, margin=0.152, greedy_score=998, sample_score=-442]
# Epoch [24/100]: 100%|██████████| 32/32 [00:33<00:00,  1.05s/it, loss=0.447, positive_reward=0.179, negative_reward=-.0246, margin=0.204, greedy_score=997, sample_score=-426]
# Epoch [25/100]: 100%|██████████| 32/32 [00:33<00:00,  1.05s/it, loss=0.426, positive_reward=0.167, negative_reward=0.00756, margin=0.16, greedy_score=997, sample_score=-463]
# Epoch [26/100]: 100%|██████████| 32/32 [00:33<00:00,  1.04s/it, loss=0.433, positive_reward=0.172, negative_reward=-.000821, margin=0.173, greedy_score=996, sample_score=-444]
# Epoch [27/100]: 100%|██████████| 32/32 [00:33<00:00,  1.04s/it, loss=0.436, positive_reward=0.184, negative_reward=-.0334, margin=0.217, greedy_score=997, sample_score=-452]
# Epoch [28/100]: 100%|██████████| 32/32 [00:30<00:00,  1.03it/s, loss=0.394, positive_reward=0.193, negative_reward=-.00894, margin=0.202, greedy_score=1e+3, sample_score=-460]
# Epoch [29/100]: 100%|██████████| 32/32 [00:28<00:00,  1.14it/s, loss=0.39, positive_reward=0.194, negative_reward=0.00474, margin=0.19, greedy_score=999, sample_score=-458]
# Epoch [30/100]: 100%|██████████| 32/32 [00:29<00:00,  1.10it/s, loss=0.455, positive_reward=0.176, negative_reward=0.067, margin=0.109, greedy_score=1e+3, sample_score=-473]
# Epoch [31/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.459, positive_reward=0.186, negative_reward=0.0751, margin=0.111, greedy_score=1e+3, sample_score=-461]
# Epoch [32/100]: 100%|██████████| 32/32 [00:25<00:00,  1.28it/s, loss=0.427, positive_reward=0.173, negative_reward=0.00439, margin=0.168, greedy_score=1e+3, sample_score=-442]
# Epoch [33/100]: 100%|██████████| 32/32 [00:26<00:00,  1.19it/s, loss=0.456, positive_reward=0.18, negative_reward=0.0678, margin=0.112, greedy_score=1e+3, sample_score=-422]
# Epoch [34/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.442, positive_reward=0.169, negative_reward=0.0031, margin=0.166, greedy_score=1e+3, sample_score=-438]
# Epoch [35/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.465, positive_reward=0.177, negative_reward=0.057, margin=0.12, greedy_score=1e+3, sample_score=-477]
# Epoch [36/100]: 100%|██████████| 32/32 [00:25<00:00,  1.28it/s, loss=0.413, positive_reward=0.188, negative_reward=0.0291, margin=0.159, greedy_score=1e+3, sample_score=-448]
# Epoch [37/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.429, positive_reward=0.168, negative_reward=0.0322, margin=0.136, greedy_score=1e+3, sample_score=-460]
# Epoch [38/100]: 100%|██████████| 32/32 [00:32<00:00,  1.02s/it, loss=0.465, positive_reward=0.158, negative_reward=0.021, margin=0.137, greedy_score=1e+3, sample_score=-461]
# Epoch [39/100]: 100%|██████████| 32/32 [00:31<00:00,  1.03it/s, loss=0.412, positive_reward=0.172, negative_reward=0.00985, margin=0.162, greedy_score=1e+3, sample_score=-449]
# Epoch [40/100]: 100%|██████████| 32/32 [00:30<00:00,  1.03it/s, loss=0.428, positive_reward=0.183, negative_reward=0.044, margin=0.139, greedy_score=997, sample_score=-473]
# Epoch [41/100]: 100%|██████████| 32/32 [00:32<00:00,  1.01s/it, loss=0.448, positive_reward=0.186, negative_reward=0.0576, margin=0.129, greedy_score=998, sample_score=-462]
# Epoch [42/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.435, positive_reward=0.194, negative_reward=0.0459, margin=0.148, greedy_score=997, sample_score=-448]
# Epoch [43/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.453, positive_reward=0.172, negative_reward=0.0498, margin=0.122, greedy_score=1e+3, sample_score=-438]
# Epoch [44/100]: 100%|██████████| 32/32 [00:31<00:00,  1.01it/s, loss=0.465, positive_reward=0.19, negative_reward=0.0157, margin=0.175, greedy_score=1e+3, sample_score=-440]
# Epoch [45/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.445, positive_reward=0.158, negative_reward=0.042, margin=0.116, greedy_score=1e+3, sample_score=-455]
# Epoch [46/100]: 100%|██████████| 32/32 [00:28<00:00,  1.13it/s, loss=0.449, positive_reward=0.189, negative_reward=0.0379, margin=0.151, greedy_score=1e+3, sample_score=-448]
# Epoch [47/100]: 100%|██████████| 32/32 [00:32<00:00,  1.01s/it, loss=0.44, positive_reward=0.173, negative_reward=0.0481, margin=0.125, greedy_score=1e+3, sample_score=-470]
# Epoch [48/100]: 100%|██████████| 32/32 [00:35<00:00,  1.10s/it, loss=0.443, positive_reward=0.175, negative_reward=0.0521, margin=0.123, greedy_score=1.01e+3, sample_score=-467]
# Epoch [49/100]: 100%|██████████| 32/32 [00:39<00:00,  1.23s/it, loss=0.472, positive_reward=0.175, negative_reward=0.0784, margin=0.0964, greedy_score=1e+3, sample_score=-467]
# Epoch [50/100]: 100%|██████████| 32/32 [00:39<00:00,  1.24s/it, loss=0.396, positive_reward=0.19, negative_reward=0.0192, margin=0.17, greedy_score=1e+3, sample_score=-474]
# Epoch [51/100]: 100%|██████████| 32/32 [00:37<00:00,  1.18s/it, loss=0.444, positive_reward=0.191, negative_reward=0.0421, margin=0.148, greedy_score=1e+3, sample_score=-486]
# Epoch [52/100]: 100%|██████████| 32/32 [00:40<00:00,  1.26s/it, loss=0.408, positive_reward=0.188, negative_reward=0.0259, margin=0.162, greedy_score=1e+3, sample_score=-493]
# Epoch [53/100]: 100%|██████████| 32/32 [00:37<00:00,  1.18s/it, loss=0.438, positive_reward=0.181, negative_reward=0.0439, margin=0.137, greedy_score=1e+3, sample_score=-479]
# Epoch [54/100]: 100%|██████████| 32/32 [00:37<00:00,  1.18s/it, loss=0.468, positive_reward=0.177, negative_reward=0.0573, margin=0.119, greedy_score=1e+3, sample_score=-500]
# Epoch [55/100]: 100%|██████████| 32/32 [00:39<00:00,  1.25s/it, loss=0.434, positive_reward=0.188, negative_reward=0.0564, margin=0.132, greedy_score=1e+3, sample_score=-451]
# Epoch [56/100]: 100%|██████████| 32/32 [00:40<00:00,  1.25s/it, loss=0.418, positive_reward=0.18, negative_reward=0.0117, margin=0.168, greedy_score=1e+3, sample_score=-486]
# Epoch [57/100]: 100%|██████████| 32/32 [00:39<00:00,  1.23s/it, loss=0.412, positive_reward=0.178, negative_reward=0.00901, margin=0.169, greedy_score=1e+3, sample_score=-481]
# Epoch [58/100]: 100%|██████████| 32/32 [00:41<00:00,  1.30s/it, loss=0.433, positive_reward=0.186, negative_reward=0.0537, margin=0.132, greedy_score=1e+3, sample_score=-479]
# Epoch [59/100]: 100%|██████████| 32/32 [00:38<00:00,  1.22s/it, loss=0.436, positive_reward=0.209, negative_reward=0.0627, margin=0.146, greedy_score=1e+3, sample_score=-452]
# Epoch [60/100]: 100%|██████████| 32/32 [00:38<00:00,  1.20s/it, loss=0.443, positive_reward=0.168, negative_reward=0.0185, margin=0.15, greedy_score=1e+3, sample_score=-456]
# Epoch [61/100]: 100%|██████████| 32/32 [00:40<00:00,  1.26s/it, loss=0.422, positive_reward=0.177, negative_reward=0.0326, margin=0.144, greedy_score=1e+3, sample_score=-476]
# Epoch [62/100]: 100%|██████████| 32/32 [00:41<00:00,  1.28s/it, loss=0.417, positive_reward=0.17, negative_reward=0.019, margin=0.151, greedy_score=1e+3, sample_score=-455]
# Epoch [63/100]: 100%|██████████| 32/32 [00:37<00:00,  1.17s/it, loss=0.445, positive_reward=0.198, negative_reward=0.0446, margin=0.153, greedy_score=1e+3, sample_score=-461]
# Epoch [64/100]: 100%|██████████| 32/32 [00:39<00:00,  1.25s/it, loss=0.425, positive_reward=0.184, negative_reward=0.0367, margin=0.147, greedy_score=1e+3, sample_score=-465]
# Epoch [65/100]: 100%|██████████| 32/32 [00:39<00:00,  1.22s/it, loss=0.41, positive_reward=0.223, negative_reward=0.0285, margin=0.194, greedy_score=1e+3, sample_score=-442]
# Epoch [66/100]: 100%|██████████| 32/32 [00:38<00:00,  1.20s/it, loss=0.477, positive_reward=0.175, negative_reward=0.0224, margin=0.153, greedy_score=1.01e+3, sample_score=-472]
# Epoch [67/100]: 100%|██████████| 32/32 [00:41<00:00,  1.29s/it, loss=0.432, positive_reward=0.161, negative_reward=0.0203, margin=0.141, greedy_score=1e+3, sample_score=-461]
# Epoch [68/100]: 100%|██████████| 32/32 [00:39<00:00,  1.25s/it, loss=0.411, positive_reward=0.202, negative_reward=0.0272, margin=0.175, greedy_score=1e+3, sample_score=-459]
# Epoch [69/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.427, positive_reward=0.154, negative_reward=-.00262, margin=0.157, greedy_score=1e+3, sample_score=-478]
# Epoch [70/100]: 100%|██████████| 32/32 [00:39<00:00,  1.24s/it, loss=0.437, positive_reward=0.19, negative_reward=0.0219, margin=0.168, greedy_score=1.01e+3, sample_score=-461]
# Epoch [71/100]: 100%|██████████| 32/32 [00:39<00:00,  1.23s/it, loss=0.446, positive_reward=0.184, negative_reward=0.0588, margin=0.125, greedy_score=1e+3, sample_score=-456]
# Epoch [72/100]: 100%|██████████| 32/32 [00:36<00:00,  1.15s/it, loss=0.459, positive_reward=0.165, negative_reward=0.0232, margin=0.142, greedy_score=1e+3, sample_score=-450]
# Epoch [73/100]: 100%|██████████| 32/32 [00:38<00:00,  1.22s/it, loss=0.408, positive_reward=0.199, negative_reward=0.0314, margin=0.167, greedy_score=999, sample_score=-457]
# Epoch [74/100]: 100%|██████████| 32/32 [00:40<00:00,  1.26s/it, loss=0.436, positive_reward=0.173, negative_reward=0.0353, margin=0.137, greedy_score=1e+3, sample_score=-456]
# Epoch [75/100]: 100%|██████████| 32/32 [00:37<00:00,  1.18s/it, loss=0.417, positive_reward=0.178, negative_reward=0.0109, margin=0.167, greedy_score=1e+3, sample_score=-469]
# Epoch [76/100]: 100%|██████████| 32/32 [00:39<00:00,  1.24s/it, loss=0.453, positive_reward=0.165, negative_reward=0.0497, margin=0.115, greedy_score=1e+3, sample_score=-456]
# Epoch [77/100]: 100%|██████████| 32/32 [00:39<00:00,  1.23s/it, loss=0.401, positive_reward=0.192, negative_reward=-.0114, margin=0.204, greedy_score=1e+3, sample_score=-446]
# Epoch [78/100]: 100%|██████████| 32/32 [00:40<00:00,  1.26s/it, loss=0.427, positive_reward=0.192, negative_reward=0.0383, margin=0.153, greedy_score=1e+3, sample_score=-422]
# Epoch [79/100]: 100%|██████████| 32/32 [00:37<00:00,  1.18s/it, loss=0.436, positive_reward=0.175, negative_reward=0.0319, margin=0.143, greedy_score=1e+3, sample_score=-463]
# Epoch [80/100]: 100%|██████████| 32/32 [00:40<00:00,  1.26s/it, loss=0.44, positive_reward=0.194, negative_reward=0.0443, margin=0.149, greedy_score=1e+3, sample_score=-467]
# Epoch [81/100]: 100%|██████████| 32/32 [00:39<00:00,  1.24s/it, loss=0.468, positive_reward=0.207, negative_reward=0.0627, margin=0.144, greedy_score=1e+3, sample_score=-480]
# Epoch [82/100]: 100%|██████████| 32/32 [00:39<00:00,  1.22s/it, loss=0.429, positive_reward=0.177, negative_reward=0.0437, margin=0.133, greedy_score=1.01e+3, sample_score=-445]
# Epoch [83/100]: 100%|██████████| 32/32 [00:39<00:00,  1.22s/it, loss=0.44, positive_reward=0.189, negative_reward=0.0589, margin=0.13, greedy_score=1e+3, sample_score=-457]
# Epoch [84/100]: 100%|██████████| 32/32 [00:39<00:00,  1.22s/it, loss=0.417, positive_reward=0.196, negative_reward=0.0263, margin=0.17, greedy_score=1e+3, sample_score=-469]
# Epoch [85/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.443, positive_reward=0.185, negative_reward=0.0512, margin=0.134, greedy_score=1e+3, sample_score=-449]
# Epoch [86/100]: 100%|██████████| 32/32 [00:38<00:00,  1.20s/it, loss=0.418, positive_reward=0.195, negative_reward=0.0156, margin=0.18, greedy_score=1e+3, sample_score=-442]
# Epoch [87/100]: 100%|██████████| 32/32 [00:39<00:00,  1.22s/it, loss=0.451, positive_reward=0.17, negative_reward=0.0367, margin=0.133, greedy_score=1e+3, sample_score=-455]
# Epoch [88/100]: 100%|██████████| 32/32 [00:40<00:00,  1.28s/it, loss=0.455, positive_reward=0.174, negative_reward=0.0513, margin=0.123, greedy_score=1e+3, sample_score=-476]
# Epoch [89/100]: 100%|██████████| 32/32 [00:37<00:00,  1.19s/it, loss=0.439, positive_reward=0.193, negative_reward=0.0594, margin=0.133, greedy_score=1e+3, sample_score=-492]
# Epoch [90/100]: 100%|██████████| 32/32 [00:37<00:00,  1.17s/it, loss=0.428, positive_reward=0.186, negative_reward=0.0512, margin=0.134, greedy_score=1e+3, sample_score=-434]
# Epoch [91/100]: 100%|██████████| 32/32 [00:38<00:00,  1.22s/it, loss=0.404, positive_reward=0.199, negative_reward=-.0137, margin=0.213, greedy_score=1e+3, sample_score=-456]
# Epoch [92/100]: 100%|██████████| 32/32 [00:39<00:00,  1.22s/it, loss=0.443, positive_reward=0.169, negative_reward=0.003, margin=0.166, greedy_score=1e+3, sample_score=-465]
# Epoch [93/100]: 100%|██████████| 32/32 [00:40<00:00,  1.26s/it, loss=0.453, positive_reward=0.196, negative_reward=0.0566, margin=0.139, greedy_score=1e+3, sample_score=-455]
# Epoch [94/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.404, positive_reward=0.183, negative_reward=0.0163, margin=0.167, greedy_score=1e+3, sample_score=-453]
# Epoch [95/100]: 100%|██████████| 32/32 [00:40<00:00,  1.26s/it, loss=0.44, positive_reward=0.184, negative_reward=0.0404, margin=0.143, greedy_score=1e+3, sample_score=-498]
# Epoch [96/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.5, positive_reward=0.178, negative_reward=0.0244, margin=0.153, greedy_score=1e+3, sample_score=-459]
# Epoch [97/100]: 100%|██████████| 32/32 [00:35<00:00,  1.11s/it, loss=0.458, positive_reward=0.162, negative_reward=0.0623, margin=0.0994, greedy_score=1e+3, sample_score=-477]
# Epoch [98/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.384, positive_reward=0.173, negative_reward=-.00556, margin=0.178, greedy_score=1e+3, sample_score=-450]
# Epoch [99/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.433, positive_reward=0.179, negative_reward=0.0466, margin=0.132, greedy_score=1e+3, sample_score=-445]
# Epoch [100/100]: 100%|██████████| 32/32 [00:28<00:00,  1.14it/s, loss=0.434, positive_reward=0.182, negative_reward=0.0462, margin=0.136, greedy_score=1e+3, sample_score=-456]

# %%
# save all png to /mnt/nfs/work/albertliu/RL/CartPole-v1/DPO

# draw the loss graph
import matplotlib.pyplot as plt
plt.plot(loss_graph)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss vs Iteration")
plt.savefig("./loss.png")

plt.show()



# draw the reward graph
plt.plot(greedy_rewards)
plt.xlabel("Iteration")
plt.ylabel("Greedy Reward")
plt.title("Greedy Reward vs Iteration")
plt.savefig("./greedy_reward.png")
plt.show()

# draw the reward graph
plt.plot(sample_rewards)
plt.xlabel("Iteration")
plt.ylabel("Sample Reward")
plt.title("Sample Reward vs Iteration")
plt.savefig("./sample_reward.png")
plt.show()


# drqw the margin graph
plt.plot(margin_graph)
plt.xlabel("Iteration")
plt.ylabel("Margin")
plt.title("Margin vs Iteration")
plt.savefig("./margin.png")
plt.show()

# draw the positive reward graph
plt.plot(positive_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Positive Reward")
plt.title("Positive Reward vs Iteration")
plt.savefig("./positive_reward.png")
plt.show()

# draw the negative reward graph
plt.plot(negative_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Negative Reward")
plt.title("Negative Reward vs Iteration")

plt.savefig("./negative_reward.png")
plt.show()

# %%
# from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
# from stable_baselines3.common.vec_env import VecEnv
# import gymnasium as gym
# from imitation.policies.serialize import load_policy
# from imitation.util.util import make_vec_env
# import numpy as np
# import torch
# import os

# # 创建环境
# env = make_vec_env(
#     "seals:seals/Walker2d-v1",
#     rng=np.random.default_rng(),
#     n_envs=1,
#     env_make_kwargs={"render_mode": "rgb_array"},
# )

# # 使用 VecVideoRecorder 包装环境以启用视频记录，指定视频保存的路径
# video_folder = './videos'
# video_length = 200  # 设置视频长度
# env = VecVideoRecorder(env, video_folder,
#                        record_video_trigger=lambda step: step == 0, video_length=video_length,
#                        name_prefix="Walker2d-video")

# # 创建模型，这里以从 Hugging Face 加载预训练的 PPO 模型为例
# model = load_policy(
#     "ppo-huggingface",
#     organization="HumanCompatibleAI",
#     env_name="seals/Walker2d-v1",
#     venv=env,
# )

# # 训练模型
# # 注意: 此处假定模型已经预训练，无需再次训练

# # 测试模型，生成视频
# obs = env.reset()
# done = False
# while not done:
#     action, _states = model.predict(obs, deterministic=True)
#     obs, rewards, dones, info = env.step(action)
#     done = dones.any()

# env.close()

# # 如果需要手动保存视频（有时候视频不会在关闭时自动保存）
# env.record_video_trigger(video_length)
