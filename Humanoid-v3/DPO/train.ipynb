# %%
import gymnasium as gym
import numpy as np
from stable_baselines3.common.env_util import make_vec_env as make_vec_env_sb3
from copy import deepcopy
import torch
from torch.distributions import Normal,MultivariateNormal
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.utils.data import Dataset, DataLoader
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
import imageio
import pandas as pd
from tqdm import tqdm
from PIL import Image
from stable_baselines3.dqn.policies import MlpPolicy
import matplotlib.pyplot as plt
import os

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !nvidia-smi
# clean up memory forcefully
torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# Mon May 13 01:06:22 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  | 00000000:01:00.0 Off |                  N/A |
# | 17%   56C    P2              91W / 250W |   3852MiB / 11264MiB |     97%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    228304      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    229850      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    277377      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    280712      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    319688      C   ...iu/miniconda3/envs/myenv/bin/python      300MiB |
# |    0   N/A  N/A    328416      C   ...iu/miniconda3/envs/myenv/bin/python      204MiB |
# |    0   N/A  N/A    377684      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   1475780      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   2544023      C   ...u/miniconda3/envs/myenv2/bin/python      184MiB |
# |    0   N/A  N/A   2546464      C   ...u/miniconda3/envs/myenv2/bin/python      192MiB |
# |    0   N/A  N/A   2573704      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2587643      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2588031      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2594108      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2594730      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2600718      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2605031      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2605258      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2610076      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# +---------------------------------------------------------------------------------------+
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
class CustomDataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32,device=device)
        self.actions = torch.tensor(actions, dtype=torch.float32,device=device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, output_dim,init_w=3e-3,log_std_min=-20,log_std_max=2):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 32)


        self.fc2 = nn.Linear(32, 32)
        self.log_std = nn.Linear(32, output_dim)
        self.mu=nn.Linear(32,output_dim)
        self.log_std_min=log_std_min
        self.log_std_max=log_std_max
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        torch.nn.init.kaiming_normal_(self.fc2.weight)
        self.mu.weight.data.uniform_(-init_w,init_w)
        self.mu.bias.data.uniform_(-init_w,init_w)
        self.log_std.weight.data.uniform_(-init_w,init_w)
        self.log_std.bias.data.uniform_(-init_w,init_w)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = self.mu(x) # Only apply if action bounds are [-1, 1]
        log_std = self.log_std(x)  # Ensure std is positive
        log_std=torch.clamp(log_std,self.log_std_min,self.log_std_max)

        return mu, log_std
# Out:
# Using device: cuda

# %%
# from imitation.util.util import make_vec_env

# observations= np.load("../dataset/obs.npy", allow_pickle=True)
# actions = np.load("../dataset/actions.npy", allow_pickle=True)

# observations=observations.squeeze()
# actions=actions.squeeze()

# print(observations.shape, actions.shape)
# print(observations[0], actions[0])
import pickle
import numpy as np
#　read /mnt/nfs/work/c98181/TDIL/saved_expert_transition/Walker2d-v3/sac/episode_num1_6123.pkl
# "states", "actions", "rewards", "next_states", "dones".
with open("/mnt/nfs/work/c98181/TDIL/saved_expert_transition/Humanoid-v3/sac/episode_num1_7463.pkl", "rb") as f:
    data = pickle.load(f)

    obs_list = data["states"]
    actions_list = data["actions"]
    observations=np.array(obs_list)
    actions=np.array(actions_list)
    # shape
    print(observations.shape)
    print(actions.shape)

# env=gym.make("Walker2d-v3",exclude_current_positions_from_observation=False,render_mode="rgb_array")
env=gym.make("Humanoid-v3",render_mode="rgb_array")
# Out:
# (1000, 376)
# (1000, 17)
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Humanoid-v3 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_env.py:211: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(

# %%
class mydataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32).to(device)
        self.actions = torch.tensor(actions, dtype=torch.float32).to(device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

# %%
policy_network = PolicyNetwork(376,17).to(device)
prev = PolicyNetwork(376,17).to(device)
prev.load_state_dict(policy_network.state_dict())
prev.eval()

optimizer = torch.optim.Adam(policy_network.parameters(), lr=0.0003,weight_decay=1e-4)

# Training loop
num_epochs = 100
batch_size = 32

dataset = mydataset(observations=observations, actions=actions)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

loss_graph=[]
greedy_rewards=[]
sample_rewards=[]
margin_graph=[]
positive_reward_graph=[]
negative_reward_graph=[]
log_interval = len(observations)//1
num_test = 10
now_log=0
now_pos=0
greedy_score=0
sample_score=0
for epoch in range(num_epochs):
    policy_network.train()

    # Compute the log probabilities of the actions
    pbar=tqdm(dataloader,position=0,leave=True)
    now_log=0

    for step, (obs_batch,act_batch) in enumerate(pbar):
        # obs_batch = torch.tensor(np.array(obs_batch), dtype=torch.float32).to(device)
        # act_batch = torch.tensor(np.array(act_batch), dtype=torch.float32).to(device)

        now_log+=obs_batch.shape[0]
        now_pos+=obs_batch.shape[0]
        
        mu, log_std = policy_network(obs_batch)
        std=log_std.exp()
        dist = Normal(mu, std)
        z_model=dist.rsample()
        model_action=torch.tanh(z_model)
        z_expert=torch.atanh(torch.clamp(act_batch, -0.999999, 0.999999))
        epsilon=1e-6


        policy_rejected_logps =dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
        policy_chosen_logps = dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        with torch.no_grad():
          prev_mu, prev_log_std = prev(obs_batch)
          prev_std=prev_log_std.exp()
          prev_dist = Normal(prev_mu, prev_std)

          reference_rejected_logps =prev_dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
          reference_chosen_logps = prev_dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        pi_logratios = policy_chosen_logps - policy_rejected_logps
        ref_logratios = reference_chosen_logps - reference_rejected_logps

        chosen_KL = (policy_chosen_logps - reference_chosen_logps).mean().clamp(min=0)
        reject_KL = (policy_rejected_logps - reference_rejected_logps).mean().clamp(min=0)

       

        chosen_logratios = policy_chosen_logps - reference_chosen_logps
        reject_logratios = policy_rejected_logps - reference_rejected_logps

        # logits = chosen_logratios - reject_logratios

        if epoch < -1:
          loss = - (policy_chosen_logps).mean()
        else:
          beta = 1
          losses=torch.pow(chosen_logratios-0.5,2)+torch.pow(reject_logratios+0.5,2)
          loss = losses.mean()
        #   losses = torch.cat((1 - F.logsigmoid(beta * (chosen_logratios - reject_KL)), 1 - F.logsigmoid(beta * (chosen_KL - reject_logratios))), 0)
        #   loss = losses.mean()
        # Optimize the policy
        optimizer.zero_grad()



        loss.backward()

        optimizer.step()
        pbar.set_description((f"Epoch [{epoch+1}/{num_epochs}]"))
        positive_reward = pi_logratios.detach().mean().item()
        negative_reward = ref_logratios.detach().mean().item()
        margin = positive_reward - negative_reward
        loss_graph.append(loss.detach().item())
        margin_graph.append(margin)
        positive_reward_graph.append(positive_reward)
        negative_reward_graph.append(negative_reward)



        total_reward=0
        if now_log>=log_interval:
            now_log-=log_interval
            
            policy_network.eval()  # 切换到评估模式

            

            total_reward=0
            # test the policy and save as the first test as gif
            # frames = []
            for _ in range(num_test):
                state,_ = env.reset()
                done = False

                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(mu)   
                        action.squeeze_()

                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/greedy/"+image_path, frames)

            greedy_score=total_reward/num_test
            total_reward=0
            frames = []
            # test the policy and save as the first test as gif
            for _ in range(num_test):
                state,_ = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(Normal(mu,std).sample())
                        action.squeeze_()
                       
                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/sample/"+image_path, frames)

            sample_score=total_reward/num_test
            greedy_rewards.append(greedy_score)
            sample_rewards.append(sample_score)
            policy_network.train()  # 切换回训练模式
        pbar.set_postfix({"loss":loss.detach().item(), "positive_reward": positive_reward, "negative_reward": negative_reward, "margin": positive_reward - negative_reward,"greedy_score":greedy_score,"sample_score":sample_score})
    # prev.load_state_dict(policy_network.state_dict())
    # prev.eval()
         

env.close()
# Out:
# Epoch [1/100]:  75%|███████▌  | 24/32 [00:00<00:00, 40.38it/s, loss=4.19e+5, positive_reward=-.507, negative_reward=-.0475, margin=-.46, greedy_score=0, sample_score=0]/tmp/ipykernel_2610522/1162110946.py:117: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025847094/work/torch/csrc/utils/tensor_new.cpp:275.)
#   state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
# Epoch [1/100]: 100%|██████████| 32/32 [00:55<00:00,  1.73s/it, loss=0.85, positive_reward=-.14, negative_reward=-.157, margin=0.0173, greedy_score=5e+3, sample_score=4.81e+3]
# Epoch [2/100]: 100%|██████████| 32/32 [00:52<00:00,  1.63s/it, loss=4.35, positive_reward=-.254, negative_reward=-.129, margin=-.126, greedy_score=5.01e+3, sample_score=4.78e+3]
# Epoch [3/100]: 100%|██████████| 32/32 [00:53<00:00,  1.66s/it, loss=1.23e+4, positive_reward=-.427, negative_reward=4, margin=-4.43, greedy_score=5.06e+3, sample_score=4.77e+3]
# Epoch [4/100]: 100%|██████████| 32/32 [00:55<00:00,  1.74s/it, loss=71.9, positive_reward=-.669, negative_reward=0.33, margin=-.999, greedy_score=5.01e+3, sample_score=4.82e+3]
# Epoch [5/100]: 100%|██████████| 32/32 [00:54<00:00,  1.72s/it, loss=185, positive_reward=-.856, negative_reward=1.47, margin=-2.32, greedy_score=5.06e+3, sample_score=4.77e+3]
# Epoch [6/100]: 100%|██████████| 32/32 [00:53<00:00,  1.66s/it, loss=1.34, positive_reward=-.101, negative_reward=-.291, margin=0.191, greedy_score=5.04e+3, sample_score=4.74e+3]
# Epoch [7/100]: 100%|██████████| 32/32 [00:54<00:00,  1.70s/it, loss=117, positive_reward=-.198, negative_reward=0.582, margin=-.78, greedy_score=5.05e+3, sample_score=4.77e+3]
# Epoch [8/100]: 100%|██████████| 32/32 [00:55<00:00,  1.74s/it, loss=0.607, positive_reward=-.0179, negative_reward=-.13, margin=0.112, greedy_score=4.98e+3, sample_score=4.77e+3]
# Epoch [9/100]: 100%|██████████| 32/32 [00:57<00:00,  1.79s/it, loss=0.548, positive_reward=-.046, negative_reward=-.12, margin=0.0745, greedy_score=5.03e+3, sample_score=4.73e+3]
# Epoch [10/100]: 100%|██████████| 32/32 [00:55<00:00,  1.73s/it, loss=1.88e+3, positive_reward=-2.23, negative_reward=3.4, margin=-5.63, greedy_score=5.07e+3, sample_score=4.76e+3]
# Epoch [11/100]: 100%|██████████| 32/32 [00:57<00:00,  1.81s/it, loss=1.5, positive_reward=-.137, negative_reward=-.0985, margin=-.0385, greedy_score=5.04e+3, sample_score=4.75e+3]
# Epoch [12/100]: 100%|██████████| 32/32 [00:56<00:00,  1.78s/it, loss=10.1, positive_reward=-.164, negative_reward=-.00461, margin=-.159, greedy_score=5.06e+3, sample_score=4.71e+3]
# Epoch [13/100]: 100%|██████████| 32/32 [01:03<00:00,  1.98s/it, loss=1.13e+4, positive_reward=-.994, negative_reward=9.32, margin=-10.3, greedy_score=5.07e+3, sample_score=4.7e+3]
# Epoch [14/100]: 100%|██████████| 32/32 [00:56<00:00,  1.78s/it, loss=2.09e+4, positive_reward=-.571, negative_reward=-6.23, margin=5.66, greedy_score=5.07e+3, sample_score=4.78e+3]
# Epoch [15/100]: 100%|██████████| 32/32 [00:53<00:00,  1.67s/it, loss=2.98e+6, positive_reward=-1.03, negative_reward=141, margin=-142, greedy_score=5.03e+3, sample_score=4.78e+3]
# Epoch [16/100]: 100%|██████████| 32/32 [00:55<00:00,  1.73s/it, loss=5.87e+4, positive_reward=-.846, negative_reward=24.6, margin=-25.5, greedy_score=4.96e+3, sample_score=4.73e+3]
# Epoch [17/100]: 100%|██████████| 32/32 [00:58<00:00,  1.82s/it, loss=340, positive_reward=-.731, negative_reward=2.46, margin=-3.19, greedy_score=4.99e+3, sample_score=4.76e+3]
# Epoch [18/100]: 100%|██████████| 32/32 [00:53<00:00,  1.67s/it, loss=42.1, positive_reward=-.359, negative_reward=0.779, margin=-1.14, greedy_score=5.01e+3, sample_score=4.78e+3]
# Epoch [19/100]: 100%|██████████| 32/32 [01:01<00:00,  1.91s/it, loss=1.04e+3, positive_reward=-.753, negative_reward=4.94, margin=-5.69, greedy_score=5.03e+3, sample_score=4.83e+3]
# Epoch [20/100]: 100%|██████████| 32/32 [00:53<00:00,  1.68s/it, loss=227, positive_reward=-.338, negative_reward=1.36, margin=-1.69, greedy_score=4.98e+3, sample_score=4.74e+3]
# Epoch [21/100]: 100%|██████████| 32/32 [00:56<00:00,  1.77s/it, loss=9.14e+3, positive_reward=-.593, negative_reward=8.99, margin=-9.58, greedy_score=4.98e+3, sample_score=4.77e+3]
# Epoch [22/100]: 100%|██████████| 32/32 [00:55<00:00,  1.74s/it, loss=4.55e+5, positive_reward=-1.02, negative_reward=79.9, margin=-80.9, greedy_score=5.06e+3, sample_score=4.73e+3]
# Epoch [23/100]: 100%|██████████| 32/32 [00:58<00:00,  1.82s/it, loss=1.94e+3, positive_reward=-.462, negative_reward=3.98, margin=-4.44, greedy_score=5.03e+3, sample_score=4.75e+3]
# Epoch [24/100]: 100%|██████████| 32/32 [00:54<00:00,  1.71s/it, loss=5.01e+9, positive_reward=-1.95, negative_reward=6.09e+3, margin=-6.09e+3, greedy_score=5.06e+3, sample_score=4.75e+3]
# Epoch [25/100]: 100%|██████████| 32/32 [00:54<00:00,  1.69s/it, loss=111, positive_reward=-.778, negative_reward=0.879, margin=-1.66, greedy_score=5.03e+3, sample_score=4.75e+3]
# Epoch [26/100]: 100%|██████████| 32/32 [00:54<00:00,  1.71s/it, loss=7.11e+3, positive_reward=-1.88, negative_reward=14.7, margin=-16.6, greedy_score=5.01e+3, sample_score=4.83e+3]
# Epoch [27/100]: 100%|██████████| 32/32 [00:54<00:00,  1.69s/it, loss=1.53e+11, positive_reward=-2.02, negative_reward=3.31e+4, margin=-3.31e+4, greedy_score=5e+3, sample_score=4.76e+3]
# Epoch [28/100]: 100%|██████████| 32/32 [00:51<00:00,  1.62s/it, loss=1.83e+4, positive_reward=-1.39, negative_reward=20, margin=-21.4, greedy_score=4.98e+3, sample_score=4.75e+3]
# Epoch [29/100]: 100%|██████████| 32/32 [00:53<00:00,  1.66s/it, loss=335, positive_reward=-.729, negative_reward=2.31, margin=-3.04, greedy_score=5.01e+3, sample_score=4.81e+3]
# Epoch [30/100]: 100%|██████████| 32/32 [00:54<00:00,  1.72s/it, loss=3.79e+5, positive_reward=-1.54, negative_reward=64.4, margin=-66, greedy_score=4.99e+3, sample_score=4.74e+3]
# Epoch [31/100]: 100%|██████████| 32/32 [00:52<00:00,  1.64s/it, loss=702, positive_reward=-.983, negative_reward=2.9, margin=-3.89, greedy_score=4.97e+3, sample_score=4.75e+3]
# Epoch [32/100]: 100%|██████████| 32/32 [00:51<00:00,  1.62s/it, loss=5.03e+6, positive_reward=-1.55, negative_reward=197, margin=-198, greedy_score=4.96e+3, sample_score=4.77e+3]
# Epoch [33/100]: 100%|██████████| 32/32 [00:53<00:00,  1.67s/it, loss=1.97e+3, positive_reward=-1.46, negative_reward=5.7, margin=-7.16, greedy_score=4.85e+3, sample_score=4.79e+3]
# Epoch [34/100]: 100%|██████████| 32/32 [00:53<00:00,  1.66s/it, loss=7.83e+5, positive_reward=-1.79, negative_reward=87.7, margin=-89.5, greedy_score=4.82e+3, sample_score=4.78e+3]
# Epoch [35/100]: 100%|██████████| 32/32 [00:44<00:00,  1.38s/it, loss=945, positive_reward=-.828, negative_reward=3.1, margin=-3.93, greedy_score=4.94e+3, sample_score=4.79e+3]
# Epoch [36/100]: 100%|██████████| 32/32 [00:39<00:00,  1.25s/it, loss=6.85e+4, positive_reward=-2.33, negative_reward=30.2, margin=-32.6, greedy_score=4.87e+3, sample_score=4.8e+3]
# Epoch [37/100]: 100%|██████████| 32/32 [00:41<00:00,  1.30s/it, loss=8.77e+3, positive_reward=-2.02, negative_reward=15.3, margin=-17.3, greedy_score=4.95e+3, sample_score=4.81e+3]
# Epoch [38/100]: 100%|██████████| 32/32 [00:32<00:00,  1.00s/it, loss=30.7, positive_reward=-.888, negative_reward=0.551, margin=-1.44, greedy_score=4.95e+3, sample_score=4.8e+3]
# Epoch [39/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=2.27e+4, positive_reward=-2.08, negative_reward=25.1, margin=-27.2, greedy_score=4.92e+3, sample_score=4.8e+3]
# Epoch [40/100]: 100%|██████████| 32/32 [00:24<00:00,  1.32it/s, loss=1.21e+6, positive_reward=-1.45, negative_reward=117, margin=-119, greedy_score=4.99e+3, sample_score=4.83e+3]
# Epoch [41/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=2.01e+4, positive_reward=-2.29, negative_reward=26.1, margin=-28.4, greedy_score=5.02e+3, sample_score=4.79e+3]
# Epoch [42/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=1e+4, positive_reward=-1.72, negative_reward=19.2, margin=-20.9, greedy_score=4.99e+3, sample_score=4.84e+3]
# Epoch [43/100]: 100%|██████████| 32/32 [00:23<00:00,  1.37it/s, loss=1.39e+3, positive_reward=-1.16, negative_reward=4.43, margin=-5.59, greedy_score=4.99e+3, sample_score=4.78e+3]
# Epoch [44/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=537, positive_reward=-1.36, negative_reward=3.41, margin=-4.77, greedy_score=4.98e+3, sample_score=4.78e+3]
# Epoch [45/100]: 100%|██████████| 32/32 [00:24<00:00,  1.29it/s, loss=38.5, positive_reward=-.677, negative_reward=0.513, margin=-1.19, greedy_score=4.98e+3, sample_score=4.75e+3]
# Epoch [46/100]: 100%|██████████| 32/32 [00:23<00:00,  1.37it/s, loss=4.09e+8, positive_reward=-1.87, negative_reward=1.78e+3, margin=-1.78e+3, greedy_score=5.05e+3, sample_score=4.77e+3]
# Epoch [47/100]: 100%|██████████| 32/32 [00:23<00:00,  1.36it/s, loss=1.1e+7, positive_reward=-1.89, negative_reward=311, margin=-313, greedy_score=5.03e+3, sample_score=4.82e+3]
# Epoch [48/100]: 100%|██████████| 32/32 [00:23<00:00,  1.39it/s, loss=2.37e+5, positive_reward=-2.24, negative_reward=79.1, margin=-81.3, greedy_score=5.02e+3, sample_score=4.82e+3]
# Epoch [49/100]: 100%|██████████| 32/32 [00:23<00:00,  1.39it/s, loss=289, positive_reward=-1.3, negative_reward=2.09, margin=-3.39, greedy_score=4.96e+3, sample_score=4.79e+3]
# Epoch [50/100]: 100%|██████████| 32/32 [00:22<00:00,  1.42it/s, loss=1.49e+10, positive_reward=-3.94, negative_reward=1.49e+4, margin=-1.49e+4, greedy_score=5e+3, sample_score=4.75e+3]
# Epoch [51/100]: 100%|██████████| 32/32 [00:23<00:00,  1.36it/s, loss=4.66e+5, positive_reward=-1.89, negative_reward=71.8, margin=-73.7, greedy_score=5.03e+3, sample_score=4.8e+3]
# Epoch [52/100]: 100%|██████████| 32/32 [00:23<00:00,  1.37it/s, loss=9.12e+5, positive_reward=-1.56, negative_reward=87, margin=-88.6, greedy_score=5.03e+3, sample_score=4.78e+3]
# Epoch [53/100]: 100%|██████████| 32/32 [00:23<00:00,  1.36it/s, loss=3.53e+3, positive_reward=-1.13, negative_reward=5.97, margin=-7.1, greedy_score=5e+3, sample_score=4.8e+3]
# Epoch [54/100]: 100%|██████████| 32/32 [00:23<00:00,  1.34it/s, loss=3.13e+7, positive_reward=-1.64, negative_reward=493, margin=-495, greedy_score=4.99e+3, sample_score=4.79e+3]
# Epoch [55/100]: 100%|██████████| 32/32 [00:23<00:00,  1.36it/s, loss=3.48e+8, positive_reward=-6.53, negative_reward=2.76e+3, margin=-2.76e+3, greedy_score=4.99e+3, sample_score=4.75e+3]
# Epoch [56/100]: 100%|██████████| 32/32 [00:23<00:00,  1.39it/s, loss=1.16e+7, positive_reward=-2.67, negative_reward=306, margin=-309, greedy_score=4.93e+3, sample_score=4.8e+3]
# Epoch [57/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=396, positive_reward=-1.32, negative_reward=3.3, margin=-4.61, greedy_score=4.92e+3, sample_score=4.79e+3]
# Epoch [58/100]: 100%|██████████| 32/32 [00:23<00:00,  1.37it/s, loss=4.36e+9, positive_reward=-7.17, negative_reward=7.69e+3, margin=-7.7e+3, greedy_score=4.98e+3, sample_score=4.75e+3]
# Epoch [59/100]: 100%|██████████| 32/32 [00:23<00:00,  1.39it/s, loss=8.11e+5, positive_reward=-1.71, negative_reward=95.9, margin=-97.6, greedy_score=4.94e+3, sample_score=4.78e+3]
# Epoch [60/100]: 100%|██████████| 32/32 [00:22<00:00,  1.40it/s, loss=2.08e+6, positive_reward=-1.97, negative_reward=128, margin=-130, greedy_score=5.01e+3, sample_score=4.76e+3]
# Epoch [61/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=9.92e+3, positive_reward=-1.18, negative_reward=18, margin=-19.1, greedy_score=4.94e+3, sample_score=4.77e+3]
# Epoch [62/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=6.1e+12, positive_reward=-18.6, negative_reward=2.12e+5, margin=-2.12e+5, greedy_score=4.96e+3, sample_score=4.73e+3]
# Epoch [63/100]: 100%|██████████| 32/32 [00:24<00:00,  1.29it/s, loss=1.57e+7, positive_reward=-4.32, negative_reward=412, margin=-417, greedy_score=4.9e+3, sample_score=4.77e+3]
# Epoch [64/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=6.62e+11, positive_reward=-24.6, negative_reward=8.02e+4, margin=-8.02e+4, greedy_score=4.94e+3, sample_score=4.78e+3]
# Epoch [65/100]: 100%|██████████| 32/32 [00:24<00:00,  1.32it/s, loss=3.03e+6, positive_reward=-2.26, negative_reward=160, margin=-163, greedy_score=4.92e+3, sample_score=4.82e+3]
# Epoch [66/100]: 100%|██████████| 32/32 [00:22<00:00,  1.39it/s, loss=4.97e+8, positive_reward=-6.43, negative_reward=3.29e+3, margin=-3.29e+3, greedy_score=4.95e+3, sample_score=4.77e+3]
# Epoch [67/100]: 100%|██████████| 32/32 [00:22<00:00,  1.39it/s, loss=3.02e+5, positive_reward=-2.82, negative_reward=74.3, margin=-77.1, greedy_score=4.87e+3, sample_score=4.76e+3]
# Epoch [68/100]: 100%|██████████| 32/32 [00:23<00:00,  1.37it/s, loss=2.32e+6, positive_reward=-4.53, negative_reward=216, margin=-220, greedy_score=4.89e+3, sample_score=4.78e+3]
# Epoch [69/100]: 100%|██████████| 32/32 [00:23<00:00,  1.35it/s, loss=668, positive_reward=-2.06, negative_reward=5.68, margin=-7.73, greedy_score=4.91e+3, sample_score=4.77e+3]
# Epoch [70/100]: 100%|██████████| 32/32 [00:23<00:00,  1.35it/s, loss=7.4e+9, positive_reward=-5.87, negative_reward=7.39e+3, margin=-7.39e+3, greedy_score=4.8e+3, sample_score=4.78e+3]
# Epoch [71/100]: 100%|██████████| 32/32 [00:23<00:00,  1.36it/s, loss=552, positive_reward=-1.11, negative_reward=3.77, margin=-4.88, greedy_score=4.92e+3, sample_score=4.8e+3]
# Epoch [72/100]: 100%|██████████| 32/32 [00:23<00:00,  1.39it/s, loss=5.18e+12, positive_reward=-33.6, negative_reward=2.28e+5, margin=-2.28e+5, greedy_score=4.89e+3, sample_score=4.76e+3]
# Epoch [73/100]: 100%|██████████| 32/32 [00:22<00:00,  1.45it/s, loss=1.05e+3, positive_reward=-1.37, negative_reward=4.45, margin=-5.82, greedy_score=4.76e+3, sample_score=4.73e+3]
# Epoch [74/100]: 100%|██████████| 32/32 [00:22<00:00,  1.44it/s, loss=3.47e+3, positive_reward=-2.62, negative_reward=13.6, margin=-16.2, greedy_score=4.85e+3, sample_score=4.78e+3]
# Epoch [75/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=4.31e+3, positive_reward=-2.05, negative_reward=13.6, margin=-15.7, greedy_score=4.88e+3, sample_score=4.81e+3]
# Epoch [76/100]: 100%|██████████| 32/32 [00:22<00:00,  1.42it/s, loss=1.46e+4, positive_reward=-1.93, negative_reward=24.3, margin=-26.3, greedy_score=4.92e+3, sample_score=4.73e+3]
# Epoch [77/100]: 100%|██████████| 32/32 [00:22<00:00,  1.45it/s, loss=8.7e+10, positive_reward=-11.5, negative_reward=2.53e+4, margin=-2.54e+4, greedy_score=4.85e+3, sample_score=4.75e+3]
# Epoch [78/100]: 100%|██████████| 32/32 [00:22<00:00,  1.40it/s, loss=3.57e+4, positive_reward=-2.86, negative_reward=41.5, margin=-44.4, greedy_score=4.89e+3, sample_score=4.8e+3]
# Epoch [79/100]: 100%|██████████| 32/32 [00:22<00:00,  1.44it/s, loss=1.73e+4, positive_reward=-2.33, negative_reward=28.4, margin=-30.7, greedy_score=4.86e+3, sample_score=4.71e+3]
# Epoch [80/100]: 100%|██████████| 32/32 [00:27<00:00,  1.14it/s, loss=9.44e+4, positive_reward=-3.84, negative_reward=67.1, margin=-71, greedy_score=4.8e+3, sample_score=4.79e+3]
# Epoch [81/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=1.07e+15, positive_reward=-66, negative_reward=2.81e+6, margin=-2.81e+6, greedy_score=4.87e+3, sample_score=4.75e+3]
# Epoch [82/100]: 100%|██████████| 32/32 [00:21<00:00,  1.48it/s, loss=1.13e+6, positive_reward=-3.23, negative_reward=149, margin=-152, greedy_score=4.77e+3, sample_score=4.77e+3]
# Epoch [83/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=2.03e+11, positive_reward=-14.2, negative_reward=3.89e+4, margin=-3.89e+4, greedy_score=4.77e+3, sample_score=4.7e+3]
# Epoch [84/100]: 100%|██████████| 32/32 [00:26<00:00,  1.21it/s, loss=2.16e+13, positive_reward=-37.8, negative_reward=3.99e+5, margin=-3.99e+5, greedy_score=4.87e+3, sample_score=4.79e+3]
# Epoch [85/100]: 100%|██████████| 32/32 [00:22<00:00,  1.44it/s, loss=9.61e+6, positive_reward=-5.5, negative_reward=457, margin=-462, greedy_score=4.86e+3, sample_score=4.8e+3]
# Epoch [86/100]: 100%|██████████| 32/32 [00:27<00:00,  1.17it/s, loss=1.13e+7, positive_reward=-6.45, negative_reward=506, margin=-513, greedy_score=4.8e+3, sample_score=4.74e+3]
# Epoch [87/100]: 100%|██████████| 32/32 [00:23<00:00,  1.36it/s, loss=2.3e+12, positive_reward=-24.3, negative_reward=1.31e+5, margin=-1.31e+5, greedy_score=4.85e+3, sample_score=4.85e+3]
# Epoch [88/100]: 100%|██████████| 32/32 [00:27<00:00,  1.16it/s, loss=6.76e+5, positive_reward=-4.81, negative_reward=137, margin=-142, greedy_score=4.86e+3, sample_score=4.77e+3]
# Epoch [89/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=9.96e+6, positive_reward=-10.8, negative_reward=610, margin=-621, greedy_score=4.83e+3, sample_score=4.74e+3]
# Epoch [90/100]: 100%|██████████| 32/32 [00:22<00:00,  1.40it/s, loss=2.68e+7, positive_reward=-8.1, negative_reward=611, margin=-619, greedy_score=4.74e+3, sample_score=4.8e+3]
# Epoch [91/100]: 100%|██████████| 32/32 [00:23<00:00,  1.38it/s, loss=1.18e+6, positive_reward=-6.67, negative_reward=204, margin=-210, greedy_score=4.78e+3, sample_score=4.72e+3]
# Epoch [92/100]: 100%|██████████| 32/32 [00:22<00:00,  1.45it/s, loss=3.44e+5, positive_reward=-7.43, negative_reward=155, margin=-163, greedy_score=4.8e+3, sample_score=4.75e+3]
# Epoch [93/100]: 100%|██████████| 32/32 [00:24<00:00,  1.29it/s, loss=2.81e+8, positive_reward=-9.04, negative_reward=1.81e+3, margin=-1.82e+3, greedy_score=4.78e+3, sample_score=4.73e+3]
# Epoch [94/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=6.99e+5, positive_reward=-5.67, negative_reward=131, margin=-137, greedy_score=4.79e+3, sample_score=4.73e+3]
# Epoch [95/100]: 100%|██████████| 32/32 [00:22<00:00,  1.44it/s, loss=6.17e+16, positive_reward=-132, negative_reward=2.13e+7, margin=-2.13e+7, greedy_score=4.87e+3, sample_score=4.82e+3]
# Epoch [96/100]: 100%|██████████| 32/32 [00:22<00:00,  1.45it/s, loss=2.49e+6, positive_reward=-5.4, negative_reward=236, margin=-242, greedy_score=4.77e+3, sample_score=4.75e+3]
# Epoch [97/100]: 100%|██████████| 32/32 [00:23<00:00,  1.38it/s, loss=2.53e+16, positive_reward=-116, negative_reward=1.36e+7, margin=-1.36e+7, greedy_score=4.81e+3, sample_score=4.74e+3]
# Epoch [98/100]: 100%|██████████| 32/32 [00:21<00:00,  1.46it/s, loss=8.78e+14, positive_reward=-66.8, negative_reward=2.58e+6, margin=-2.58e+6, greedy_score=4.82e+3, sample_score=4.74e+3]
# Epoch [99/100]: 100%|██████████| 32/32 [00:22<00:00,  1.45it/s, loss=3.7e+10, positive_reward=-12.2, negative_reward=1.69e+4, margin=-1.69e+4, greedy_score=4.8e+3, sample_score=4.72e+3]
# Epoch [100/100]: 100%|██████████| 32/32 [00:23<00:00,  1.37it/s, loss=1.42e+10, positive_reward=-14.5, negative_reward=1.12e+4, margin=-1.12e+4, greedy_score=4.82e+3, sample_score=4.71e+3]

# %%
# save all png to /mnt/nfs/work/albertliu/RL/CartPole-v1/DPO

# draw the loss graph
import matplotlib.pyplot as plt
plt.plot(loss_graph)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss vs Iteration")
plt.savefig("./loss.png")

plt.show()



# draw the reward graph
plt.plot(greedy_rewards)
plt.xlabel("Iteration")
plt.ylabel("Greedy Reward")
plt.title("Greedy Reward vs Iteration")
plt.savefig("./greedy_reward.png")
plt.show()

# draw the reward graph
plt.plot(sample_rewards)
plt.xlabel("Iteration")
plt.ylabel("Sample Reward")
plt.title("Sample Reward vs Iteration")
plt.savefig("./sample_reward.png")
plt.show()


# drqw the margin graph
plt.plot(margin_graph)
plt.xlabel("Iteration")
plt.ylabel("Margin")
plt.title("Margin vs Iteration")
plt.savefig("./margin.png")
plt.show()

# draw the positive reward graph
plt.plot(positive_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Positive Reward")
plt.title("Positive Reward vs Iteration")
plt.savefig("./positive_reward.png")
plt.show()

# draw the negative reward graph
plt.plot(negative_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Negative Reward")
plt.title("Negative Reward vs Iteration")

plt.savefig("./negative_reward.png")
plt.show()

# %%
# from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
# from stable_baselines3.common.vec_env import VecEnv
# import gymnasium as gym
# from imitation.policies.serialize import load_policy
# from imitation.util.util import make_vec_env
# import numpy as np
# import torch
# import os

# # 创建环境
# env = make_vec_env(
#     "seals:seals/Walker2d-v1",
#     rng=np.random.default_rng(),
#     n_envs=1,
#     env_make_kwargs={"render_mode": "rgb_array"},
# )

# # 使用 VecVideoRecorder 包装环境以启用视频记录，指定视频保存的路径
# video_folder = './videos'
# video_length = 200  # 设置视频长度
# env = VecVideoRecorder(env, video_folder,
#                        record_video_trigger=lambda step: step == 0, video_length=video_length,
#                        name_prefix="Walker2d-video")

# # 创建模型，这里以从 Hugging Face 加载预训练的 PPO 模型为例
# model = load_policy(
#     "ppo-huggingface",
#     organization="HumanCompatibleAI",
#     env_name="seals/Walker2d-v1",
#     venv=env,
# )

# # 训练模型
# # 注意: 此处假定模型已经预训练，无需再次训练

# # 测试模型，生成视频
# obs = env.reset()
# done = False
# while not done:
#     action, _states = model.predict(obs, deterministic=True)
#     obs, rewards, dones, info = env.step(action)
#     done = dones.any()

# env.close()

# # 如果需要手动保存视频（有时候视频不会在关闭时自动保存）
# env.record_video_trigger(video_length)
