# %%
import gymnasium as gym
import numpy as np
from stable_baselines3.common.env_util import make_vec_env as make_vec_env_sb3
from copy import deepcopy
import torch
from torch.distributions import Normal,MultivariateNormal
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.utils.data import Dataset, DataLoader
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
import imageio
import pandas as pd
from tqdm import tqdm
from PIL import Image
from stable_baselines3.dqn.policies import MlpPolicy
import matplotlib.pyplot as plt

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !nvidia-smi
# clean up memory forcefully
torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# Mon May 13 00:39:53 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  | 00000000:01:00.0 Off |                  N/A |
# | 17%   56C    P2              90W / 250W |   2894MiB / 11264MiB |     97%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    228304      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    229850      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    277377      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    280712      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    319688      C   ...iu/miniconda3/envs/myenv/bin/python      300MiB |
# |    0   N/A  N/A    328416      C   ...iu/miniconda3/envs/myenv/bin/python      204MiB |
# |    0   N/A  N/A    377684      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   1475780      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   2544023      C   ...u/miniconda3/envs/myenv2/bin/python      184MiB |
# |    0   N/A  N/A   2546464      C   ...u/miniconda3/envs/myenv2/bin/python      192MiB |
# |    0   N/A  N/A   2573624      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2573704      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2584185      C   ...181/miniconda3/envs/copy/bin/python      194MiB |
# |    0   N/A  N/A   2587146      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# +---------------------------------------------------------------------------------------+
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
class CustomDataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32,device=device)
        self.actions = torch.tensor(actions, dtype=torch.float32,device=device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, output_dim,init_w=3e-3,log_std_min=-20,log_std_max=2):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 32)


        self.fc2 = nn.Linear(32, 32)
        self.log_std = nn.Linear(32, output_dim)
        self.mu=nn.Linear(32,output_dim)
        self.log_std_min=log_std_min
        self.log_std_max=log_std_max
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        torch.nn.init.kaiming_normal_(self.fc2.weight)
        self.mu.weight.data.uniform_(-init_w,init_w)
        self.mu.bias.data.uniform_(-init_w,init_w)
        self.log_std.weight.data.uniform_(-init_w,init_w)
        self.log_std.bias.data.uniform_(-init_w,init_w)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = self.mu(x) # Only apply if action bounds are [-1, 1]
        log_std = self.log_std(x)  # Ensure std is positive
        log_std=torch.clamp(log_std,self.log_std_min,self.log_std_max)

        return mu, log_std
# Out:
# Using device: cuda

# %%
# from imitation.util.util import make_vec_env

# observations= np.load("../dataset/obs.npy", allow_pickle=True)
# actions = np.load("../dataset/actions.npy", allow_pickle=True)

# observations=observations.squeeze()
# actions=actions.squeeze()

# print(observations.shape, actions.shape)
# print(observations[0], actions[0])
import pickle
import numpy as np
#　read /mnt/nfs/work/c98181/TDIL/saved_expert_transition/Walker2d-v3/sac/episode_num1_6123.pkl
# "states", "actions", "rewards", "next_states", "dones".
with open("/mnt/nfs/work/c98181/TDIL/saved_expert_transition/Ant-v3/sac/episode_num1_8524.pkl", "rb") as f:
    data = pickle.load(f)

    obs_list = data["states"]
    actions_list = data["actions"]
    observations=np.array(obs_list)
    actions=np.array(actions_list)
    # shape
    print(observations.shape)
    print(actions.shape)

# env=gym.make("Walker2d-v3",exclude_current_positions_from_observation=False,render_mode="rgb_array")
env=gym.make("Ant-v3",render_mode="rgb_array")
# Out:
# (1000, 111)
# (1000, 8)
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Ant-v3 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_env.py:211: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(

# %%
class mydataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32).to(device)
        self.actions = torch.tensor(actions, dtype=torch.float32).to(device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

# %%
policy_network = PolicyNetwork(111,8).to(device)
prev = PolicyNetwork(111,8).to(device)
prev.load_state_dict(policy_network.state_dict())
prev.eval()

optimizer = torch.optim.Adam(policy_network.parameters(), lr=0.0003,weight_decay=1e-4)

# Training loop
num_epochs = 100
batch_size = 32

dataset = mydataset(observations=observations, actions=actions)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

loss_graph=[]
greedy_rewards=[]
sample_rewards=[]
margin_graph=[]
positive_reward_graph=[]
negative_reward_graph=[]
log_interval = len(observations)//1
num_test = 10
prev_load_freq = 32
now_log=0
now_pos=0
greedy_score=0
sample_score=0
for epoch in range(num_epochs):
    policy_network.train()

    # Compute the log probabilities of the actions
    pbar=tqdm(dataloader,position=0,leave=True)
    now_log=0

    for step, (obs_batch,act_batch) in enumerate(pbar):
        # obs_batch = torch.tensor(np.array(obs_batch), dtype=torch.float32).to(device)
        # act_batch = torch.tensor(np.array(act_batch), dtype=torch.float32).to(device)

        now_log+=obs_batch.shape[0]
        now_pos+=obs_batch.shape[0]
        
        mu, log_std = policy_network(obs_batch)
        std=log_std.exp()
        dist = Normal(mu, std)
        z_model=dist.rsample()
        model_action=torch.tanh(z_model)
        z_expert=torch.atanh(torch.clamp(act_batch, -0.999999, 0.999999))
        epsilon=1e-6


        policy_rejected_logps =dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
        policy_chosen_logps = dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        with torch.no_grad():
          prev_mu, prev_log_std = prev(obs_batch)
          prev_std=prev_log_std.exp()
          prev_dist = Normal(prev_mu, prev_std)

          reference_rejected_logps =prev_dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
          reference_chosen_logps = prev_dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        pi_logratios = policy_chosen_logps - policy_rejected_logps
        ref_logratios = reference_chosen_logps - reference_rejected_logps
        logits = pi_logratios - ref_logratios
        chosen_KL = (policy_chosen_logps - reference_chosen_logps).mean().clamp(min=0)
        reject_KL = (policy_rejected_logps - reference_rejected_logps).mean().clamp(min=0)

       

        chosen_logratios = policy_chosen_logps - reference_chosen_logps
        reject_logratios = policy_rejected_logps - reference_rejected_logps

        # logits = chosen_logratios - reject_logratios

        if epoch < -1:
          loss = - (policy_chosen_logps).mean()
        else:
          beta = 0.1
          losses=-F.logsigmoid(beta * logits)
          loss = losses.mean()
        #   losses = torch.cat((1 - F.logsigmoid(beta * (chosen_logratios - reject_KL)), 1 - F.logsigmoid(beta * (chosen_KL - reject_logratios))), 0)
        #   loss = losses.mean()
        # Optimize the policy
        optimizer.zero_grad()


        loss.backward()

        optimizer.step()
        pbar.set_description((f"Epoch [{epoch+1}/{num_epochs}]"))
        positive_reward = chosen_logratios.detach().mean().item()
        negative_reward = reject_logratios.detach().mean().item()
        margin = positive_reward - negative_reward
        loss_graph.append(loss.detach().item())
        margin_graph.append(margin)
        positive_reward_graph.append(positive_reward)
        negative_reward_graph.append(negative_reward)



        total_reward=0
        if now_log>=log_interval:
            now_log-=log_interval
            
            policy_network.eval()  # 切换到评估模式

            

            total_reward=0
            # test the policy and save as the first test as gif
            frames = []
            for _ in range(num_test):
                state,_ = env.reset()
                done = False

                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(mu)   
                        action.squeeze_()

                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/greedy/"+image_path, frames)

            greedy_score=total_reward/num_test
            total_reward=0
            frames = []
            # test the policy and save as the first test as gif
            for _ in range(num_test):
                state,_ = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(Normal(mu,std).sample())
                        action.squeeze_()
                       
                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/sample/"+image_path, frames)

            sample_score=total_reward/num_test
            greedy_rewards.append(greedy_score)
            sample_rewards.append(sample_score)
            policy_network.train()  # 切换回训练模式
        pbar.set_postfix({"loss":loss.detach().item(), "positive_reward": positive_reward, "negative_reward": negative_reward, "margin": positive_reward - negative_reward,"greedy_score":greedy_score,"sample_score":sample_score})
    prev.load_state_dict(policy_network.state_dict())
    prev.eval()
         

env.close()
# Out:
# Epoch [1/100]:  75%|███████▌  | 24/32 [00:00<00:00, 51.41it/s, loss=0.688, positive_reward=0.161, negative_reward=0.0594, margin=0.102, greedy_score=0, sample_score=0]     /tmp/ipykernel_2587643/4294611384.py:117: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025847094/work/torch/csrc/utils/tensor_new.cpp:275.)
#   state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
# Epoch [1/100]: 100%|██████████| 32/32 [00:32<00:00,  1.01s/it, loss=0.688, positive_reward=0.157, negative_reward=0.0456, margin=0.112, greedy_score=1e+3, sample_score=-357]
# Epoch [2/100]: 100%|██████████| 32/32 [00:34<00:00,  1.08s/it, loss=0.688, positive_reward=0.177, negative_reward=0.0737, margin=0.103, greedy_score=1e+3, sample_score=-261]
# Epoch [3/100]: 100%|██████████| 32/32 [00:36<00:00,  1.13s/it, loss=0.686, positive_reward=0.1, negative_reward=-.043, margin=0.143, greedy_score=1e+3, sample_score=-225]
# Epoch [4/100]: 100%|██████████| 32/32 [00:36<00:00,  1.14s/it, loss=0.691, positive_reward=0.0436, negative_reward=-7.36e-5, margin=0.0436, greedy_score=1e+3, sample_score=-200]
# Epoch [5/100]: 100%|██████████| 32/32 [00:36<00:00,  1.14s/it, loss=0.691, positive_reward=0.0356, negative_reward=-.000598, margin=0.0362, greedy_score=1e+3, sample_score=-184]
# Epoch [6/100]: 100%|██████████| 32/32 [00:35<00:00,  1.11s/it, loss=0.692, positive_reward=0.0263, negative_reward=0.00257, margin=0.0237, greedy_score=1e+3, sample_score=-195]
# Epoch [7/100]: 100%|██████████| 32/32 [00:35<00:00,  1.11s/it, loss=0.691, positive_reward=0.0339, negative_reward=-.0102, margin=0.0441, greedy_score=1e+3, sample_score=-161]
# Epoch [8/100]: 100%|██████████| 32/32 [00:28<00:00,  1.10it/s, loss=0.692, positive_reward=0.0095, negative_reward=-.00696, margin=0.0165, greedy_score=997, sample_score=-194]
# Epoch [9/100]: 100%|██████████| 32/32 [00:29<00:00,  1.09it/s, loss=0.692, positive_reward=0.0235, negative_reward=0.00156, margin=0.0219, greedy_score=1e+3, sample_score=-222]
# Epoch [10/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.692, positive_reward=0.016, negative_reward=0.000469, margin=0.0155, greedy_score=999, sample_score=-169]
# Epoch [11/100]: 100%|██████████| 32/32 [00:31<00:00,  1.01it/s, loss=0.692, positive_reward=0.0101, negative_reward=-.0145, margin=0.0246, greedy_score=1e+3, sample_score=-193]
# Epoch [12/100]: 100%|██████████| 32/32 [00:31<00:00,  1.02it/s, loss=0.693, positive_reward=0.00479, negative_reward=0.00877, margin=-.00398, greedy_score=998, sample_score=-203]
# Epoch [13/100]: 100%|██████████| 32/32 [00:34<00:00,  1.07s/it, loss=0.692, positive_reward=0.0153, negative_reward=-.0043, margin=0.0196, greedy_score=1e+3, sample_score=-217]
# Epoch [14/100]: 100%|██████████| 32/32 [00:35<00:00,  1.10s/it, loss=0.693, positive_reward=0.00602, negative_reward=0.00774, margin=-.00173, greedy_score=1e+3, sample_score=-200]
# Epoch [15/100]: 100%|██████████| 32/32 [00:34<00:00,  1.09s/it, loss=0.693, positive_reward=-.0025, negative_reward=-.00544, margin=0.00294, greedy_score=995, sample_score=-221]
# Epoch [16/100]: 100%|██████████| 32/32 [00:34<00:00,  1.08s/it, loss=0.693, positive_reward=0.00618, negative_reward=0.00605, margin=0.00013, greedy_score=1e+3, sample_score=-171]
# Epoch [17/100]: 100%|██████████| 32/32 [00:33<00:00,  1.04s/it, loss=0.694, positive_reward=-.00101, negative_reward=0.013, margin=-.014, greedy_score=996, sample_score=-165]
# Epoch [18/100]: 100%|██████████| 32/32 [00:32<00:00,  1.02s/it, loss=0.694, positive_reward=-.0068, negative_reward=0.00795, margin=-.0148, greedy_score=995, sample_score=-215]
# Epoch [19/100]: 100%|██████████| 32/32 [00:34<00:00,  1.07s/it, loss=0.693, positive_reward=0.00555, negative_reward=0.00204, margin=0.00351, greedy_score=996, sample_score=-173]
# Epoch [20/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.693, positive_reward=0.0102, negative_reward=0.0142, margin=-.004, greedy_score=994, sample_score=-192]
# Epoch [21/100]: 100%|██████████| 32/32 [00:29<00:00,  1.10it/s, loss=0.694, positive_reward=-.017, negative_reward=0.00318, margin=-.0202, greedy_score=994, sample_score=-214]
# Epoch [22/100]: 100%|██████████| 32/32 [00:27<00:00,  1.18it/s, loss=0.694, positive_reward=-.00889, negative_reward=0.00135, margin=-.0102, greedy_score=991, sample_score=-187]
# Epoch [23/100]: 100%|██████████| 32/32 [00:34<00:00,  1.08s/it, loss=0.694, positive_reward=-.00865, negative_reward=0.00347, margin=-.0121, greedy_score=996, sample_score=-193]
# Epoch [24/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.693, positive_reward=-.000967, negative_reward=0.00303, margin=-.004, greedy_score=995, sample_score=-201]
# Epoch [25/100]: 100%|██████████| 32/32 [00:33<00:00,  1.05s/it, loss=0.693, positive_reward=-.00959, negative_reward=-.0106, margin=0.00103, greedy_score=993, sample_score=-215]
# Epoch [26/100]: 100%|██████████| 32/32 [00:31<00:00,  1.03it/s, loss=0.694, positive_reward=-.0167, negative_reward=0.00427, margin=-.0209, greedy_score=994, sample_score=-220]
# Epoch [27/100]: 100%|██████████| 32/32 [00:32<00:00,  1.02s/it, loss=0.693, positive_reward=-.00254, negative_reward=0.00369, margin=-.00623, greedy_score=993, sample_score=-226]
# Epoch [28/100]: 100%|██████████| 32/32 [00:33<00:00,  1.06s/it, loss=0.693, positive_reward=0.00483, negative_reward=0.007, margin=-.00217, greedy_score=991, sample_score=-191]
# Epoch [29/100]: 100%|██████████| 32/32 [00:34<00:00,  1.06s/it, loss=0.694, positive_reward=-.00167, negative_reward=0.00871, margin=-.0104, greedy_score=996, sample_score=-222]
# Epoch [30/100]: 100%|██████████| 32/32 [00:29<00:00,  1.09it/s, loss=0.694, positive_reward=-.0106, negative_reward=0.00608, margin=-.0167, greedy_score=994, sample_score=-214]
# Epoch [31/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.693, positive_reward=0.02, negative_reward=0.00773, margin=0.0122, greedy_score=997, sample_score=-206]
# Epoch [32/100]: 100%|██████████| 32/32 [00:29<00:00,  1.10it/s, loss=0.693, positive_reward=-.00344, negative_reward=-.00914, margin=0.0057, greedy_score=996, sample_score=-222]
# Epoch [33/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.692, positive_reward=0.0208, negative_reward=0.0042, margin=0.0166, greedy_score=992, sample_score=-208]
# Epoch [34/100]: 100%|██████████| 32/32 [00:22<00:00,  1.41it/s, loss=0.694, positive_reward=-.00568, negative_reward=0.00682, margin=-.0125, greedy_score=994, sample_score=-233]
# Epoch [35/100]: 100%|██████████| 32/32 [00:24<00:00,  1.32it/s, loss=0.692, positive_reward=0.0152, negative_reward=-.00734, margin=0.0225, greedy_score=1e+3, sample_score=-208]
# Epoch [36/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.694, positive_reward=-.00143, negative_reward=0.00715, margin=-.00857, greedy_score=995, sample_score=-256]
# Epoch [37/100]: 100%|██████████| 32/32 [00:23<00:00,  1.37it/s, loss=0.693, positive_reward=-.0025, negative_reward=0.00163, margin=-.00413, greedy_score=991, sample_score=-246]
# Epoch [38/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.694, positive_reward=-.019, negative_reward=0.00422, margin=-.0232, greedy_score=998, sample_score=-236]
# Epoch [39/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.694, positive_reward=-.00423, negative_reward=0.0217, margin=-.0259, greedy_score=992, sample_score=-218]
# Epoch [40/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.693, positive_reward=0.00842, negative_reward=0.00383, margin=0.00459, greedy_score=990, sample_score=-241]
# Epoch [41/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.694, positive_reward=-.01, negative_reward=0.00802, margin=-.0181, greedy_score=992, sample_score=-218]
# Epoch [42/100]: 100%|██████████| 32/32 [00:29<00:00,  1.10it/s, loss=0.693, positive_reward=0.00815, negative_reward=0.00132, margin=0.00683, greedy_score=990, sample_score=-219]
# Epoch [43/100]: 100%|██████████| 32/32 [00:31<00:00,  1.03it/s, loss=0.694, positive_reward=-.0091, negative_reward=0.00444, margin=-.0135, greedy_score=999, sample_score=-208]
# Epoch [44/100]: 100%|██████████| 32/32 [00:31<00:00,  1.03it/s, loss=0.693, positive_reward=0.00527, negative_reward=-.00301, margin=0.00828, greedy_score=993, sample_score=-220]
# Epoch [45/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.693, positive_reward=-.00818, negative_reward=-.00223, margin=-.00595, greedy_score=994, sample_score=-209]
# Epoch [46/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.694, positive_reward=0.00168, negative_reward=0.0121, margin=-.0104, greedy_score=991, sample_score=-220]
# Epoch [47/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.692, positive_reward=0.00972, negative_reward=-.00381, margin=0.0135, greedy_score=993, sample_score=-200]
# Epoch [48/100]: 100%|██████████| 32/32 [00:31<00:00,  1.02it/s, loss=0.693, positive_reward=-.0081, negative_reward=-.00553, margin=-.00257, greedy_score=994, sample_score=-226]
# Epoch [49/100]: 100%|██████████| 32/32 [00:32<00:00,  1.02s/it, loss=0.693, positive_reward=0.00699, negative_reward=-.00569, margin=0.0127, greedy_score=987, sample_score=-234]
# Epoch [50/100]: 100%|██████████| 32/32 [00:33<00:00,  1.04s/it, loss=0.693, positive_reward=-.00651, negative_reward=-.00188, margin=-.00463, greedy_score=989, sample_score=-195]
# Epoch [51/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.693, positive_reward=-.00839, negative_reward=-.00191, margin=-.00648, greedy_score=989, sample_score=-236]
# Epoch [52/100]: 100%|██████████| 32/32 [00:38<00:00,  1.19s/it, loss=0.693, positive_reward=0.0106, negative_reward=0.000147, margin=0.0104, greedy_score=989, sample_score=-217]
# Epoch [53/100]: 100%|██████████| 32/32 [00:38<00:00,  1.22s/it, loss=0.694, positive_reward=-.0155, negative_reward=0.00737, margin=-.0229, greedy_score=991, sample_score=-216]
# Epoch [54/100]: 100%|██████████| 32/32 [00:38<00:00,  1.19s/it, loss=0.693, positive_reward=-.00831, negative_reward=-.00212, margin=-.0062, greedy_score=987, sample_score=-227]
# Epoch [55/100]: 100%|██████████| 32/32 [00:39<00:00,  1.23s/it, loss=0.692, positive_reward=0.00801, negative_reward=-.00548, margin=0.0135, greedy_score=986, sample_score=-217]
# Epoch [56/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.693, positive_reward=-.00719, negative_reward=-.00214, margin=-.00505, greedy_score=989, sample_score=-215]
# Epoch [57/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.693, positive_reward=0.0137, negative_reward=0.00374, margin=0.00995, greedy_score=992, sample_score=-178]
# Epoch [58/100]: 100%|██████████| 32/32 [00:38<00:00,  1.20s/it, loss=0.694, positive_reward=-.0146, negative_reward=0.00304, margin=-.0176, greedy_score=994, sample_score=-229]
# Epoch [59/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.693, positive_reward=0.00611, negative_reward=0.00879, margin=-.00268, greedy_score=997, sample_score=-230]
# Epoch [60/100]: 100%|██████████| 32/32 [00:40<00:00,  1.27s/it, loss=0.694, positive_reward=-.0183, negative_reward=-.00705, margin=-.0112, greedy_score=986, sample_score=-220]
# Epoch [61/100]: 100%|██████████| 32/32 [00:39<00:00,  1.24s/it, loss=0.694, positive_reward=-.0105, negative_reward=0.00377, margin=-.0143, greedy_score=986, sample_score=-231]
# Epoch [62/100]: 100%|██████████| 32/32 [00:38<00:00,  1.22s/it, loss=0.694, positive_reward=-.00512, negative_reward=0.0045, margin=-.00962, greedy_score=987, sample_score=-210]
# Epoch [63/100]: 100%|██████████| 32/32 [00:38<00:00,  1.22s/it, loss=0.693, positive_reward=-.00541, negative_reward=-.00537, margin=-4.02e-5, greedy_score=987, sample_score=-235]
# Epoch [64/100]: 100%|██████████| 32/32 [00:36<00:00,  1.14s/it, loss=0.694, positive_reward=0.00453, negative_reward=0.0187, margin=-.0142, greedy_score=986, sample_score=-207]
# Epoch [65/100]: 100%|██████████| 32/32 [00:39<00:00,  1.23s/it, loss=0.693, positive_reward=0.0109, negative_reward=0.00213, margin=0.00872, greedy_score=985, sample_score=-189]
# Epoch [66/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.693, positive_reward=0.00138, negative_reward=0.00382, margin=-.00244, greedy_score=988, sample_score=-205]
# Epoch [67/100]: 100%|██████████| 32/32 [00:37<00:00,  1.16s/it, loss=0.693, positive_reward=0.00365, negative_reward=-.00456, margin=0.00821, greedy_score=987, sample_score=-214]
# Epoch [68/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.694, positive_reward=-.0123, negative_reward=0.00124, margin=-.0136, greedy_score=988, sample_score=-223]
# Epoch [69/100]: 100%|██████████| 32/32 [00:37<00:00,  1.18s/it, loss=0.694, positive_reward=-.00988, negative_reward=0.0123, margin=-.0222, greedy_score=995, sample_score=-245]
# Epoch [70/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.691, positive_reward=0.0298, negative_reward=-.0049, margin=0.0347, greedy_score=991, sample_score=-228]
# Epoch [71/100]: 100%|██████████| 32/32 [00:39<00:00,  1.24s/it, loss=0.694, positive_reward=-.0112, negative_reward=0.00288, margin=-.0141, greedy_score=990, sample_score=-233]
# Epoch [72/100]: 100%|██████████| 32/32 [00:40<00:00,  1.25s/it, loss=0.694, positive_reward=0.000212, negative_reward=0.00929, margin=-.00908, greedy_score=986, sample_score=-227]
# Epoch [73/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.695, positive_reward=-.0203, negative_reward=0.0215, margin=-.0418, greedy_score=986, sample_score=-221]
# Epoch [74/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.693, positive_reward=0.00305, negative_reward=-.00226, margin=0.00531, greedy_score=984, sample_score=-216]
# Epoch [75/100]: 100%|██████████| 32/32 [00:39<00:00,  1.24s/it, loss=0.693, positive_reward=0.00766, negative_reward=0.00614, margin=0.00152, greedy_score=985, sample_score=-221]
# Epoch [76/100]: 100%|██████████| 32/32 [00:38<00:00,  1.20s/it, loss=0.694, positive_reward=-.0145, negative_reward=-.000417, margin=-.0141, greedy_score=986, sample_score=-207]
# Epoch [77/100]: 100%|██████████| 32/32 [00:36<00:00,  1.14s/it, loss=0.693, positive_reward=0.00352, negative_reward=0.0074, margin=-.00388, greedy_score=984, sample_score=-230]
# Epoch [78/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.693, positive_reward=-.00138, negative_reward=0.00377, margin=-.00514, greedy_score=986, sample_score=-203]
# Epoch [79/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.694, positive_reward=-.00756, negative_reward=0.00705, margin=-.0146, greedy_score=995, sample_score=-223]
# Epoch [80/100]: 100%|██████████| 32/32 [00:39<00:00,  1.25s/it, loss=0.694, positive_reward=0.00336, negative_reward=0.0105, margin=-.00711, greedy_score=984, sample_score=-216]
# Epoch [81/100]: 100%|██████████| 32/32 [00:41<00:00,  1.29s/it, loss=0.693, positive_reward=-.00353, negative_reward=-.00626, margin=0.00273, greedy_score=986, sample_score=-198]
# Epoch [82/100]: 100%|██████████| 32/32 [00:39<00:00,  1.24s/it, loss=0.693, positive_reward=-.00281, negative_reward=-.000111, margin=-.0027, greedy_score=987, sample_score=-205]
# Epoch [83/100]: 100%|██████████| 32/32 [00:37<00:00,  1.17s/it, loss=0.693, positive_reward=0.00679, negative_reward=0.00803, margin=-.00123, greedy_score=985, sample_score=-250]
# Epoch [84/100]: 100%|██████████| 32/32 [00:38<00:00,  1.19s/it, loss=0.694, positive_reward=-.0186, negative_reward=-.00275, margin=-.0158, greedy_score=984, sample_score=-227]
# Epoch [85/100]: 100%|██████████| 32/32 [00:38<00:00,  1.20s/it, loss=0.693, positive_reward=0.0125, negative_reward=0.0162, margin=-.00375, greedy_score=986, sample_score=-211]
# Epoch [86/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.694, positive_reward=-.0106, negative_reward=0.00645, margin=-.0171, greedy_score=985, sample_score=-202]
# Epoch [87/100]: 100%|██████████| 32/32 [00:40<00:00,  1.27s/it, loss=0.693, positive_reward=0.0127, negative_reward=0.0106, margin=0.00213, greedy_score=990, sample_score=-222]
# Epoch [88/100]: 100%|██████████| 32/32 [00:39<00:00,  1.24s/it, loss=0.694, positive_reward=-.00583, negative_reward=0.00442, margin=-.0102, greedy_score=983, sample_score=-219]
# Epoch [89/100]: 100%|██████████| 32/32 [00:36<00:00,  1.15s/it, loss=0.693, positive_reward=0.00213, negative_reward=0.00448, margin=-.00235, greedy_score=984, sample_score=-249]
# Epoch [90/100]: 100%|██████████| 32/32 [00:39<00:00,  1.23s/it, loss=0.693, positive_reward=0.00556, negative_reward=-.0031, margin=0.00866, greedy_score=984, sample_score=-236]
# Epoch [91/100]: 100%|██████████| 32/32 [00:40<00:00,  1.25s/it, loss=0.693, positive_reward=-.00787, negative_reward=-.01, margin=0.00215, greedy_score=989, sample_score=-196]
# Epoch [92/100]: 100%|██████████| 32/32 [00:39<00:00,  1.23s/it, loss=0.693, positive_reward=-.00116, negative_reward=0.0034, margin=-.00456, greedy_score=988, sample_score=-216]
# Epoch [93/100]: 100%|██████████| 32/32 [00:39<00:00,  1.22s/it, loss=0.694, positive_reward=-.00728, negative_reward=0.00322, margin=-.0105, greedy_score=986, sample_score=-204]
# Epoch [94/100]: 100%|██████████| 32/32 [00:38<00:00,  1.20s/it, loss=0.694, positive_reward=-.00714, negative_reward=0.00387, margin=-.011, greedy_score=987, sample_score=-233]
# Epoch [95/100]: 100%|██████████| 32/32 [00:38<00:00,  1.19s/it, loss=0.693, positive_reward=0.00471, negative_reward=0.00152, margin=0.00319, greedy_score=984, sample_score=-218]
# Epoch [96/100]: 100%|██████████| 32/32 [00:40<00:00,  1.26s/it, loss=0.694, positive_reward=-.00529, negative_reward=0.00516, margin=-.0104, greedy_score=985, sample_score=-214]
# Epoch [97/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.693, positive_reward=0.0118, negative_reward=0.0117, margin=0.000105, greedy_score=984, sample_score=-238]
# Epoch [98/100]: 100%|██████████| 32/32 [00:38<00:00,  1.21s/it, loss=0.693, positive_reward=-.000273, negative_reward=-.0022, margin=0.00193, greedy_score=986, sample_score=-229]
# Epoch [99/100]: 100%|██████████| 32/32 [00:39<00:00,  1.24s/it, loss=0.694, positive_reward=-.0182, negative_reward=0.00122, margin=-.0194, greedy_score=984, sample_score=-246]
# Epoch [100/100]: 100%|██████████| 32/32 [00:33<00:00,  1.04s/it, loss=0.693, positive_reward=0.00656, negative_reward=-.00338, margin=0.00994, greedy_score=987, sample_score=-262]

# %%
# save all png to /mnt/nfs/work/albertliu/RL/CartPole-v1/DPO

# draw the loss graph
import matplotlib.pyplot as plt
plt.plot(loss_graph)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss vs Iteration")
# plt.savefig("./loss.png")

plt.show()



# draw the reward graph
plt.plot(greedy_rewards)
plt.xlabel("Iteration")
plt.ylabel("Greedy Reward")
plt.title("Greedy Reward vs Iteration")
# plt.savefig("./greedy_reward.png")
plt.show()

# draw the reward graph
plt.plot(sample_rewards)
plt.xlabel("Iteration")
plt.ylabel("Sample Reward")
plt.title("Sample Reward vs Iteration")
# plt.savefig("./sample_reward.png")
plt.show()


# drqw the margin graph
plt.plot(margin_graph)
plt.xlabel("Iteration")
plt.ylabel("Margin")
plt.title("Margin vs Iteration")
# plt.savefig("./margin.png")
plt.show()

# draw the positive reward graph
plt.plot(positive_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Positive Reward")
plt.title("Positive Reward vs Iteration")
# plt.savefig("./positive_reward.png")
plt.show()

# draw the negative reward graph
plt.plot(negative_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Negative Reward")
# plt.title("Negative Reward vs Iteration")

plt.savefig("./negative_reward.png")
plt.show()

# %%
# from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
# from stable_baselines3.common.vec_env import VecEnv
# import gymnasium as gym
# from imitation.policies.serialize import load_policy
# from imitation.util.util import make_vec_env
# import numpy as np
# import torch
# import os

# # 创建环境
# env = make_vec_env(
#     "seals:seals/Walker2d-v1",
#     rng=np.random.default_rng(),
#     n_envs=1,
#     env_make_kwargs={"render_mode": "rgb_array"},
# )

# # 使用 VecVideoRecorder 包装环境以启用视频记录，指定视频保存的路径
# video_folder = './videos'
# video_length = 200  # 设置视频长度
# env = VecVideoRecorder(env, video_folder,
#                        record_video_trigger=lambda step: step == 0, video_length=video_length,
#                        name_prefix="Walker2d-video")

# # 创建模型，这里以从 Hugging Face 加载预训练的 PPO 模型为例
# model = load_policy(
#     "ppo-huggingface",
#     organization="HumanCompatibleAI",
#     env_name="seals/Walker2d-v1",
#     venv=env,
# )

# # 训练模型
# # 注意: 此处假定模型已经预训练，无需再次训练

# # 测试模型，生成视频
# obs = env.reset()
# done = False
# while not done:
#     action, _states = model.predict(obs, deterministic=True)
#     obs, rewards, dones, info = env.step(action)
#     done = dones.any()

# env.close()

# # 如果需要手动保存视频（有时候视频不会在关闭时自动保存）
# env.record_video_trigger(video_length)
