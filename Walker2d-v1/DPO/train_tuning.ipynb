# %%
import gymnasium as gym
import numpy as np
from stable_baselines3.common.env_util import make_vec_env as make_vec_env_sb3
from copy import deepcopy
import torch
from torch.distributions import Normal,MultivariateNormal
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.utils.data import Dataset, DataLoader
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
import imageio
import pandas as pd
from tqdm import tqdm
from PIL import Image
from stable_baselines3.dqn.policies import MlpPolicy
import matplotlib.pyplot as plt

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !nvidia-smi
# clean up memory forcefully
torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# Sun May  5 02:19:50 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  | 00000000:01:00.0 Off |                  N/A |
# | 14%   51C    P8              17W / 250W |   1236MiB / 11264MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    377684      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A    521631      C   build/xiangqi/minizero_xiangqi              844MiB |
# |    0   N/A  N/A   1475780      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# +---------------------------------------------------------------------------------------+
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
class CustomDataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32,device=device)
        self.actions = torch.tensor(actions, dtype=torch.float32,device=device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, output_dim,init_w=3e-3,log_std_min=-20,log_std_max=2):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 32)


        self.fc2 = nn.Linear(32, 32)
        self.log_std = nn.Linear(32, output_dim)
        self.mu=nn.Linear(32,output_dim)
        self.log_std_min=log_std_min
        self.log_std_max=log_std_max
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        torch.nn.init.kaiming_normal_(self.fc2.weight)
        self.mu.weight.data.uniform_(-init_w,init_w)
        self.mu.bias.data.uniform_(-init_w,init_w)
        self.log_std.weight.data.uniform_(-init_w,init_w)
        self.log_std.bias.data.uniform_(-init_w,init_w)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = self.mu(x) # Only apply if action bounds are [-1, 1]
        log_std = self.log_std(x)  # Ensure std is positive
        log_std=torch.clamp(log_std,self.log_std_min,self.log_std_max)

        return mu, log_std
# Out:
# Using device: cuda

# %%
from imitation.util.util import make_vec_env

observations= np.load("../dataset/obs.npy", allow_pickle=True)
actions = np.load("../dataset/actions.npy", allow_pickle=True)
observations=observations.squeeze()
actions=actions.squeeze()
env=gym.make("Walker2d-v3",exclude_current_positions_from_observation=False,render_mode="rgb_array")


# test policy
# done=False
# reward_sum = 0
# frames = []
# while not done:
#     action, _states = model.predict(obs, deterministic=True)
#     obs, reward,truncate,done, info = env.step(action)
#     reward_sum += reward
#     frames.append(env.render())
    
# print(reward_sum)
# imageio.mimsave(os.path.join(os.path.dirname(__file__),"walker2d.gif"), frames)
# Out:
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Walker2d-v3 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_env.py:211: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(

# %%
class mydataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32).to(device)
        self.actions = torch.tensor(actions, dtype=torch.float32).to(device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

# %%
policy_network = PolicyNetwork(18,6).to(device)
prev = PolicyNetwork(18,6).to(device)
prev.load_state_dict(policy_network.state_dict())
prev.eval()

optimizer = torch.optim.Adam(policy_network.parameters(), lr=3e-3,weight_decay=1e-4)

# Training loop
num_epochs = 100
batch_size = 32

dataset = mydataset(observations=observations, actions=actions)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

loss_graph=[]
greedy_rewards=[]
sample_rewards=[]
margin_graph=[]
positive_reward_graph=[]
negative_reward_graph=[]
log_interval = len(observations)//1
num_test = 1
prev_load_freq = 1000
now_log=0
now_pos=0
greedy_score=0
sample_score=0
for epoch in range(num_epochs):
    policy_network.train()

    # Compute the log probabilities of the actions
    pbar=tqdm(dataloader,position=0,leave=True)
    now_log=0

    for step, (obs_batch,act_batch) in enumerate(pbar):
        # obs_batch = torch.tensor(np.array(obs_batch), dtype=torch.float32).to(device)
        # act_batch = torch.tensor(np.array(act_batch), dtype=torch.float32).to(device)

        now_log+=obs_batch.shape[0]
        now_pos+=obs_batch.shape[0]
        
        mu, log_std = policy_network(obs_batch)
        std=log_std.exp()
        dist = Normal(mu, std)
        z_model=dist.rsample()
        model_action=torch.tanh(z_model)
        z_expert=torch.atanh(torch.clamp(act_batch, -0.999999, 0.999999))
        epsilon=1e-6


        policy_rejected_logps =dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
        policy_chosen_logps = dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        with torch.no_grad():
          prev_mu, prev_log_std = prev(obs_batch)
          prev_std=prev_log_std.exp()
          prev_dist = Normal(prev_mu, prev_std)

          reference_rejected_logps =prev_dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
          reference_chosen_logps = prev_dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        pi_logratios = policy_chosen_logps - policy_rejected_logps
        ref_logratios = reference_chosen_logps - reference_rejected_logps
        logits = pi_logratios - ref_logratios
        chosen_KL = (policy_chosen_logps - reference_chosen_logps).mean().clamp(min=0)
        reject_KL = (policy_rejected_logps - reference_rejected_logps).mean().clamp(min=0)

       

        chosen_logratios = policy_chosen_logps - reference_chosen_logps
        reject_logratios = policy_rejected_logps - reference_rejected_logps

        # logits = chosen_logratios - reject_logratios

        if epoch < -1:
          loss = - (policy_chosen_logps).mean()
        else:
          beta = 0.1
          losses=-F.logsigmoid(beta * logits)
          loss = losses.mean()
        #   losses = torch.cat((1 - F.logsigmoid(beta * (chosen_logratios - reject_KL)), 1 - F.logsigmoid(beta * (chosen_KL - reject_logratios))), 0)
        #   loss = losses.mean()
        # Optimize the policy
        optimizer.zero_grad()

        if (step+1) % prev_load_freq == 0:
            prev.load_state_dict(policy_network.state_dict())
            prev.eval()

        loss.backward()

        optimizer.step()
        pbar.set_description((f"Epoch [{epoch+1}/{num_epochs}]"))
        positive_reward = chosen_logratios.detach().mean().item()
        negative_reward = reject_logratios.detach().mean().item()
        margin = positive_reward - negative_reward
        loss_graph.append(loss.detach().item())
        margin_graph.append(margin)
        positive_reward_graph.append(positive_reward)
        negative_reward_graph.append(negative_reward)



        total_reward=0
        if now_log>=log_interval:
            now_log-=log_interval
            
            policy_network.eval()  # 切换到评估模式

            

            total_reward=0
            # test the policy and save as the first test as gif
            frames = []
            for _ in range(num_test):
                state,_ = env.reset()
                done = False

                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(mu)   
                        action.squeeze_()

                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/greedy/"+image_path, frames)

            greedy_score=total_reward/num_test
            total_reward=0
            frames = []
            # test the policy and save as the first test as gif
            for _ in range(num_test):
                state,_ = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(Normal(mu,std).sample())
                        action.squeeze_()
                       
                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/sample/"+image_path, frames)

            sample_score=total_reward/num_test
            greedy_rewards.append(greedy_score)
            sample_rewards.append(sample_score)
            policy_network.train()  # 切换回训练模式
        pbar.set_postfix({"loss":loss.detach().item(), "positive_reward": positive_reward, "negative_reward": negative_reward, "margin": positive_reward - negative_reward,"greedy_score":greedy_score,"sample_score":sample_score})

         

env.close()
# Out:
# Epoch [1/100]: 100%|█████████▉| 3118/3125 [00:17<00:00, 190.71it/s, loss=0.691, positive_reward=0.0359, negative_reward=-.00134, margin=0.0372, greedy_score=0, sample_score=0]    /tmp/ipykernel_3705241/3899842663.py:120: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025847094/work/torch/csrc/utils/tensor_new.cpp:275.)
#   state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
# Found 1 GPUs for rendering. Using device 0.
# Epoch [1/100]: 100%|██████████| 3125/3125 [00:21<00:00, 147.88it/s, loss=0.69, positive_reward=0.0496, negative_reward=-.00616, margin=0.0557, greedy_score=2.6e+3, sample_score=465]
# Epoch [2/100]: 100%|██████████| 3125/3125 [00:20<00:00, 148.94it/s, loss=0.698, positive_reward=-.0926, negative_reward=0.00196, margin=-.0946, greedy_score=1.28e+3, sample_score=486]
# Epoch [3/100]: 100%|██████████| 3125/3125 [00:20<00:00, 150.75it/s, loss=0.694, positive_reward=-.00152, negative_reward=0.00602, margin=-.00755, greedy_score=2.95e+3, sample_score=1.24e+3]
# Epoch [4/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.45it/s, loss=0.689, positive_reward=0.102, negative_reward=0.00692, margin=0.0948, greedy_score=2.84e+3, sample_score=379]
# Epoch [5/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.36it/s, loss=0.689, positive_reward=0.0861, negative_reward=-.00254, margin=0.0887, greedy_score=2.66e+3, sample_score=1.35e+3]
# Epoch [6/100]: 100%|██████████| 3125/3125 [00:21<00:00, 148.03it/s, loss=0.687, positive_reward=0.121, negative_reward=-.00172, margin=0.122, greedy_score=2.68e+3, sample_score=1.41e+3]
# Epoch [7/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.36it/s, loss=0.689, positive_reward=0.0966, negative_reward=0.0059, margin=0.0907, greedy_score=2.57e+3, sample_score=327]
# Epoch [8/100]: 100%|██████████| 3125/3125 [00:21<00:00, 148.76it/s, loss=0.693, positive_reward=0.0151, negative_reward=0.0166, margin=-.00157, greedy_score=2.86e+3, sample_score=336]
# Epoch [9/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.40it/s, loss=0.691, positive_reward=0.0318, negative_reward=-.0124, margin=0.0442, greedy_score=2.2e+3, sample_score=268]
# Epoch [10/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.41it/s, loss=0.698, positive_reward=-.0763, negative_reward=0.0161, margin=-.0924, greedy_score=2.59e+3, sample_score=492]
# Epoch [11/100]: 100%|██████████| 3125/3125 [00:20<00:00, 148.83it/s, loss=0.69, positive_reward=0.0642, negative_reward=0.00357, margin=0.0607, greedy_score=2.68e+3, sample_score=1.44e+3]
# Epoch [12/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.92it/s, loss=0.688, positive_reward=0.0854, negative_reward=-.00942, margin=0.0949, greedy_score=2.77e+3, sample_score=1.17e+3]
# Epoch [13/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.81it/s, loss=0.695, positive_reward=-.0265, negative_reward=0.00183, margin=-.0283, greedy_score=1.22e+3, sample_score=422]
# Epoch [14/100]: 100%|██████████| 3125/3125 [00:21<00:00, 147.71it/s, loss=0.699, positive_reward=-.0871, negative_reward=0.0169, margin=-.104, greedy_score=2.45e+3, sample_score=157]
# Epoch [15/100]: 100%|██████████| 3125/3125 [00:20<00:00, 150.89it/s, loss=0.692, positive_reward=0.0172, negative_reward=-.0112, margin=0.0284, greedy_score=2.82e+3, sample_score=158]
# Epoch [16/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.13it/s, loss=0.694, positive_reward=-.00357, negative_reward=0.0156, margin=-.0191, greedy_score=2.8e+3, sample_score=235]
# Epoch [17/100]: 100%|██████████| 3125/3125 [00:20<00:00, 150.77it/s, loss=0.696, positive_reward=-.0612, negative_reward=-.01, margin=-.0512, greedy_score=1.21e+3, sample_score=68.5]
# Epoch [18/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.59it/s, loss=0.699, positive_reward=-.107, negative_reward=0.0101, margin=-.117, greedy_score=2.57e+3, sample_score=1.38e+3]
# Epoch [19/100]: 100%|██████████| 3125/3125 [00:20<00:00, 150.46it/s, loss=0.693, positive_reward=0.027, negative_reward=0.0116, margin=0.0154, greedy_score=2.89e+3, sample_score=378]
# Epoch [20/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.26it/s, loss=0.691, positive_reward=0.0509, negative_reward=0.0152, margin=0.0356, greedy_score=2.86e+3, sample_score=243]
# Epoch [21/100]: 100%|██████████| 3125/3125 [00:20<00:00, 152.24it/s, loss=0.695, positive_reward=-.0235, negative_reward=0.00628, margin=-.0298, greedy_score=2.47e+3, sample_score=415]
# Epoch [22/100]: 100%|██████████| 3125/3125 [00:21<00:00, 147.03it/s, loss=0.693, positive_reward=0.0116, negative_reward=-.00178, margin=0.0134, greedy_score=3.03e+3, sample_score=337]
# Epoch [23/100]: 100%|██████████| 3125/3125 [00:20<00:00, 151.99it/s, loss=0.692, positive_reward=0.0518, negative_reward=0.0296, margin=0.0222, greedy_score=2.6e+3, sample_score=823]
# Epoch [24/100]: 100%|██████████| 3125/3125 [00:21<00:00, 147.82it/s, loss=0.693, positive_reward=0.0283, negative_reward=0.0163, margin=0.012, greedy_score=2.84e+3, sample_score=1.22e+3]
# Epoch [25/100]: 100%|██████████| 3125/3125 [00:20<00:00, 151.87it/s, loss=0.694, positive_reward=-.0153, negative_reward=-.00907, margin=-.00619, greedy_score=2.06e+3, sample_score=1.43e+3]
# Epoch [26/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.61it/s, loss=0.694, positive_reward=-.0196, negative_reward=0.000705, margin=-.0204, greedy_score=840, sample_score=459]
# Epoch [27/100]: 100%|██████████| 3125/3125 [00:20<00:00, 151.25it/s, loss=0.691, positive_reward=0.0355, negative_reward=-.0114, margin=0.0469, greedy_score=1.55e+3, sample_score=483]
# Epoch [28/100]: 100%|██████████| 3125/3125 [00:21<00:00, 147.37it/s, loss=0.697, positive_reward=-.0652, negative_reward=0.000791, margin=-.066, greedy_score=1.63e+3, sample_score=126]
# Epoch [29/100]: 100%|██████████| 3125/3125 [00:20<00:00, 151.99it/s, loss=0.69, positive_reward=0.0645, negative_reward=0.00751, margin=0.057, greedy_score=3.34e+3, sample_score=195]
# Epoch [30/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.94it/s, loss=0.693, positive_reward=0.00107, negative_reward=0.00651, margin=-.00544, greedy_score=2.58e+3, sample_score=357]
# Epoch [31/100]: 100%|██████████| 3125/3125 [00:20<00:00, 152.46it/s, loss=0.694, positive_reward=-.00333, negative_reward=0.0104, margin=-.0138, greedy_score=2.79e+3, sample_score=158]
# Epoch [32/100]: 100%|██████████| 3125/3125 [00:21<00:00, 145.74it/s, loss=0.696, positive_reward=-.0537, negative_reward=0.0049, margin=-.0586, greedy_score=2.66e+3, sample_score=448]
# Epoch [33/100]: 100%|██████████| 3125/3125 [00:20<00:00, 151.79it/s, loss=0.695, positive_reward=-.034, negative_reward=-.00437, margin=-.0297, greedy_score=1.37e+3, sample_score=1.25e+3]
# Epoch [34/100]: 100%|██████████| 3125/3125 [00:21<00:00, 147.34it/s, loss=0.692, positive_reward=0.0293, negative_reward=0.00398, margin=0.0253, greedy_score=2.74e+3, sample_score=169]
# Epoch [35/100]: 100%|██████████| 3125/3125 [00:20<00:00, 151.93it/s, loss=0.695, positive_reward=-.0442, negative_reward=-.00344, margin=-.0408, greedy_score=2.77e+3, sample_score=1.18e+3]
# Epoch [36/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.52it/s, loss=0.699, positive_reward=-.101, negative_reward=0.00662, margin=-.108, greedy_score=2.79e+3, sample_score=456]
# Epoch [37/100]: 100%|██████████| 3125/3125 [00:20<00:00, 150.97it/s, loss=0.693, positive_reward=-.00751, negative_reward=-.00379, margin=-.00372, greedy_score=2.9e+3, sample_score=340]
# Epoch [38/100]: 100%|██████████| 3125/3125 [00:21<00:00, 148.20it/s, loss=0.689, positive_reward=0.0924, negative_reward=0.00378, margin=0.0886, greedy_score=3.09e+3, sample_score=407]
# Epoch [39/100]: 100%|██████████| 3125/3125 [00:20<00:00, 151.11it/s, loss=0.693, positive_reward=0.00452, negative_reward=0.00709, margin=-.00256, greedy_score=3.11e+3, sample_score=1.3e+3]
# Epoch [40/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.58it/s, loss=0.694, positive_reward=-.0229, negative_reward=-.00622, margin=-.0167, greedy_score=3.18e+3, sample_score=1.29e+3]
# Epoch [41/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.91it/s, loss=0.693, positive_reward=0.0218, negative_reward=0.0215, margin=0.000267, greedy_score=2.63e+3, sample_score=279]
# Epoch [42/100]: 100%|██████████| 3125/3125 [00:21<00:00, 147.98it/s, loss=0.699, positive_reward=-.111, negative_reward=0.0067, margin=-.117, greedy_score=841, sample_score=528]
# Epoch [43/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.99it/s, loss=0.694, positive_reward=-.0154, negative_reward=-.00782, margin=-.00755, greedy_score=2.85e+3, sample_score=405]
# Epoch [44/100]: 100%|██████████| 3125/3125 [00:21<00:00, 148.73it/s, loss=0.691, positive_reward=0.0486, negative_reward=0.00559, margin=0.043, greedy_score=2.88e+3, sample_score=536]
# Epoch [45/100]: 100%|██████████| 3125/3125 [00:21<00:00, 148.50it/s, loss=0.695, positive_reward=-.0334, negative_reward=0.00377, margin=-.0372, greedy_score=2.75e+3, sample_score=287]
# Epoch [46/100]: 100%|██████████| 3125/3125 [00:21<00:00, 148.59it/s, loss=0.692, positive_reward=0.0352, negative_reward=0.014, margin=0.0212, greedy_score=2.73e+3, sample_score=283]
# Epoch [47/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.36it/s, loss=0.695, positive_reward=-.0271, negative_reward=0.000235, margin=-.0273, greedy_score=2.44e+3, sample_score=1.31e+3]
# Epoch [48/100]: 100%|██████████| 3125/3125 [00:21<00:00, 148.70it/s, loss=0.697, positive_reward=-.0588, negative_reward=0.00993, margin=-.0687, greedy_score=2.84e+3, sample_score=381]
# Epoch [49/100]: 100%|██████████| 3125/3125 [00:21<00:00, 148.18it/s, loss=0.694, positive_reward=-.0162, negative_reward=0.00902, margin=-.0252, greedy_score=840, sample_score=431]
# Epoch [50/100]: 100%|██████████| 3125/3125 [00:20<00:00, 148.92it/s, loss=0.697, positive_reward=-.0645, negative_reward=0.0155, margin=-.08, greedy_score=2.65e+3, sample_score=1.25e+3]
# Epoch [51/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.34it/s, loss=0.692, positive_reward=0.0275, negative_reward=0.00239, margin=0.0251, greedy_score=2.96e+3, sample_score=531]
# Epoch [52/100]: 100%|██████████| 3125/3125 [00:21<00:00, 148.65it/s, loss=0.693, positive_reward=0.0259, negative_reward=0.0119, margin=0.014, greedy_score=2.92e+3, sample_score=415]
# Epoch [53/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.38it/s, loss=0.695, positive_reward=-.0299, negative_reward=0.00125, margin=-.0312, greedy_score=2.9e+3, sample_score=214]
# Epoch [54/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.70it/s, loss=0.697, positive_reward=-.0659, negative_reward=-2.91e-5, margin=-.0659, greedy_score=2.95e+3, sample_score=1.11e+3]
# Epoch [55/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.81it/s, loss=0.687, positive_reward=0.118, negative_reward=-.0029, margin=0.121, greedy_score=3.39e+3, sample_score=639]
# Epoch [56/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.18it/s, loss=0.693, positive_reward=-.00669, negative_reward=-.00155, margin=-.00514, greedy_score=2.82e+3, sample_score=388]
# Epoch [57/100]: 100%|██████████| 3125/3125 [00:21<00:00, 147.78it/s, loss=0.69, positive_reward=0.0675, negative_reward=-.000121, margin=0.0676, greedy_score=2.9e+3, sample_score=884]
# Epoch [58/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.96it/s, loss=0.694, positive_reward=-.0107, negative_reward=0.000999, margin=-.0117, greedy_score=2.81e+3, sample_score=1.34e+3]
# Epoch [59/100]: 100%|██████████| 3125/3125 [00:21<00:00, 145.73it/s, loss=0.691, positive_reward=0.0632, negative_reward=0.00916, margin=0.0541, greedy_score=2.58e+3, sample_score=980]
# Epoch [60/100]: 100%|██████████| 3125/3125 [00:20<00:00, 150.19it/s, loss=0.694, positive_reward=-.00774, negative_reward=0.00485, margin=-.0126, greedy_score=1.26e+3, sample_score=267]
# Epoch [61/100]: 100%|██████████| 3125/3125 [00:21<00:00, 147.20it/s, loss=0.695, positive_reward=-.0421, negative_reward=-.00501, margin=-.0371, greedy_score=2.92e+3, sample_score=310]
# Epoch [62/100]: 100%|██████████| 3125/3125 [00:21<00:00, 148.27it/s, loss=0.7, positive_reward=-.104, negative_reward=0.0209, margin=-.125, greedy_score=1.38e+3, sample_score=809]
# Epoch [63/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.77it/s, loss=0.7, positive_reward=-.121, negative_reward=0.00296, margin=-.124, greedy_score=2.59e+3, sample_score=515]
# Epoch [64/100]: 100%|██████████| 3125/3125 [00:20<00:00, 150.67it/s, loss=0.693, positive_reward=0.017, negative_reward=0.0116, margin=0.00538, greedy_score=2.82e+3, sample_score=509]
# Epoch [65/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.50it/s, loss=0.698, positive_reward=-.0804, negative_reward=0.00997, margin=-.0904, greedy_score=2.59e+3, sample_score=465]
# Epoch [66/100]: 100%|██████████| 3125/3125 [00:20<00:00, 149.94it/s, loss=0.696, positive_reward=-.0492, negative_reward=0.00233, margin=-.0515, greedy_score=2.82e+3, sample_score=473]
# Epoch [67/100]: 100%|██████████| 3125/3125 [00:21<00:00, 146.76it/s, loss=0.694, positive_reward=-.00712, negative_reward=0.0169, margin=-.024, greedy_score=2.76e+3, sample_score=366]
# Epoch [68/100]: 100%|██████████| 3125/3125 [00:18<00:00, 172.20it/s, loss=0.694, positive_reward=-.00087, negative_reward=0.0172, margin=-.0181, greedy_score=2.54e+3, sample_score=594]
# Epoch [69/100]: 100%|██████████| 3125/3125 [00:17<00:00, 178.59it/s, loss=0.694, positive_reward=-.00957, negative_reward=0.00525, margin=-.0148, greedy_score=2.77e+3, sample_score=472]
# Epoch [70/100]: 100%|██████████| 3125/3125 [00:17<00:00, 178.75it/s, loss=0.698, positive_reward=-.0832, negative_reward=0.00751, margin=-.0907, greedy_score=2.76e+3, sample_score=574]
# Epoch [71/100]: 100%|██████████| 3125/3125 [00:17<00:00, 175.06it/s, loss=0.692, positive_reward=0.0319, negative_reward=0.000547, margin=0.0314, greedy_score=1.29e+3, sample_score=256]
# Epoch [72/100]: 100%|██████████| 3125/3125 [00:17<00:00, 176.52it/s, loss=0.693, positive_reward=0.0094, negative_reward=0.00432, margin=0.00508, greedy_score=2.37e+3, sample_score=1.34e+3]
# Epoch [73/100]: 100%|██████████| 3125/3125 [00:17<00:00, 178.37it/s, loss=0.694, positive_reward=-.0124, negative_reward=0.00189, margin=-.0143, greedy_score=2.48e+3, sample_score=349]
# Epoch [74/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.42it/s, loss=0.696, positive_reward=-.0374, negative_reward=0.0154, margin=-.0528, greedy_score=2.5e+3, sample_score=362]
# Epoch [75/100]: 100%|██████████| 3125/3125 [00:17<00:00, 178.64it/s, loss=0.695, positive_reward=-.0238, negative_reward=0.0107, margin=-.0345, greedy_score=2.6e+3, sample_score=1.33e+3]
# Epoch [76/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.67it/s, loss=0.696, positive_reward=-.0672, negative_reward=-.00609, margin=-.0611, greedy_score=840, sample_score=1.54e+3]
# Epoch [77/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.48it/s, loss=0.697, positive_reward=-.0679, negative_reward=0.00589, margin=-.0738, greedy_score=3.11e+3, sample_score=636]
# Epoch [78/100]: 100%|██████████| 3125/3125 [00:17<00:00, 176.64it/s, loss=0.695, positive_reward=-.0273, negative_reward=0.00775, margin=-.0351, greedy_score=2.77e+3, sample_score=239]
# Epoch [79/100]: 100%|██████████| 3125/3125 [00:17<00:00, 178.29it/s, loss=0.696, positive_reward=-.0575, negative_reward=0.00502, margin=-.0625, greedy_score=2.67e+3, sample_score=277]
# Epoch [80/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.84it/s, loss=0.696, positive_reward=-.0295, negative_reward=0.0168, margin=-.0463, greedy_score=2.93e+3, sample_score=313]
# Epoch [81/100]: 100%|██████████| 3125/3125 [00:17<00:00, 175.81it/s, loss=0.687, positive_reward=0.144, negative_reward=0.0125, margin=0.132, greedy_score=1.24e+3, sample_score=509]
# Epoch [82/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.25it/s, loss=0.693, positive_reward=4.06e-5, negative_reward=0.00372, margin=-.00368, greedy_score=840, sample_score=1.2e+3]
# Epoch [83/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.86it/s, loss=0.691, positive_reward=0.0642, negative_reward=0.0115, margin=0.0526, greedy_score=2.66e+3, sample_score=281]
# Epoch [84/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.28it/s, loss=0.695, positive_reward=-.034, negative_reward=0.00323, margin=-.0372, greedy_score=3.07e+3, sample_score=1.3e+3]
# Epoch [85/100]: 100%|██████████| 3125/3125 [00:17<00:00, 178.62it/s, loss=0.692, positive_reward=0.0398, negative_reward=0.014, margin=0.0258, greedy_score=2.96e+3, sample_score=408]
# Epoch [86/100]: 100%|██████████| 3125/3125 [00:17<00:00, 178.13it/s, loss=0.693, positive_reward=0.0141, negative_reward=-.000537, margin=0.0146, greedy_score=2.74e+3, sample_score=1.19e+3]
# Epoch [87/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.52it/s, loss=0.695, positive_reward=-.0281, negative_reward=0.0084, margin=-.0365, greedy_score=3e+3, sample_score=272]
# Epoch [88/100]: 100%|██████████| 3125/3125 [00:17<00:00, 178.51it/s, loss=0.692, positive_reward=0.0177, negative_reward=-.00358, margin=0.0213, greedy_score=2.84e+3, sample_score=300]
# Epoch [89/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.83it/s, loss=0.689, positive_reward=0.0939, negative_reward=0.00717, margin=0.0867, greedy_score=2.61e+3, sample_score=412]
# Epoch [90/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.75it/s, loss=0.691, positive_reward=0.0451, negative_reward=-.000194, margin=0.0453, greedy_score=2.34e+3, sample_score=265]
# Epoch [91/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.84it/s, loss=0.691, positive_reward=0.0395, negative_reward=0.00392, margin=0.0356, greedy_score=2.69e+3, sample_score=354]
# Epoch [92/100]: 100%|██████████| 3125/3125 [00:17<00:00, 175.96it/s, loss=0.695, positive_reward=-.0245, negative_reward=0.00751, margin=-.032, greedy_score=2.52e+3, sample_score=392]
# Epoch [93/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.96it/s, loss=0.69, positive_reward=0.0816, negative_reward=0.0166, margin=0.065, greedy_score=2.47e+3, sample_score=350]
# Epoch [94/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.19it/s, loss=0.693, positive_reward=0.0167, negative_reward=0.00323, margin=0.0135, greedy_score=840, sample_score=405]
# Epoch [95/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.83it/s, loss=0.692, positive_reward=0.024, negative_reward=-.00263, margin=0.0266, greedy_score=2.09e+3, sample_score=313]
# Epoch [96/100]: 100%|██████████| 3125/3125 [00:17<00:00, 178.48it/s, loss=0.688, positive_reward=0.111, negative_reward=0.000546, margin=0.11, greedy_score=2.77e+3, sample_score=460]
# Epoch [97/100]: 100%|██████████| 3125/3125 [00:17<00:00, 178.01it/s, loss=0.694, positive_reward=-.00776, negative_reward=0.0126, margin=-.0204, greedy_score=2.86e+3, sample_score=279]
# Epoch [98/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.81it/s, loss=0.691, positive_reward=0.0441, negative_reward=-.00613, margin=0.0502, greedy_score=3.01e+3, sample_score=196]
# Epoch [99/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.73it/s, loss=0.696, positive_reward=-.0489, negative_reward=0.00954, margin=-.0584, greedy_score=2.7e+3, sample_score=1.19e+3]
# Epoch [100/100]: 100%|██████████| 3125/3125 [00:17<00:00, 177.94it/s, loss=0.692, positive_reward=0.0429, negative_reward=0.0115, margin=0.0313, greedy_score=2.82e+3, sample_score=422]

# %%
# save all png to /mnt/nfs/work/albertliu/RL/CartPole-v1/DPO

# draw the loss graph
import matplotlib.pyplot as plt
plt.plot(loss_graph)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss vs Iteration")
# plt.savefig("./loss.png")

plt.show()



# draw the reward graph
plt.plot(greedy_rewards)
plt.xlabel("Iteration")
plt.ylabel("Greedy Reward")
plt.title("Greedy Reward vs Iteration")
# plt.savefig("./greedy_reward.png")
plt.show()

# draw the reward graph
plt.plot(sample_rewards)
plt.xlabel("Iteration")
plt.ylabel("Sample Reward")
plt.title("Sample Reward vs Iteration")
# plt.savefig("./sample_reward.png")
plt.show()


# drqw the margin graph
plt.plot(margin_graph)
plt.xlabel("Iteration")
plt.ylabel("Margin")
plt.title("Margin vs Iteration")
# plt.savefig("./margin.png")
plt.show()

# draw the positive reward graph
plt.plot(positive_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Positive Reward")
plt.title("Positive Reward vs Iteration")
# plt.savefig("./positive_reward.png")
plt.show()

# draw the negative reward graph
plt.plot(negative_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Negative Reward")
# plt.title("Negative Reward vs Iteration")

plt.savefig("./negative_reward.png")
plt.show()

# %%
# from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
# from stable_baselines3.common.vec_env import VecEnv
# import gymnasium as gym
# from imitation.policies.serialize import load_policy
# from imitation.util.util import make_vec_env
# import numpy as np
# import torch
# import os

# # 创建环境
# env = make_vec_env(
#     "seals:seals/Walker2d-v1",
#     rng=np.random.default_rng(),
#     n_envs=1,
#     env_make_kwargs={"render_mode": "rgb_array"},
# )

# # 使用 VecVideoRecorder 包装环境以启用视频记录，指定视频保存的路径
# video_folder = './videos'
# video_length = 200  # 设置视频长度
# env = VecVideoRecorder(env, video_folder,
#                        record_video_trigger=lambda step: step == 0, video_length=video_length,
#                        name_prefix="Walker2d-video")

# # 创建模型，这里以从 Hugging Face 加载预训练的 PPO 模型为例
# model = load_policy(
#     "ppo-huggingface",
#     organization="HumanCompatibleAI",
#     env_name="seals/Walker2d-v1",
#     venv=env,
# )

# # 训练模型
# # 注意: 此处假定模型已经预训练，无需再次训练

# # 测试模型，生成视频
# obs = env.reset()
# done = False
# while not done:
#     action, _states = model.predict(obs, deterministic=True)
#     obs, rewards, dones, info = env.step(action)
#     done = dones.any()

# env.close()

# # 如果需要手动保存视频（有时候视频不会在关闭时自动保存）
# env.record_video_trigger(video_length)
