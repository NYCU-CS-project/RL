# %%
import gymnasium as gym
import numpy as np
from stable_baselines3.common.env_util import make_vec_env as make_vec_env_sb3
from copy import deepcopy
import torch
from torch.distributions import Normal,MultivariateNormal
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.utils.data import Dataset, DataLoader
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
import imageio
import pandas as pd
from tqdm import tqdm
from PIL import Image
from stable_baselines3.dqn.policies import MlpPolicy
import matplotlib.pyplot as plt

# %%
import gc
gc.collect()
# Out:
# 1399

# %%
# !nvidia-smi
# clean up memory forcefully
torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# Fri May 10 17:05:37 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  | 00000000:01:00.0 Off |                  N/A |
# |  0%   47C    P2              56W / 250W |   2348MiB / 11264MiB |      5%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    228304      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    229850      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    277377      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    280712      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    319688      C   ...iu/miniconda3/envs/myenv/bin/python      300MiB |
# |    0   N/A  N/A    328416      C   ...iu/miniconda3/envs/myenv/bin/python      204MiB |
# |    0   N/A  N/A    352630    C+G   ...181/miniconda3/envs/copy/bin/python      217MiB |
# |    0   N/A  N/A    358431      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A    377684      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A    429052      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   1475780      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# +---------------------------------------------------------------------------------------+
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
class CustomDataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32,device=device)
        self.actions = torch.tensor(actions, dtype=torch.float32,device=device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, output_dim,init_w=3e-3,log_std_min=-20,log_std_max=2):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 32)


        self.fc2 = nn.Linear(32, 32)
        self.log_std = nn.Linear(32, output_dim)
        self.mu=nn.Linear(32,output_dim)
        self.log_std_min=log_std_min
        self.log_std_max=log_std_max
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        torch.nn.init.kaiming_normal_(self.fc2.weight)
        self.mu.weight.data.uniform_(-init_w,init_w)
        self.mu.bias.data.uniform_(-init_w,init_w)
        self.log_std.weight.data.uniform_(-init_w,init_w)
        self.log_std.bias.data.uniform_(-init_w,init_w)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = self.mu(x) # Only apply if action bounds are [-1, 1]
        log_std = self.log_std(x)  # Ensure std is positive
        log_std=torch.clamp(log_std,self.log_std_min,self.log_std_max)

        return mu, log_std
# Out:
# Using device: cuda

# %%
# from imitation.util.util import make_vec_env

# observations= np.load("../dataset/obs.npy", allow_pickle=True)
# actions = np.load("../dataset/actions.npy", allow_pickle=True)

# observations=observations.squeeze()
# actions=actions.squeeze()

# print(observations.shape, actions.shape)
# print(observations[0], actions[0])
import pickle
import numpy as np
#　read /mnt/nfs/work/c98181/TDIL/saved_expert_transition/Walker2d-v3/sac/episode_num1_6123.pkl
# "states", "actions", "rewards", "next_states", "dones".
with open("/mnt/nfs/work/c98181/TDIL/saved_expert_transition/Walker2d-v3/sac/episode_num1_6123.pkl", "rb") as f:
    data = pickle.load(f)

    obs_list = data["states"]
    actions_list = data["actions"]
    observations=np.array(obs_list)
    actions=np.array(actions_list)
    # shape
    print(observations.shape)
    print(actions.shape)

# env=gym.make("Walker2d-v3",exclude_current_positions_from_observation=False,render_mode="rgb_array")
env=gym.make("Walker2d-v3",render_mode="rgb_array")
# Out:
# (1000, 17)
# (1000, 6)
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Walker2d-v3 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_env.py:211: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(

# %%
class mydataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32).to(device)
        self.actions = torch.tensor(actions, dtype=torch.float32).to(device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

# %%
policy_network = PolicyNetwork(17,6).to(device)
prev = PolicyNetwork(17,6).to(device)
prev.load_state_dict(policy_network.state_dict())
prev.eval()

optimizer = torch.optim.Adam(policy_network.parameters(), lr=0.0003,weight_decay=1e-4)

# Training loop
num_epochs = 100
batch_size = 32

dataset = mydataset(observations=observations, actions=actions)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

loss_graph=[]
greedy_rewards=[]
sample_rewards=[]
margin_graph=[]
positive_reward_graph=[]
negative_reward_graph=[]
log_interval = len(observations)//1
num_test = 10
prev_load_freq = 32
now_log=0
now_pos=0
greedy_score=0
sample_score=0
for epoch in range(num_epochs):
    policy_network.train()

    # Compute the log probabilities of the actions
    pbar=tqdm(dataloader,position=0,leave=True)
    now_log=0

    for step, (obs_batch,act_batch) in enumerate(pbar):
        # obs_batch = torch.tensor(np.array(obs_batch), dtype=torch.float32).to(device)
        # act_batch = torch.tensor(np.array(act_batch), dtype=torch.float32).to(device)

        now_log+=obs_batch.shape[0]
        now_pos+=obs_batch.shape[0]
        
        mu, log_std = policy_network(obs_batch)
        std=log_std.exp()
        dist = Normal(mu, std)
        z_model=dist.rsample()
        model_action=torch.tanh(z_model)
        z_expert=torch.atanh(torch.clamp(act_batch, -0.999999, 0.999999))
        epsilon=1e-6


        policy_rejected_logps =dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
        policy_chosen_logps = dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        with torch.no_grad():
          prev_mu, prev_log_std = prev(obs_batch)
          prev_std=prev_log_std.exp()
          prev_dist = Normal(prev_mu, prev_std)

          reference_rejected_logps =prev_dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
          reference_chosen_logps = prev_dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        pi_logratios = policy_chosen_logps - policy_rejected_logps
        ref_logratios = reference_chosen_logps - reference_rejected_logps
        logits = pi_logratios - ref_logratios
        chosen_KL = (policy_chosen_logps - reference_chosen_logps).mean().clamp(min=0)
        reject_KL = (policy_rejected_logps - reference_rejected_logps).mean().clamp(min=0)

       

        chosen_logratios = policy_chosen_logps - reference_chosen_logps
        reject_logratios = policy_rejected_logps - reference_rejected_logps

        # logits = chosen_logratios - reject_logratios

        if epoch < -1:
          loss = - (policy_chosen_logps).mean()
        else:
          beta = 0.1
          losses=-F.logsigmoid(beta * logits)
          loss = losses.mean()
        #   losses = torch.cat((1 - F.logsigmoid(beta * (chosen_logratios - reject_KL)), 1 - F.logsigmoid(beta * (chosen_KL - reject_logratios))), 0)
        #   loss = losses.mean()
        # Optimize the policy
        optimizer.zero_grad()


        loss.backward()

        optimizer.step()
        pbar.set_description((f"Epoch [{epoch+1}/{num_epochs}]"))
        positive_reward = pi_logratios.detach().mean().item()
        negative_reward = ref_logratios.detach().mean().item()
        margin = positive_reward - negative_reward
        loss_graph.append(loss.detach().item())
        margin_graph.append(margin)
        positive_reward_graph.append(positive_reward)
        negative_reward_graph.append(negative_reward)



        total_reward=0
        if now_log>=log_interval:
            now_log-=log_interval
            
            policy_network.eval()  # 切换到评估模式

            

            total_reward=0
            # test the policy and save as the first test as gif
            frames = []
            for _ in range(num_test):
                state,_ = env.reset()
                done = False

                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(mu)   
                        action.squeeze_()

                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/greedy/"+image_path, frames)

            greedy_score=total_reward/num_test
            total_reward=0
            frames = []
            # test the policy and save as the first test as gif
            for _ in range(num_test):
                state,_ = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(Normal(mu,std).sample())
                        action.squeeze_()
                       
                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/sample/"+image_path, frames)

            sample_score=total_reward/num_test
            greedy_rewards.append(greedy_score)
            sample_rewards.append(sample_score)
            policy_network.train()  # 切换回训练模式
        pbar.set_postfix({"loss":loss.detach().item(), "positive_reward": positive_reward, "negative_reward": negative_reward, "margin": positive_reward - negative_reward,"greedy_score":greedy_score,"sample_score":sample_score})
    prev.load_state_dict(policy_network.state_dict())
    prev.eval()
         

env.close()
# Out:
# Epoch [1/100]: 100%|██████████| 32/32 [00:12<00:00,  2.50it/s, loss=0.67, positive_reward=0.484, negative_reward=0.0592, margin=0.425, greedy_score=937, sample_score=649]
# Epoch [2/100]: 100%|██████████| 32/32 [00:12<00:00,  2.55it/s, loss=0.675, positive_reward=0.38, negative_reward=0.0555, margin=0.325, greedy_score=841, sample_score=672]
# Epoch [3/100]: 100%|██████████| 32/32 [00:12<00:00,  2.54it/s, loss=0.669, positive_reward=0.514, negative_reward=0.0816, margin=0.432, greedy_score=841, sample_score=603]
# Epoch [4/100]: 100%|██████████| 32/32 [00:12<00:00,  2.52it/s, loss=0.682, positive_reward=0.232, negative_reward=0.0511, margin=0.181, greedy_score=839, sample_score=650]
# Epoch [5/100]: 100%|██████████| 32/32 [00:12<00:00,  2.51it/s, loss=0.673, positive_reward=0.427, negative_reward=0.103, margin=0.324, greedy_score=872, sample_score=746]
# Epoch [6/100]: 100%|██████████| 32/32 [00:12<00:00,  2.50it/s, loss=0.677, positive_reward=0.339, negative_reward=0.0561, margin=0.283, greedy_score=955, sample_score=539]
# Epoch [7/100]: 100%|██████████| 32/32 [00:12<00:00,  2.48it/s, loss=0.67, positive_reward=0.494, negative_reward=0.152, margin=0.341, greedy_score=1.1e+3, sample_score=624]
# Epoch [8/100]: 100%|██████████| 32/32 [00:12<00:00,  2.53it/s, loss=0.675, positive_reward=0.374, negative_reward=0.0287, margin=0.345, greedy_score=808, sample_score=693]
# Epoch [9/100]: 100%|██████████| 32/32 [00:12<00:00,  2.50it/s, loss=0.674, positive_reward=0.403, negative_reward=0.111, margin=0.292, greedy_score=935, sample_score=568]
# Epoch [10/100]: 100%|██████████| 32/32 [00:12<00:00,  2.51it/s, loss=0.676, positive_reward=0.355, negative_reward=0.0793, margin=0.275, greedy_score=808, sample_score=671]
# Epoch [11/100]: 100%|██████████| 32/32 [00:12<00:00,  2.48it/s, loss=0.676, positive_reward=0.35, negative_reward=0.000439, margin=0.35, greedy_score=1.14e+3, sample_score=619]
# Epoch [12/100]: 100%|██████████| 32/32 [00:12<00:00,  2.48it/s, loss=0.675, positive_reward=0.372, negative_reward=0.0143, margin=0.358, greedy_score=1.11e+3, sample_score=658]
# Epoch [13/100]: 100%|██████████| 32/32 [00:12<00:00,  2.48it/s, loss=0.671, positive_reward=0.473, negative_reward=0.107, margin=0.366, greedy_score=1.11e+3, sample_score=691]
# Epoch [14/100]: 100%|██████████| 32/32 [00:12<00:00,  2.54it/s, loss=0.676, positive_reward=0.361, negative_reward=0.036, margin=0.325, greedy_score=902, sample_score=611]
# Epoch [15/100]: 100%|██████████| 32/32 [00:12<00:00,  2.51it/s, loss=0.676, positive_reward=0.362, negative_reward=0.115, margin=0.247, greedy_score=872, sample_score=526]
# Epoch [16/100]: 100%|██████████| 32/32 [00:12<00:00,  2.52it/s, loss=0.681, positive_reward=0.249, negative_reward=-.0319, margin=0.28, greedy_score=907, sample_score=584]
# Epoch [17/100]: 100%|██████████| 32/32 [00:12<00:00,  2.54it/s, loss=0.673, positive_reward=0.429, negative_reward=0.116, margin=0.313, greedy_score=867, sample_score=619]
# Epoch [18/100]: 100%|██████████| 32/32 [00:12<00:00,  2.51it/s, loss=0.676, positive_reward=0.352, negative_reward=0.143, margin=0.209, greedy_score=1.15e+3, sample_score=565]
# Epoch [19/100]: 100%|██████████| 32/32 [00:12<00:00,  2.52it/s, loss=0.675, positive_reward=0.388, negative_reward=0.0708, margin=0.318, greedy_score=1.14e+3, sample_score=640]
# Epoch [20/100]: 100%|██████████| 32/32 [00:12<00:00,  2.50it/s, loss=0.665, positive_reward=0.588, negative_reward=0.171, margin=0.417, greedy_score=1.14e+3, sample_score=536]
# Epoch [21/100]: 100%|██████████| 32/32 [00:12<00:00,  2.53it/s, loss=0.672, positive_reward=0.447, negative_reward=0.0306, margin=0.416, greedy_score=1.07e+3, sample_score=553]
# Epoch [22/100]: 100%|██████████| 32/32 [00:12<00:00,  2.57it/s, loss=0.676, positive_reward=0.362, negative_reward=0.0567, margin=0.305, greedy_score=909, sample_score=555]
# Epoch [23/100]: 100%|██████████| 32/32 [00:12<00:00,  2.59it/s, loss=0.663, positive_reward=0.637, negative_reward=0.136, margin=0.501, greedy_score=875, sample_score=577]
# Epoch [24/100]: 100%|██████████| 32/32 [00:12<00:00,  2.56it/s, loss=0.677, positive_reward=0.335, negative_reward=0.0144, margin=0.32, greedy_score=1.01e+3, sample_score=595]
# Epoch [25/100]: 100%|██████████| 32/32 [00:12<00:00,  2.57it/s, loss=0.676, positive_reward=0.356, negative_reward=0.0978, margin=0.258, greedy_score=871, sample_score=560]
# Epoch [26/100]: 100%|██████████| 32/32 [00:12<00:00,  2.53it/s, loss=0.668, positive_reward=0.538, negative_reward=0.0666, margin=0.471, greedy_score=1.14e+3, sample_score=715]
# Epoch [27/100]: 100%|██████████| 32/32 [00:12<00:00,  2.55it/s, loss=0.665, positive_reward=0.593, negative_reward=0.0602, margin=0.533, greedy_score=1.11e+3, sample_score=577]
# Epoch [28/100]: 100%|██████████| 32/32 [00:12<00:00,  2.59it/s, loss=0.675, positive_reward=0.386, negative_reward=0.145, margin=0.242, greedy_score=1.01e+3, sample_score=577]
# Epoch [29/100]: 100%|██████████| 32/32 [00:12<00:00,  2.57it/s, loss=0.673, positive_reward=0.412, negative_reward=0.129, margin=0.283, greedy_score=1.04e+3, sample_score=568]
# Epoch [30/100]: 100%|██████████| 32/32 [00:12<00:00,  2.54it/s, loss=0.657, positive_reward=0.759, negative_reward=0.082, margin=0.677, greedy_score=1.17e+3, sample_score=574]
# Epoch [31/100]: 100%|██████████| 32/32 [00:12<00:00,  2.59it/s, loss=0.663, positive_reward=0.628, negative_reward=0.0861, margin=0.542, greedy_score=1.04e+3, sample_score=579]
# Epoch [32/100]: 100%|██████████| 32/32 [00:12<00:00,  2.59it/s, loss=0.676, positive_reward=0.355, negative_reward=0.131, margin=0.223, greedy_score=904, sample_score=557]
# Epoch [33/100]: 100%|██████████| 32/32 [00:12<00:00,  2.57it/s, loss=0.668, positive_reward=0.528, negative_reward=0.125, margin=0.403, greedy_score=1.11e+3, sample_score=559]
# Epoch [34/100]: 100%|██████████| 32/32 [00:12<00:00,  2.51it/s, loss=0.681, positive_reward=0.263, negative_reward=0.0514, margin=0.211, greedy_score=1.17e+3, sample_score=569]
# Epoch [35/100]: 100%|██████████| 32/32 [00:12<00:00,  2.53it/s, loss=0.659, positive_reward=0.717, negative_reward=0.0801, margin=0.637, greedy_score=1.11e+3, sample_score=579]
# Epoch [36/100]: 100%|██████████| 32/32 [00:12<00:00,  2.54it/s, loss=0.663, positive_reward=0.635, negative_reward=0.148, margin=0.487, greedy_score=1.17e+3, sample_score=568]
# Epoch [37/100]: 100%|██████████| 32/32 [00:12<00:00,  2.59it/s, loss=0.668, positive_reward=0.522, negative_reward=0.134, margin=0.388, greedy_score=966, sample_score=584]
# Epoch [38/100]: 100%|██████████| 32/32 [00:12<00:00,  2.55it/s, loss=0.676, positive_reward=0.372, negative_reward=-.0304, margin=0.403, greedy_score=1.17e+3, sample_score=556]
# Epoch [39/100]: 100%|██████████| 32/32 [00:12<00:00,  2.54it/s, loss=0.669, positive_reward=0.511, negative_reward=0.0929, margin=0.418, greedy_score=1.17e+3, sample_score=556]
# Epoch [40/100]: 100%|██████████| 32/32 [00:12<00:00,  2.54it/s, loss=0.67, positive_reward=0.474, negative_reward=0.05, margin=0.424, greedy_score=1.17e+3, sample_score=626]
# Epoch [41/100]: 100%|██████████| 32/32 [00:12<00:00,  2.52it/s, loss=0.66, positive_reward=0.688, negative_reward=0.0785, margin=0.609, greedy_score=1.17e+3, sample_score=603]
# Epoch [42/100]: 100%|██████████| 32/32 [00:12<00:00,  2.50it/s, loss=0.654, positive_reward=0.831, negative_reward=0.0734, margin=0.758, greedy_score=1.17e+3, sample_score=667]
# Epoch [43/100]: 100%|██████████| 32/32 [00:12<00:00,  2.55it/s, loss=0.669, positive_reward=0.51, negative_reward=0.0704, margin=0.44, greedy_score=1.17e+3, sample_score=526]
# Epoch [44/100]: 100%|██████████| 32/32 [00:12<00:00,  2.57it/s, loss=0.67, positive_reward=0.488, negative_reward=0.147, margin=0.341, greedy_score=1.17e+3, sample_score=573]
# Epoch [45/100]: 100%|██████████| 32/32 [00:12<00:00,  2.59it/s, loss=0.679, positive_reward=0.299, negative_reward=0.0646, margin=0.234, greedy_score=1.18e+3, sample_score=524]
# Epoch [46/100]: 100%|██████████| 32/32 [00:12<00:00,  2.59it/s, loss=0.673, positive_reward=0.431, negative_reward=0.0844, margin=0.346, greedy_score=1.14e+3, sample_score=641]
# Epoch [47/100]: 100%|██████████| 32/32 [00:12<00:00,  2.58it/s, loss=0.677, positive_reward=0.329, negative_reward=0.0633, margin=0.265, greedy_score=1.18e+3, sample_score=585]
# Epoch [48/100]: 100%|██████████| 32/32 [00:12<00:00,  2.58it/s, loss=0.67, positive_reward=0.479, negative_reward=0.0816, margin=0.397, greedy_score=1.17e+3, sample_score=712]
# Epoch [49/100]: 100%|██████████| 32/32 [00:12<00:00,  2.59it/s, loss=0.68, positive_reward=0.274, negative_reward=0.0387, margin=0.235, greedy_score=1.17e+3, sample_score=590]
# Epoch [50/100]: 100%|██████████| 32/32 [00:12<00:00,  2.59it/s, loss=0.676, positive_reward=0.363, negative_reward=-.00451, margin=0.368, greedy_score=1.18e+3, sample_score=601]
# Epoch [51/100]: 100%|██████████| 32/32 [00:12<00:00,  2.58it/s, loss=0.656, positive_reward=0.775, negative_reward=0.106, margin=0.669, greedy_score=1.17e+3, sample_score=635]
# Epoch [52/100]: 100%|██████████| 32/32 [00:12<00:00,  2.63it/s, loss=0.66, positive_reward=0.703, negative_reward=0.0924, margin=0.611, greedy_score=1.18e+3, sample_score=578]
# Epoch [53/100]: 100%|██████████| 32/32 [00:12<00:00,  2.63it/s, loss=0.676, positive_reward=0.35, negative_reward=0.0383, margin=0.312, greedy_score=1.17e+3, sample_score=665]
# Epoch [54/100]: 100%|██████████| 32/32 [00:12<00:00,  2.63it/s, loss=0.674, positive_reward=0.401, negative_reward=0.0539, margin=0.347, greedy_score=1.18e+3, sample_score=624]
# Epoch [55/100]: 100%|██████████| 32/32 [00:12<00:00,  2.64it/s, loss=0.669, positive_reward=0.51, negative_reward=0.0282, margin=0.482, greedy_score=1.18e+3, sample_score=607]
# Epoch [56/100]: 100%|██████████| 32/32 [00:12<00:00,  2.64it/s, loss=0.673, positive_reward=0.423, negative_reward=0.116, margin=0.307, greedy_score=1.18e+3, sample_score=565]
# Epoch [57/100]: 100%|██████████| 32/32 [00:12<00:00,  2.63it/s, loss=0.673, positive_reward=0.428, negative_reward=0.0793, margin=0.348, greedy_score=1.17e+3, sample_score=615]
# Epoch [58/100]: 100%|██████████| 32/32 [00:12<00:00,  2.64it/s, loss=0.668, positive_reward=0.536, negative_reward=0.122, margin=0.414, greedy_score=1.18e+3, sample_score=596]
# Epoch [59/100]: 100%|██████████| 32/32 [00:11<00:00,  2.68it/s, loss=0.67, positive_reward=0.497, negative_reward=0.12, margin=0.377, greedy_score=1.17e+3, sample_score=745]
# Epoch [60/100]: 100%|██████████| 32/32 [00:11<00:00,  2.70it/s, loss=0.669, positive_reward=0.518, negative_reward=0.0663, margin=0.451, greedy_score=1.18e+3, sample_score=532]
# Epoch [61/100]: 100%|██████████| 32/32 [00:12<00:00,  2.67it/s, loss=0.666, positive_reward=0.569, negative_reward=0.102, margin=0.467, greedy_score=1.18e+3, sample_score=512]
# Epoch [62/100]: 100%|██████████| 32/32 [00:11<00:00,  2.67it/s, loss=0.67, positive_reward=0.485, negative_reward=0.108, margin=0.377, greedy_score=1.17e+3, sample_score=572]
# Epoch [63/100]: 100%|██████████| 32/32 [00:11<00:00,  2.67it/s, loss=0.663, positive_reward=0.647, negative_reward=0.111, margin=0.537, greedy_score=1.17e+3, sample_score=593]
# Epoch [64/100]: 100%|██████████| 32/32 [00:11<00:00,  2.69it/s, loss=0.671, positive_reward=0.452, negative_reward=0.054, margin=0.397, greedy_score=1.17e+3, sample_score=724]
# Epoch [65/100]: 100%|██████████| 32/32 [00:11<00:00,  2.70it/s, loss=0.683, positive_reward=0.205, negative_reward=-.0177, margin=0.222, greedy_score=1.17e+3, sample_score=670]
# Epoch [66/100]: 100%|██████████| 32/32 [00:11<00:00,  2.73it/s, loss=0.652, positive_reward=0.874, negative_reward=0.176, margin=0.698, greedy_score=1.17e+3, sample_score=827]
# Epoch [67/100]: 100%|██████████| 32/32 [00:12<00:00,  2.66it/s, loss=0.671, positive_reward=0.457, negative_reward=0.142, margin=0.315, greedy_score=1.17e+3, sample_score=551]
# Epoch [68/100]: 100%|██████████| 32/32 [00:11<00:00,  2.68it/s, loss=0.673, positive_reward=0.431, negative_reward=0.0118, margin=0.419, greedy_score=1.17e+3, sample_score=532]
# Epoch [69/100]: 100%|██████████| 32/32 [00:11<00:00,  2.73it/s, loss=0.674, positive_reward=0.406, negative_reward=0.0556, margin=0.351, greedy_score=1.17e+3, sample_score=655]
# Epoch [70/100]: 100%|██████████| 32/32 [00:11<00:00,  2.69it/s, loss=0.668, positive_reward=0.529, negative_reward=0.0453, margin=0.484, greedy_score=1.17e+3, sample_score=560]
# Epoch [71/100]: 100%|██████████| 32/32 [00:12<00:00,  2.65it/s, loss=0.676, positive_reward=0.359, negative_reward=0.0262, margin=0.332, greedy_score=1.17e+3, sample_score=683]
# Epoch [72/100]: 100%|██████████| 32/32 [00:11<00:00,  2.68it/s, loss=0.68, positive_reward=0.285, negative_reward=0.0354, margin=0.25, greedy_score=1.17e+3, sample_score=619]
# Epoch [73/100]: 100%|██████████| 32/32 [00:12<00:00,  2.64it/s, loss=0.66, positive_reward=0.708, negative_reward=0.179, margin=0.529, greedy_score=1.17e+3, sample_score=570]
# Epoch [74/100]: 100%|██████████| 32/32 [00:12<00:00,  2.66it/s, loss=0.663, positive_reward=0.64, negative_reward=0.12, margin=0.52, greedy_score=1.17e+3, sample_score=584]
# Epoch [75/100]: 100%|██████████| 32/32 [00:11<00:00,  2.67it/s, loss=0.665, positive_reward=0.583, negative_reward=0.115, margin=0.468, greedy_score=1.17e+3, sample_score=671]
# Epoch [76/100]: 100%|██████████| 32/32 [00:12<00:00,  2.67it/s, loss=0.671, positive_reward=0.479, negative_reward=0.0879, margin=0.391, greedy_score=1.17e+3, sample_score=665]
# Epoch [77/100]: 100%|██████████| 32/32 [00:11<00:00,  2.69it/s, loss=0.668, positive_reward=0.526, negative_reward=0.126, margin=0.4, greedy_score=1.17e+3, sample_score=521]
# Epoch [78/100]: 100%|██████████| 32/32 [00:11<00:00,  2.68it/s, loss=0.66, positive_reward=0.705, negative_reward=0.124, margin=0.581, greedy_score=1.17e+3, sample_score=655]
# Epoch [79/100]: 100%|██████████| 32/32 [00:11<00:00,  2.68it/s, loss=0.673, positive_reward=0.426, negative_reward=0.0634, margin=0.363, greedy_score=1.17e+3, sample_score=562]
# Epoch [80/100]: 100%|██████████| 32/32 [00:12<00:00,  2.65it/s, loss=0.672, positive_reward=0.442, negative_reward=0.0238, margin=0.418, greedy_score=1.17e+3, sample_score=702]
# Epoch [81/100]: 100%|██████████| 32/32 [00:12<00:00,  2.65it/s, loss=0.673, positive_reward=0.415, negative_reward=0.0814, margin=0.334, greedy_score=1.17e+3, sample_score=602]
# Epoch [82/100]: 100%|██████████| 32/32 [00:11<00:00,  2.67it/s, loss=0.665, positive_reward=0.596, negative_reward=0.166, margin=0.43, greedy_score=1.17e+3, sample_score=556]
# Epoch [83/100]: 100%|██████████| 32/32 [00:11<00:00,  2.69it/s, loss=0.684, positive_reward=0.201, negative_reward=0.0295, margin=0.172, greedy_score=1.17e+3, sample_score=610]
# Epoch [84/100]: 100%|██████████| 32/32 [00:11<00:00,  2.67it/s, loss=0.669, positive_reward=0.514, negative_reward=0.0486, margin=0.466, greedy_score=1.17e+3, sample_score=540]
# Epoch [85/100]: 100%|██████████| 32/32 [00:12<00:00,  2.66it/s, loss=0.678, positive_reward=0.331, negative_reward=0.0384, margin=0.293, greedy_score=1.17e+3, sample_score=622]
# Epoch [86/100]: 100%|██████████| 32/32 [00:12<00:00,  2.66it/s, loss=0.665, positive_reward=0.597, negative_reward=0.178, margin=0.419, greedy_score=1.17e+3, sample_score=674]
# Epoch [87/100]: 100%|██████████| 32/32 [00:12<00:00,  2.63it/s, loss=0.666, positive_reward=0.573, negative_reward=0.115, margin=0.458, greedy_score=1.17e+3, sample_score=605]
# Epoch [88/100]: 100%|██████████| 32/32 [00:11<00:00,  2.68it/s, loss=0.66, positive_reward=0.7, negative_reward=0.0997, margin=0.6, greedy_score=1.17e+3, sample_score=606]
# Epoch [89/100]: 100%|██████████| 32/32 [00:11<00:00,  2.68it/s, loss=0.67, positive_reward=0.475, negative_reward=0.0913, margin=0.384, greedy_score=1.17e+3, sample_score=542]
# Epoch [90/100]: 100%|██████████| 32/32 [00:12<00:00,  2.64it/s, loss=0.661, positive_reward=0.691, negative_reward=0.0623, margin=0.628, greedy_score=1.17e+3, sample_score=622]
# Epoch [91/100]: 100%|██████████| 32/32 [00:12<00:00,  2.65it/s, loss=0.673, positive_reward=0.436, negative_reward=0.017, margin=0.419, greedy_score=1.17e+3, sample_score=540]
# Epoch [92/100]: 100%|██████████| 32/32 [00:11<00:00,  2.68it/s, loss=0.669, positive_reward=0.518, negative_reward=0.128, margin=0.391, greedy_score=1.17e+3, sample_score=528]
# Epoch [93/100]: 100%|██████████| 32/32 [00:11<00:00,  2.67it/s, loss=0.667, positive_reward=0.55, negative_reward=0.101, margin=0.449, greedy_score=1.17e+3, sample_score=829]
# Epoch [94/100]: 100%|██████████| 32/32 [00:12<00:00,  2.66it/s, loss=0.667, positive_reward=0.544, negative_reward=0.0699, margin=0.474, greedy_score=1.17e+3, sample_score=554]
# Epoch [95/100]: 100%|██████████| 32/32 [00:12<00:00,  2.66it/s, loss=0.673, positive_reward=0.412, negative_reward=0.0857, margin=0.326, greedy_score=1.17e+3, sample_score=823]
# Epoch [96/100]: 100%|██████████| 32/32 [00:12<00:00,  2.61it/s, loss=0.672, positive_reward=0.437, negative_reward=0.13, margin=0.308, greedy_score=1.17e+3, sample_score=545]
# Epoch [97/100]: 100%|██████████| 32/32 [00:12<00:00,  2.65it/s, loss=0.679, positive_reward=0.298, negative_reward=0.0317, margin=0.266, greedy_score=1.17e+3, sample_score=620]
# Epoch [98/100]: 100%|██████████| 32/32 [00:11<00:00,  2.75it/s, loss=0.665, positive_reward=0.6, negative_reward=0.137, margin=0.463, greedy_score=1.17e+3, sample_score=547]
# Epoch [99/100]: 100%|██████████| 32/32 [00:10<00:00,  3.19it/s, loss=0.675, positive_reward=0.383, negative_reward=0.112, margin=0.271, greedy_score=1.17e+3, sample_score=551]
# Epoch [100/100]: 100%|██████████| 32/32 [00:09<00:00,  3.21it/s, loss=0.667, positive_reward=0.562, negative_reward=0.0557, margin=0.506, greedy_score=1.17e+3, sample_score=645]

# %%
# save all png to /mnt/nfs/work/albertliu/RL/CartPole-v1/DPO

# draw the loss graph
import matplotlib.pyplot as plt
plt.plot(loss_graph)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss vs Iteration")
# plt.savefig("./loss.png")

plt.show()



# draw the reward graph
plt.plot(greedy_rewards)
plt.xlabel("Iteration")
plt.ylabel("Greedy Reward")
plt.title("Greedy Reward vs Iteration")
# plt.savefig("./greedy_reward.png")
plt.show()

# draw the reward graph
plt.plot(sample_rewards)
plt.xlabel("Iteration")
plt.ylabel("Sample Reward")
plt.title("Sample Reward vs Iteration")
# plt.savefig("./sample_reward.png")
plt.show()


# drqw the margin graph
plt.plot(margin_graph)
plt.xlabel("Iteration")
plt.ylabel("Margin")
plt.title("Margin vs Iteration")
# plt.savefig("./margin.png")
plt.show()

# draw the positive reward graph
plt.plot(positive_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Positive Reward")
plt.title("Positive Reward vs Iteration")
# plt.savefig("./positive_reward.png")
plt.show()

# draw the negative reward graph
plt.plot(negative_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Negative Reward")
# plt.title("Negative Reward vs Iteration")

plt.savefig("./negative_reward.png")
plt.show()

# %%
# from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
# from stable_baselines3.common.vec_env import VecEnv
# import gymnasium as gym
# from imitation.policies.serialize import load_policy
# from imitation.util.util import make_vec_env
# import numpy as np
# import torch
# import os

# # 创建环境
# env = make_vec_env(
#     "seals:seals/Walker2d-v1",
#     rng=np.random.default_rng(),
#     n_envs=1,
#     env_make_kwargs={"render_mode": "rgb_array"},
# )

# # 使用 VecVideoRecorder 包装环境以启用视频记录，指定视频保存的路径
# video_folder = './videos'
# video_length = 200  # 设置视频长度
# env = VecVideoRecorder(env, video_folder,
#                        record_video_trigger=lambda step: step == 0, video_length=video_length,
#                        name_prefix="Walker2d-video")

# # 创建模型，这里以从 Hugging Face 加载预训练的 PPO 模型为例
# model = load_policy(
#     "ppo-huggingface",
#     organization="HumanCompatibleAI",
#     env_name="seals/Walker2d-v1",
#     venv=env,
# )

# # 训练模型
# # 注意: 此处假定模型已经预训练，无需再次训练

# # 测试模型，生成视频
# obs = env.reset()
# done = False
# while not done:
#     action, _states = model.predict(obs, deterministic=True)
#     obs, rewards, dones, info = env.step(action)
#     done = dones.any()

# env.close()

# # 如果需要手动保存视频（有时候视频不会在关闭时自动保存）
# env.record_video_trigger(video_length)
