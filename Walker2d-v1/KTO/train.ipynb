# %%
import gymnasium as gym
import numpy as np
from stable_baselines3.common.env_util import make_vec_env as make_vec_env_sb3
from copy import deepcopy
import torch
from torch.distributions import Normal
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.utils.data import Dataset, DataLoader
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
import imageio
import pandas as pd
from tqdm import tqdm
from PIL import Image
from stable_baselines3.dqn.policies import MlpPolicy
import matplotlib.pyplot as plt

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !nvidia-smi
# clean up memory forcefully
torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# Thu Apr 18 18:35:00 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  | 00000000:01:00.0 Off |                  N/A |
# | 15%   56C    P2              81W / 250W |   2001MiB / 11264MiB |     33%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    377684      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A    384717      C   build/xiangqi/minizero_xiangqi             1000MiB |
# |    0   N/A  N/A   1233867      G   ...181/miniconda3/envs/copy/bin/python       46MiB |
# |    0   N/A  N/A   1344479      C   ...181/miniconda3/envs/copy/bin/python      212MiB |
# |    0   N/A  N/A   1352095    C+G   ...iu/miniconda3/envs/myenv/bin/python      544MiB |
# +---------------------------------------------------------------------------------------+
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
class CustomDataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32,device=device)
        self.actions = torch.tensor(actions, dtype=torch.float32,device=device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, output_dim,init_w=3e-3,log_std_min=-20,log_std_max=2):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 32)


        self.fc2 = nn.Linear(32, 32)
        self.log_std = nn.Linear(32, output_dim)
        self.mu=nn.Linear(32,output_dim)
        self.log_std_min=log_std_min
        self.log_std_max=log_std_max
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        torch.nn.init.kaiming_normal_(self.fc2.weight)
        self.mu.weight.data.uniform_(-init_w,init_w)
        self.mu.bias.data.uniform_(-init_w,init_w)
        self.log_std.weight.data.uniform_(-init_w,init_w)
        self.log_std.bias.data.uniform_(-init_w,init_w)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = self.mu(x) # Only apply if action bounds are [-1, 1]
        log_std = self.log_std(x)  # Ensure std is positive
        log_std=torch.clamp(log_std,self.log_std_min,self.log_std_max)

        return mu, log_std
# Out:
# Using device: cuda

# %%
from imitation.util.util import make_vec_env

observations= np.load("../dataset/obs.npy", allow_pickle=True)
actions = np.load("../dataset/actions.npy", allow_pickle=True)
rewards = np.load("../dataset/rewards.npy", allow_pickle=True)
dones = np.load("../dataset/dones.npy", allow_pickle=True)
info = np.load("../dataset/info.npy", allow_pickle=True)
next_obs = np.load("../dataset/next_obs.npy", allow_pickle=True)
observations=observations.squeeze()
actions=actions.squeeze()
rewards=rewards.squeeze()
dones=dones.squeeze()
info=info.squeeze()
next_obs=next_obs.squeeze()

print(observations.shape, actions.shape, rewards.shape, dones.shape, info.shape, next_obs.shape)
print(observations[0], actions[0], rewards[0], dones[0], info[0], next_obs[0])
env = make_vec_env(
    "seals:seals/Walker2d-v1",
    rng=np.random.default_rng(),
    env_make_kwargs={"render_mode": "rgb_array"},
    n_envs=1,
)
# Out:
# (100000, 18) (100000, 6) (100000,) (100000,) (100000,) (100000, 18)
# [ 1.36961687e-03  1.24769787e+00 -4.59026476e-03 -4.83472364e-03
#   3.13270239e-03  4.12755577e-03  1.06635776e-03  2.29496561e-03
#   4.36249915e-04  4.35072424e-03  3.15853554e-03 -4.97261500e-03
#   3.57404277e-03 -4.66414425e-03  2.29655446e-03 -3.24344379e-03
#   3.63178922e-03  4.14612202e-04] [1.        1.        0.9766268 1.        0.1786359 1.       ] 1.1278079 False {'x_position': 0.002431965734592546, 'x_velocity': 0.13279360767225037, 'TimeLimit.truncated': False} [ 2.43196573e-03  1.24594578e+00 -8.64441604e-04 -1.14463408e-03
#   3.10100134e-03  5.86868264e-02  3.56366528e-03  2.25989286e-03
#   5.70766729e-02  2.47718944e-01 -4.40264873e-01  8.48866739e-01
#   8.48918506e-01  1.11113961e-03  1.00000000e+01  5.52236742e-01
#  -2.65369722e-03  1.00000000e+01]

# %%
class mydataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32).to(device)
        self.actions = torch.tensor(actions, dtype=torch.float32).to(device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

# %%
# state=env.reset()
# print(env.step([[1,1,1,1,1,1]]))
# env.render()

# %%
policy_network = PolicyNetwork(18,6).to(device)
prev = PolicyNetwork(18,6).to(device)
prev.load_state_dict(policy_network.state_dict())
prev.eval()

optimizer = torch.optim.Adam(policy_network.parameters(), lr=1e-4,weight_decay=1e-5)

# Training loop
num_epochs = 100
batch_size = 32

dataset = mydataset(observations=observations, actions=actions)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

loss_graph=[]
greedy_rewards=[]
sample_rewards=[]
margin_graph=[]
positive_reward_graph=[]
negative_reward_graph=[]
log_interval = len(observations)//1
num_test = 10
prev_load_freq = 1000
now_log=0
now_pos=0
greedy_score=0
sample_score=0
for epoch in range(num_epochs):
    policy_network.train()

    # Compute the log probabilities of the actions
    pbar=tqdm(dataloader,position=0,leave=True)
    now_log=0

    for step, (obs_batch,act_batch) in enumerate(pbar):
        # obs_batch = torch.tensor(np.array(obs_batch), dtype=torch.float32).to(device)
        # act_batch = torch.tensor(np.array(act_batch), dtype=torch.float32).to(device)

        now_log+=obs_batch.shape[0]
        now_pos+=obs_batch.shape[0]
        
        mu, log_std = policy_network(obs_batch)
        std=log_std.exp()
        dist = Normal(mu, std)
        z_model=dist.rsample()
        model_action=torch.tanh(z_model)
        z_expert=torch.atanh(torch.clamp(act_batch, -0.999, 0.999))
        epsilon=1e-6


        policy_rejected_logps =dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
        policy_chosen_logps = dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        with torch.no_grad():
          prev_mu, prev_log_std = prev(obs_batch)
          prev_std=prev_log_std.exp()
          prev_dist = Normal(prev_mu, prev_std)

          reference_rejected_logps =prev_dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
          reference_chosen_logps = prev_dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        pi_logratios = policy_chosen_logps - policy_rejected_logps
        ref_logratios = reference_chosen_logps - reference_rejected_logps

        chosen_KL = (policy_chosen_logps - reference_chosen_logps).mean().clamp(min=0)
        reject_KL = (policy_rejected_logps - reference_rejected_logps).mean().clamp(min=0)

        logits = pi_logratios - ref_logratios

        chosen_logratios = policy_chosen_logps - reference_chosen_logps
        reject_logratios = policy_rejected_logps - reference_rejected_logps

        # logits = chosen_logratios - reject_logratios

        if epoch <= -1:
          loss = - (policy_chosen_logps).mean()
        else:
          beta = 1
        #   losses = (
        #           -F.logsigmoid(beta * logits)
        #       )
        #   loss = losses.mean()
          losses = torch.cat((1 - F.logsigmoid(beta * (chosen_logratios - reject_KL)), 1 - F.logsigmoid(beta * (chosen_KL - reject_logratios))), 0)
          loss = losses.mean()
        # Optimize the policy
        optimizer.zero_grad()

        if (step+1) % prev_load_freq == 0:
            prev.load_state_dict(policy_network.state_dict())
            prev.eval()

        loss.backward()

        optimizer.step()
        pbar.set_description((f"Epoch [{epoch+1}/{num_epochs}]"))
        positive_reward = chosen_logratios.detach().mean().item()
        negative_reward = reject_logratios.detach().mean().item()
        margin = positive_reward - negative_reward
        loss_graph.append(loss.detach().item())
        margin_graph.append(margin)
        positive_reward_graph.append(positive_reward)
        negative_reward_graph.append(negative_reward)



        total_reward=0
        if now_log>=log_interval:
            now_log-=log_interval
            
            policy_network.eval()  # 切换到评估模式

            

            total_reward=0
            # test the policy and save as the first test as gif
            for _ in range(num_test):
                state = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(mu)   
                        action.squeeze_()

                    state, reward, done, _ = env.step([action.cpu().numpy()])  # 执行动作
                    total_reward += reward

            greedy_score=total_reward/num_test
            total_reward=0

            # test the policy and save as the first test as gif
            for _ in range(num_test):
                state = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(Normal(mu,std).sample())
                        action.squeeze_()
                       
                    state, reward, done, _ = env.step([action.cpu().numpy()])  # 执行动作
                    total_reward += reward

            sample_score=total_reward/num_test
            greedy_rewards.append(greedy_score)
            sample_rewards.append(sample_score)
            policy_network.train()  # 切换回训练模式
        pbar.set_postfix({"loss":loss.detach().item(), "positive_reward": positive_reward, "negative_reward": negative_reward, "margin": positive_reward - negative_reward,"greedy_score":greedy_score,"sample_score":sample_score})

         

env.close()
# Out:
# Epoch [1/100]: 100%|█████████▉| 3119/3125 [00:22<00:00, 144.18it/s, loss=1.68, positive_reward=0.025, negative_reward=-.000218, margin=0.0252, greedy_score=0, sample_score=0]    /tmp/ipykernel_1400362/1205753383.py:120: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025847094/work/torch/csrc/utils/tensor_new.cpp:275.)
#   state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
# Epoch [1/100]: 100%|██████████| 3125/3125 [00:39<00:00, 78.85it/s, loss=1.68, positive_reward=0.0279, negative_reward=0.0019, margin=0.026, greedy_score=[-74.909256], sample_score=[-509.37494]]
# Epoch [2/100]: 100%|██████████| 3125/3125 [00:40<00:00, 76.70it/s, loss=1.77, positive_reward=-.249, negative_reward=0.00806, margin=-.257, greedy_score=[356.6219], sample_score=[-497.68173]]
# Epoch [3/100]: 100%|██████████| 3125/3125 [00:37<00:00, 83.38it/s, loss=1.59, positive_reward=0.243, negative_reward=0.0239, margin=0.219, greedy_score=[361.50745], sample_score=[-382.5496]]
# Epoch [4/100]: 100%|██████████| 3125/3125 [00:43<00:00, 71.98it/s, loss=1.59, positive_reward=0.232, negative_reward=0.00593, margin=0.226, greedy_score=[428.85], sample_score=[-227.2832]]
# Epoch [5/100]: 100%|██████████| 3125/3125 [00:41<00:00, 76.21it/s, loss=1.59, positive_reward=0.237, negative_reward=0.0152, margin=0.222, greedy_score=[794.2425], sample_score=[-468.89786]]
# Epoch [6/100]: 100%|██████████| 3125/3125 [00:35<00:00, 88.66it/s, loss=1.57, positive_reward=0.273, negative_reward=0.00917, margin=0.264, greedy_score=[743.6509], sample_score=[-435.81488]]
# Epoch [7/100]: 100%|██████████| 3125/3125 [00:34<00:00, 91.56it/s, loss=1.65, positive_reward=0.0918, negative_reward=-.0022, margin=0.094, greedy_score=[1438.7905], sample_score=[-359.10016]]
# Epoch [8/100]: 100%|██████████| 3125/3125 [00:37<00:00, 84.04it/s, loss=1.6, positive_reward=0.225, negative_reward=0.0226, margin=0.202, greedy_score=[1029.1665], sample_score=[-172.86679]]
# Epoch [9/100]: 100%|██████████| 3125/3125 [00:41<00:00, 76.10it/s, loss=1.67, positive_reward=0.0506, negative_reward=-.000692, margin=0.0513, greedy_score=[1425.7721], sample_score=[-350.3341]]
# Epoch [10/100]: 100%|██████████| 3125/3125 [00:38<00:00, 82.21it/s, loss=1.57, positive_reward=0.29, negative_reward=0.0204, margin=0.269, greedy_score=[1083.1361], sample_score=[-57.61039]]
# Epoch [11/100]: 100%|██████████| 3125/3125 [00:40<00:00, 76.86it/s, loss=1.66, positive_reward=0.0716, negative_reward=0.00396, margin=0.0677, greedy_score=[1484.7853], sample_score=[-366.93472]]
# Epoch [12/100]: 100%|██████████| 3125/3125 [00:40<00:00, 76.71it/s, loss=1.65, positive_reward=0.0836, negative_reward=0.00273, margin=0.0808, greedy_score=[1599.7458], sample_score=[-86.94111]]
# Epoch [13/100]: 100%|██████████| 3125/3125 [00:42<00:00, 73.08it/s, loss=1.66, positive_reward=0.0619, negative_reward=-.00166, margin=0.0636, greedy_score=[1690.0154], sample_score=[-248.97168]]
# Epoch [14/100]: 100%|██████████| 3125/3125 [00:39<00:00, 78.17it/s, loss=1.65, positive_reward=0.0837, negative_reward=0.00468, margin=0.079, greedy_score=[1343.2987], sample_score=[-0.9176121]]
# Epoch [15/100]: 100%|██████████| 3125/3125 [00:40<00:00, 76.66it/s, loss=1.76, positive_reward=-.214, negative_reward=0.0193, margin=-.233, greedy_score=[1024.5143], sample_score=[-221.34152]]
# Epoch [16/100]: 100%|██████████| 3125/3125 [00:38<00:00, 81.43it/s, loss=1.58, positive_reward=0.273, negative_reward=0.0199, margin=0.253, greedy_score=[1067.3073], sample_score=[-193.33005]]
# Epoch [17/100]: 100%|██████████| 3125/3125 [00:32<00:00, 95.41it/s, loss=1.68, positive_reward=0.0324, negative_reward=-.00301, margin=0.0354, greedy_score=[1671.8899], sample_score=[11.328988]]
# Epoch [18/100]: 100%|██████████| 3125/3125 [00:33<00:00, 94.45it/s, loss=1.77, positive_reward=-.263, negative_reward=0.00284, margin=-.265, greedy_score=[1367.1179], sample_score=[94.39179]]
# Epoch [19/100]: 100%|██████████| 3125/3125 [00:33<00:00, 93.20it/s, loss=1.78, positive_reward=-.284, negative_reward=0.0109, margin=-.295, greedy_score=[1132.8063], sample_score=[-66.32506]]
# Epoch [20/100]: 100%|██████████| 3125/3125 [00:35<00:00, 88.69it/s, loss=1.61, positive_reward=0.225, negative_reward=0.0344, margin=0.191, greedy_score=[1184.3256], sample_score=[-195.74887]]
# Epoch [21/100]: 100%|██████████| 3125/3125 [00:38<00:00, 82.07it/s, loss=1.57, positive_reward=0.265, negative_reward=0.00554, margin=0.26, greedy_score=[1327.064], sample_score=[-113.15558]]
# Epoch [22/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.78it/s, loss=1.6, positive_reward=0.209, negative_reward=0.00874, margin=0.201, greedy_score=[755.64923], sample_score=[-100.08734]]
# Epoch [23/100]: 100%|██████████| 3125/3125 [00:38<00:00, 81.21it/s, loss=1.64, positive_reward=0.109, negative_reward=0.00706, margin=0.101, greedy_score=[1753.1781], sample_score=[-181.23341]]
# Epoch [24/100]: 100%|██████████| 3125/3125 [00:38<00:00, 80.55it/s, loss=1.59, positive_reward=0.241, negative_reward=0.0115, margin=0.229, greedy_score=[1393.6567], sample_score=[-176.54189]]
# Epoch [25/100]: 100%|██████████| 3125/3125 [00:38<00:00, 80.86it/s, loss=1.66, positive_reward=0.0712, negative_reward=0.0094, margin=0.0618, greedy_score=[1839.4108], sample_score=[-254.2107]]
# Epoch [26/100]: 100%|██████████| 3125/3125 [00:38<00:00, 81.26it/s, loss=1.66, positive_reward=0.0591, negative_reward=-.00367, margin=0.0628, greedy_score=[1506.7908], sample_score=[72.298874]]
# Epoch [27/100]: 100%|██████████| 3125/3125 [00:39<00:00, 78.66it/s, loss=1.76, positive_reward=-.249, negative_reward=0.000435, margin=-.25, greedy_score=[1421.9435], sample_score=[-74.159874]]
# Epoch [28/100]: 100%|██████████| 3125/3125 [00:38<00:00, 80.93it/s, loss=1.79, positive_reward=-.318, negative_reward=0.0198, margin=-.338, greedy_score=[949.39856], sample_score=[-97.065315]]
# Epoch [29/100]: 100%|██████████| 3125/3125 [00:38<00:00, 81.09it/s, loss=1.68, positive_reward=0.0336, negative_reward=0.00152, margin=0.0321, greedy_score=[1778.6195], sample_score=[159.63268]]
# Epoch [30/100]: 100%|██████████| 3125/3125 [00:38<00:00, 81.59it/s, loss=1.66, positive_reward=0.0663, negative_reward=0.00355, margin=0.0628, greedy_score=[1584.5916], sample_score=[73.52147]]
# Epoch [31/100]: 100%|██████████| 3125/3125 [00:38<00:00, 81.76it/s, loss=1.77, positive_reward=-.237, negative_reward=0.0196, margin=-.257, greedy_score=[1259.1681], sample_score=[70.98259]]
# Epoch [32/100]: 100%|██████████| 3125/3125 [00:38<00:00, 80.73it/s, loss=1.59, positive_reward=0.256, negative_reward=0.0227, margin=0.234, greedy_score=[1423.673], sample_score=[-28.645935]]
# Epoch [33/100]: 100%|██████████| 3125/3125 [00:39<00:00, 78.43it/s, loss=1.59, positive_reward=0.25, negative_reward=0.0292, margin=0.221, greedy_score=[1291.3843], sample_score=[-292.86145]]
# Epoch [34/100]: 100%|██████████| 3125/3125 [00:38<00:00, 80.79it/s, loss=1.75, positive_reward=-.199, negative_reward=-.00191, margin=-.197, greedy_score=[1238.0955], sample_score=[45.890656]]
# Epoch [35/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.64it/s, loss=1.6, positive_reward=0.231, negative_reward=0.0214, margin=0.21, greedy_score=[1453.2411], sample_score=[-97.68574]]
# Epoch [36/100]: 100%|██████████| 3125/3125 [00:39<00:00, 78.22it/s, loss=1.6, positive_reward=0.204, negative_reward=0.00327, margin=0.201, greedy_score=[1809.5527], sample_score=[-230.42603]]
# Epoch [37/100]: 100%|██████████| 3125/3125 [00:40<00:00, 77.72it/s, loss=1.6, positive_reward=0.209, negative_reward=0.00504, margin=0.204, greedy_score=[1658.2683], sample_score=[-156.78946]]
# Epoch [38/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.34it/s, loss=1.6, positive_reward=0.225, negative_reward=0.018, margin=0.207, greedy_score=[1655.0144], sample_score=[-184.70355]]
# Epoch [39/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.69it/s, loss=1.66, positive_reward=0.0909, negative_reward=0.0226, margin=0.0684, greedy_score=[1675.4197], sample_score=[47.410122]]
# Epoch [40/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.65it/s, loss=1.58, positive_reward=0.244, negative_reward=0.00856, margin=0.236, greedy_score=[1443.492], sample_score=[-140.66232]]
# Epoch [41/100]: 100%|██████████| 3125/3125 [01:13<00:00, 42.63it/s, loss=1.59, positive_reward=0.234, negative_reward=0.00287, margin=0.231, greedy_score=[1371.4797], sample_score=[-46.057945]]
# Epoch [42/100]: 100%|██████████| 3125/3125 [01:29<00:00, 34.91it/s, loss=1.67, positive_reward=0.0455, negative_reward=0.0012, margin=0.0443, greedy_score=[1685.6406], sample_score=[68.01148]]
# Epoch [43/100]: 100%|██████████| 3125/3125 [01:28<00:00, 35.14it/s, loss=1.77, positive_reward=-.236, negative_reward=0.015, margin=-.251, greedy_score=[1392.4978], sample_score=[182.10672]]
# Epoch [44/100]: 100%|██████████| 3125/3125 [01:29<00:00, 34.73it/s, loss=1.79, positive_reward=-.321, negative_reward=0.0145, margin=-.336, greedy_score=[1128.6472], sample_score=[31.236485]]
# Epoch [45/100]: 100%|██████████| 3125/3125 [01:29<00:00, 34.89it/s, loss=1.58, positive_reward=0.254, negative_reward=-.00239, margin=0.256, greedy_score=[557.6527], sample_score=[-137.91844]]
# Epoch [46/100]: 100%|██████████| 3125/3125 [01:29<00:00, 34.84it/s, loss=1.66, positive_reward=0.082, negative_reward=0.00333, margin=0.0786, greedy_score=[1448.672], sample_score=[28.760977]]
# Epoch [47/100]: 100%|██████████| 3125/3125 [01:25<00:00, 36.63it/s, loss=1.59, positive_reward=0.238, negative_reward=0.0216, margin=0.216, greedy_score=[1725.848], sample_score=[-245.23438]]
# Epoch [48/100]: 100%|██████████| 3125/3125 [00:46<00:00, 66.89it/s, loss=1.67, positive_reward=0.0575, negative_reward=-8.59e-5, margin=0.0576, greedy_score=[1409.0571], sample_score=[287.73578]]
# Epoch [49/100]: 100%|██████████| 3125/3125 [00:44<00:00, 69.91it/s, loss=1.65, positive_reward=0.0991, negative_reward=0.00452, margin=0.0945, greedy_score=[1695.6149], sample_score=[-75.322426]]
# Epoch [50/100]: 100%|██████████| 3125/3125 [00:40<00:00, 76.23it/s, loss=1.74, positive_reward=-.172, negative_reward=0.00761, margin=-.18, greedy_score=[1353.1868], sample_score=[75.18506]]
# Epoch [51/100]: 100%|██████████| 3125/3125 [00:40<00:00, 76.71it/s, loss=1.61, positive_reward=0.208, negative_reward=0.0365, margin=0.172, greedy_score=[1579.2572], sample_score=[-5.9109373]]
# Epoch [52/100]: 100%|██████████| 3125/3125 [00:40<00:00, 77.28it/s, loss=1.65, positive_reward=0.0868, negative_reward=-.00221, margin=0.089, greedy_score=[1459.179], sample_score=[191.17583]]
# Epoch [53/100]: 100%|██████████| 3125/3125 [00:40<00:00, 76.72it/s, loss=1.6, positive_reward=0.212, negative_reward=0.0127, margin=0.199, greedy_score=[1359.0741], sample_score=[47.818504]]
# Epoch [54/100]: 100%|██████████| 3125/3125 [00:39<00:00, 78.13it/s, loss=1.79, positive_reward=-.291, negative_reward=0.0199, margin=-.311, greedy_score=[1334.0989], sample_score=[113.68667]]
# Epoch [55/100]: 100%|██████████| 3125/3125 [00:39<00:00, 78.16it/s, loss=1.59, positive_reward=0.223, negative_reward=0.00461, margin=0.219, greedy_score=[1000.054], sample_score=[-199.6903]]
# Epoch [56/100]: 100%|██████████| 3125/3125 [00:41<00:00, 75.11it/s, loss=1.58, positive_reward=0.256, negative_reward=0.011, margin=0.245, greedy_score=[1088.2189], sample_score=[-282.10736]]
# Epoch [57/100]: 100%|██████████| 3125/3125 [00:40<00:00, 76.44it/s, loss=1.66, positive_reward=0.0717, negative_reward=0.00213, margin=0.0696, greedy_score=[1666.0658], sample_score=[267.75818]]
# Epoch [58/100]: 100%|██████████| 3125/3125 [00:39<00:00, 78.36it/s, loss=1.66, positive_reward=0.0747, negative_reward=-.00107, margin=0.0758, greedy_score=[1473.9656], sample_score=[-113.18768]]
# Epoch [59/100]: 100%|██████████| 3125/3125 [00:40<00:00, 77.09it/s, loss=1.59, positive_reward=0.233, negative_reward=0.016, margin=0.217, greedy_score=[1155.1165], sample_score=[-10.31513]]
# Epoch [60/100]: 100%|██████████| 3125/3125 [00:40<00:00, 77.67it/s, loss=1.77, positive_reward=-.245, negative_reward=0.00872, margin=-.254, greedy_score=[1161.9944], sample_score=[18.19971]]
# Epoch [61/100]: 100%|██████████| 3125/3125 [00:40<00:00, 78.11it/s, loss=1.58, positive_reward=0.279, negative_reward=0.0261, margin=0.253, greedy_score=[1507.4045], sample_score=[-100.6047]]
# Epoch [62/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.30it/s, loss=1.65, positive_reward=0.0847, negative_reward=-.00154, margin=0.0863, greedy_score=[1821.8112], sample_score=[36.943035]]
# Epoch [63/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.38it/s, loss=1.57, positive_reward=0.262, negative_reward=0.00232, margin=0.26, greedy_score=[1374.2024], sample_score=[121.99431]]
# Epoch [64/100]: 100%|██████████| 3125/3125 [00:39<00:00, 78.85it/s, loss=1.77, positive_reward=-.246, negative_reward=0.0246, margin=-.27, greedy_score=[900.5301], sample_score=[151.43051]]
# Epoch [65/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.29it/s, loss=1.68, positive_reward=0.0251, negative_reward=-.000472, margin=0.0256, greedy_score=[1876.0486], sample_score=[112.48946]]
# Epoch [66/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.98it/s, loss=1.76, positive_reward=-.236, negative_reward=0.00848, margin=-.244, greedy_score=[1253.3728], sample_score=[201.32108]]
# Epoch [67/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.52it/s, loss=1.59, positive_reward=0.224, negative_reward=0.00408, margin=0.22, greedy_score=[1230.2683], sample_score=[-76.875015]]
# Epoch [68/100]: 100%|██████████| 3125/3125 [00:38<00:00, 80.54it/s, loss=1.79, positive_reward=-.308, negative_reward=0.0128, margin=-.321, greedy_score=[1327.4347], sample_score=[196.59743]]
# Epoch [69/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.99it/s, loss=1.6, positive_reward=0.228, negative_reward=0.0227, margin=0.205, greedy_score=[1379.2919], sample_score=[379.64886]]
# Epoch [70/100]: 100%|██████████| 3125/3125 [00:38<00:00, 81.06it/s, loss=1.75, positive_reward=-.218, negative_reward=-.0177, margin=-.201, greedy_score=[923.17566], sample_score=[113.77718]]
# Epoch [71/100]: 100%|██████████| 3125/3125 [00:38<00:00, 81.31it/s, loss=1.8, positive_reward=-.32, negative_reward=0.0376, margin=-.358, greedy_score=[1202.0513], sample_score=[276.97647]]
# Epoch [72/100]: 100%|██████████| 3125/3125 [00:39<00:00, 80.03it/s, loss=1.79, positive_reward=-.312, negative_reward=0.0204, margin=-.333, greedy_score=[1298.9319], sample_score=[322.62653]]
# Epoch [73/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.40it/s, loss=1.59, positive_reward=0.217, negative_reward=0.00184, margin=0.215, greedy_score=[1168.5872], sample_score=[148.86598]]
# Epoch [74/100]: 100%|██████████| 3125/3125 [00:39<00:00, 78.65it/s, loss=1.66, positive_reward=0.0829, negative_reward=0.00984, margin=0.0731, greedy_score=[1530.2821], sample_score=[180.38411]]
# Epoch [75/100]: 100%|██████████| 3125/3125 [00:38<00:00, 81.47it/s, loss=1.76, positive_reward=-.199, negative_reward=0.0225, margin=-.221, greedy_score=[1256.4513], sample_score=[401.62518]]
# Epoch [76/100]: 100%|██████████| 3125/3125 [00:38<00:00, 81.53it/s, loss=1.67, positive_reward=0.0496, negative_reward=0.0022, margin=0.0474, greedy_score=[2058.529], sample_score=[317.4522]]
# Epoch [77/100]: 100%|██████████| 3125/3125 [00:38<00:00, 80.34it/s, loss=1.66, positive_reward=0.0671, negative_reward=0.00471, margin=0.0624, greedy_score=[1849.7107], sample_score=[312.17377]]
# Epoch [78/100]: 100%|██████████| 3125/3125 [00:38<00:00, 80.31it/s, loss=1.66, positive_reward=0.0739, negative_reward=0.00711, margin=0.0668, greedy_score=[1791.7428], sample_score=[58.874523]]
# Epoch [79/100]: 100%|██████████| 3125/3125 [00:39<00:00, 79.51it/s, loss=1.56, positive_reward=0.295, negative_reward=-.0133, margin=0.309, greedy_score=[1508.2346], sample_score=[-29.090195]]
# Epoch [80/100]: 100%|██████████| 3125/3125 [00:34<00:00, 91.26it/s, loss=1.75, positive_reward=-.202, negative_reward=-.00445, margin=-.198, greedy_score=[1282.1566], sample_score=[353.43417]]
# Epoch [81/100]: 100%|██████████| 3125/3125 [00:34<00:00, 91.80it/s, loss=1.58, positive_reward=0.247, negative_reward=0.00802, margin=0.239, greedy_score=[1098.3708], sample_score=[94.293015]]
# Epoch [82/100]: 100%|██████████| 3125/3125 [00:33<00:00, 92.32it/s, loss=1.78, positive_reward=-.286, negative_reward=0.0213, margin=-.307, greedy_score=[1446.419], sample_score=[160.49736]]
# Epoch [83/100]: 100%|██████████| 3125/3125 [00:33<00:00, 92.44it/s, loss=1.6, positive_reward=0.235, negative_reward=0.0296, margin=0.205, greedy_score=[1300.0767], sample_score=[-40.958645]]
# Epoch [84/100]: 100%|██████████| 3125/3125 [00:33<00:00, 93.44it/s, loss=1.75, positive_reward=-.206, negative_reward=0.000529, margin=-.207, greedy_score=[1470.6746], sample_score=[239.90564]]
# Epoch [85/100]: 100%|██████████| 3125/3125 [00:34<00:00, 91.07it/s, loss=1.58, positive_reward=0.234, negative_reward=-.0192, margin=0.253, greedy_score=[1366.6438], sample_score=[183.72905]]
# Epoch [86/100]: 100%|██████████| 3125/3125 [00:34<00:00, 90.38it/s, loss=1.75, positive_reward=-.172, negative_reward=0.0161, margin=-.188, greedy_score=[1377.8539], sample_score=[200.25656]]
# Epoch [87/100]: 100%|██████████| 3125/3125 [00:33<00:00, 93.62it/s, loss=1.67, positive_reward=0.0391, negative_reward=-.000823, margin=0.0399, greedy_score=[1846.251], sample_score=[352.8443]]
# Epoch [88/100]: 100%|██████████| 3125/3125 [00:33<00:00, 93.01it/s, loss=1.69, positive_reward=0.0179, negative_reward=0.00219, margin=0.0157, greedy_score=[2073.7412], sample_score=[382.59366]]
# Epoch [89/100]: 100%|██████████| 3125/3125 [00:34<00:00, 91.48it/s, loss=1.78, positive_reward=-.274, negative_reward=0.0193, margin=-.293, greedy_score=[1647.2361], sample_score=[161.09787]]
# Epoch [90/100]: 100%|██████████| 3125/3125 [00:34<00:00, 91.00it/s, loss=1.58, positive_reward=0.246, negative_reward=-.00154, margin=0.247, greedy_score=[1701.4285], sample_score=[416.5258]]
# Epoch [91/100]: 100%|██████████| 3125/3125 [00:33<00:00, 93.36it/s, loss=1.75, positive_reward=-.193, negative_reward=0.0108, margin=-.204, greedy_score=[1265.552], sample_score=[235.81982]]
# Epoch [92/100]: 100%|██████████| 3125/3125 [00:33<00:00, 92.70it/s, loss=1.59, positive_reward=0.24, negative_reward=0.0243, margin=0.216, greedy_score=[1327.349], sample_score=[178.58878]]
# Epoch [93/100]: 100%|██████████| 3125/3125 [00:33<00:00, 93.87it/s, loss=1.77, positive_reward=-.254, negative_reward=0.0072, margin=-.261, greedy_score=[993.9915], sample_score=[196.73709]]
# Epoch [94/100]: 100%|██████████| 3125/3125 [00:33<00:00, 94.08it/s, loss=1.59, positive_reward=0.255, negative_reward=0.0291, margin=0.226, greedy_score=[1366.7834], sample_score=[253.82442]]
# Epoch [95/100]: 100%|██████████| 3125/3125 [00:33<00:00, 92.60it/s, loss=1.75, positive_reward=-.206, negative_reward=0.000499, margin=-.207, greedy_score=[1644.8477], sample_score=[375.34253]]
# Epoch [96/100]: 100%|██████████| 3125/3125 [00:32<00:00, 95.10it/s, loss=1.67, positive_reward=0.0508, negative_reward=-.00162, margin=0.0525, greedy_score=[1845.3586], sample_score=[204.27368]]
# Epoch [97/100]: 100%|██████████| 3125/3125 [00:33<00:00, 93.61it/s, loss=1.76, positive_reward=-.221, negative_reward=0.0116, margin=-.232, greedy_score=[1368.5055], sample_score=[145.58968]]
# Epoch [98/100]: 100%|██████████| 3125/3125 [00:33<00:00, 93.31it/s, loss=1.78, positive_reward=-.297, negative_reward=0.0119, margin=-.309, greedy_score=[1201.2638], sample_score=[447.81537]]
# Epoch [99/100]: 100%|██████████| 3125/3125 [00:33<00:00, 94.00it/s, loss=1.59, positive_reward=0.242, negative_reward=0.0118, margin=0.23, greedy_score=[1649.5588], sample_score=[178.32268]]
# Epoch [100/100]: 100%|██████████| 3125/3125 [00:33<00:00, 93.65it/s, loss=1.57, positive_reward=0.26, negative_reward=-.00565, margin=0.266, greedy_score=[1735.9182], sample_score=[223.76242]]

# %%
# save all png to /mnt/nfs/work/albertliu/RL/CartPole-v1/DPO

# draw the loss graph
import matplotlib.pyplot as plt
plt.plot(loss_graph)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss vs Iteration")
plt.savefig("./loss.png")

plt.show()



# draw the reward graph
plt.plot(greedy_rewards)
plt.xlabel("Iteration")
plt.ylabel("Greedy Reward")
plt.title("Greedy Reward vs Iteration")
plt.savefig("./greedy_reward.png")
plt.show()

# draw the reward graph
plt.plot(sample_rewards)
plt.xlabel("Iteration")
plt.ylabel("Sample Reward")
plt.title("Sample Reward vs Iteration")
plt.savefig("./sample_reward.png")
plt.show()


# drqw the margin graph
plt.plot(margin_graph)
plt.xlabel("Iteration")
plt.ylabel("Margin")
plt.title("Margin vs Iteration")
plt.savefig("./margin.png")
plt.show()

# draw the positive reward graph
plt.plot(positive_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Positive Reward")
plt.title("Positive Reward vs Iteration")
plt.savefig("./positive_reward.png")
plt.show()

# draw the negative reward graph
plt.plot(negative_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Negative Reward")
plt.title("Negative Reward vs Iteration")

plt.savefig("./negative_reward.png")
plt.show()

# %%
# from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
# from stable_baselines3.common.vec_env import VecEnv
# import gymnasium as gym
# from imitation.policies.serialize import load_policy
# from imitation.util.util import make_vec_env
# import numpy as np
# import torch
# import os

# # 创建环境
# env = make_vec_env(
#     "seals:seals/Walker2d-v1",
#     rng=np.random.default_rng(),
#     n_envs=1,
#     env_make_kwargs={"render_mode": "rgb_array"},
# )

# # 使用 VecVideoRecorder 包装环境以启用视频记录，指定视频保存的路径
# video_folder = './videos'
# video_length = 200  # 设置视频长度
# env = VecVideoRecorder(env, video_folder,
#                        record_video_trigger=lambda step: step == 0, video_length=video_length,
#                        name_prefix="Walker2d-video")

# # 创建模型，这里以从 Hugging Face 加载预训练的 PPO 模型为例
# model = load_policy(
#     "ppo-huggingface",
#     organization="HumanCompatibleAI",
#     env_name="seals/Walker2d-v1",
#     venv=env,
# )

# # 训练模型
# # 注意: 此处假定模型已经预训练，无需再次训练

# # 测试模型，生成视频
# obs = env.reset()
# done = False
# while not done:
#     action, _states = model.predict(obs, deterministic=True)
#     obs, rewards, dones, info = env.step(action)
#     done = dones.any()

# env.close()

# # 如果需要手动保存视频（有时候视频不会在关闭时自动保存）
# env.record_video_trigger(video_length)
