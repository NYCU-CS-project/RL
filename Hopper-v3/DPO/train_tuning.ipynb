# %%
import gymnasium as gym
import numpy as np
from stable_baselines3.common.env_util import make_vec_env as make_vec_env_sb3
from copy import deepcopy
import torch
from torch.distributions import Normal,MultivariateNormal
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.utils.data import Dataset, DataLoader
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
import imageio
import pandas as pd
from tqdm import tqdm
from PIL import Image
from stable_baselines3.dqn.policies import MlpPolicy
import matplotlib.pyplot as plt

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !nvidia-smi
# clean up memory forcefully
torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# Mon May 13 00:52:11 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  | 00000000:01:00.0 Off |                  N/A |
# | 17%   56C    P2              90W / 250W |   3304MiB / 11264MiB |     96%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    228304      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    229850      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    277377      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    280712      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    319688      C   ...iu/miniconda3/envs/myenv/bin/python      300MiB |
# |    0   N/A  N/A    328416      C   ...iu/miniconda3/envs/myenv/bin/python      204MiB |
# |    0   N/A  N/A    377684      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   1475780      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   2544023      C   ...u/miniconda3/envs/myenv2/bin/python      184MiB |
# |    0   N/A  N/A   2546464      C   ...u/miniconda3/envs/myenv2/bin/python      192MiB |
# |    0   N/A  N/A   2573624      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2573704      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2584185      C   ...181/miniconda3/envs/copy/bin/python      194MiB |
# |    0   N/A  N/A   2587643      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2588031      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2591397    C+G   ...181/miniconda3/envs/copy/bin/python      217MiB |
# +---------------------------------------------------------------------------------------+
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
class CustomDataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32,device=device)
        self.actions = torch.tensor(actions, dtype=torch.float32,device=device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, output_dim,init_w=3e-3,log_std_min=-20,log_std_max=2):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 32)


        self.fc2 = nn.Linear(32, 32)
        self.log_std = nn.Linear(32, output_dim)
        self.mu=nn.Linear(32,output_dim)
        self.log_std_min=log_std_min
        self.log_std_max=log_std_max
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        torch.nn.init.kaiming_normal_(self.fc2.weight)
        self.mu.weight.data.uniform_(-init_w,init_w)
        self.mu.bias.data.uniform_(-init_w,init_w)
        self.log_std.weight.data.uniform_(-init_w,init_w)
        self.log_std.bias.data.uniform_(-init_w,init_w)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = self.mu(x) # Only apply if action bounds are [-1, 1]
        log_std = self.log_std(x)  # Ensure std is positive
        log_std=torch.clamp(log_std,self.log_std_min,self.log_std_max)

        return mu, log_std
# Out:
# Using device: cuda

# %%
# from imitation.util.util import make_vec_env

# observations= np.load("../dataset/obs.npy", allow_pickle=True)
# actions = np.load("../dataset/actions.npy", allow_pickle=True)

# observations=observations.squeeze()
# actions=actions.squeeze()

# print(observations.shape, actions.shape)
# print(observations[0], actions[0])
import pickle
import numpy as np
#　read /mnt/nfs/work/c98181/TDIL/saved_expert_transition/Walker2d-v3/sac/episode_num1_6123.pkl
# "states", "actions", "rewards", "next_states", "dones".
with open("/mnt/nfs/work/c98181/TDIL/saved_expert_transition/Hopper-v3/sac/episode_num1_4534.pkl", "rb") as f:
    data = pickle.load(f)

    obs_list = data["states"]
    actions_list = data["actions"]
    observations=np.array(obs_list)
    actions=np.array(actions_list)
    # shape
    print(observations.shape)
    print(actions.shape)

# env=gym.make("Walker2d-v3",exclude_current_positions_from_observation=False,render_mode="rgb_array")
env=gym.make("Hopper-v3",render_mode="rgb_array")
# Out:
# (1000, 11)
# (1000, 3)
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Hopper-v3 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_env.py:211: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(

# %%
class mydataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32).to(device)
        self.actions = torch.tensor(actions, dtype=torch.float32).to(device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

# %%
policy_network = PolicyNetwork(11,3).to(device)
prev = PolicyNetwork(11,3).to(device)
prev.load_state_dict(policy_network.state_dict())
prev.eval()

optimizer = torch.optim.Adam(policy_network.parameters(), lr=0.0003,weight_decay=1e-4)

# Training loop
num_epochs = 100
batch_size = 32

dataset = mydataset(observations=observations, actions=actions)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

loss_graph=[]
greedy_rewards=[]
sample_rewards=[]
margin_graph=[]
positive_reward_graph=[]
negative_reward_graph=[]
log_interval = len(observations)//1
num_test = 10
prev_load_freq = 32
now_log=0
now_pos=0
greedy_score=0
sample_score=0
for epoch in range(num_epochs):
    policy_network.train()

    # Compute the log probabilities of the actions
    pbar=tqdm(dataloader,position=0,leave=True)
    now_log=0

    for step, (obs_batch,act_batch) in enumerate(pbar):
        # obs_batch = torch.tensor(np.array(obs_batch), dtype=torch.float32).to(device)
        # act_batch = torch.tensor(np.array(act_batch), dtype=torch.float32).to(device)

        now_log+=obs_batch.shape[0]
        now_pos+=obs_batch.shape[0]
        
        mu, log_std = policy_network(obs_batch)
        std=log_std.exp()
        dist = Normal(mu, std)
        z_model=dist.rsample()
        model_action=torch.tanh(z_model)
        z_expert=torch.atanh(torch.clamp(act_batch, -0.999999, 0.999999))
        epsilon=1e-6


        policy_rejected_logps =dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
        policy_chosen_logps = dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        with torch.no_grad():
          prev_mu, prev_log_std = prev(obs_batch)
          prev_std=prev_log_std.exp()
          prev_dist = Normal(prev_mu, prev_std)

          reference_rejected_logps =prev_dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
          reference_chosen_logps = prev_dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        pi_logratios = policy_chosen_logps - policy_rejected_logps
        ref_logratios = reference_chosen_logps - reference_rejected_logps
        logits = pi_logratios - ref_logratios
        chosen_KL = (policy_chosen_logps - reference_chosen_logps).mean().clamp(min=0)
        reject_KL = (policy_rejected_logps - reference_rejected_logps).mean().clamp(min=0)

       

        chosen_logratios = policy_chosen_logps - reference_chosen_logps
        reject_logratios = policy_rejected_logps - reference_rejected_logps

        # logits = chosen_logratios - reject_logratios

        if epoch < -1:
          loss = - (policy_chosen_logps).mean()
        else:
          beta = 0.1
          losses=-F.logsigmoid(beta * logits)
          loss = losses.mean()
        #   losses = torch.cat((1 - F.logsigmoid(beta * (chosen_logratios - reject_KL)), 1 - F.logsigmoid(beta * (chosen_KL - reject_logratios))), 0)
        #   loss = losses.mean()
        # Optimize the policy
        optimizer.zero_grad()


        loss.backward()

        optimizer.step()
        pbar.set_description((f"Epoch [{epoch+1}/{num_epochs}]"))
        positive_reward = pi_logratios.detach().mean().item()
        negative_reward = ref_logratios.detach().mean().item()
        margin = positive_reward - negative_reward
        loss_graph.append(loss.detach().item())
        margin_graph.append(margin)
        positive_reward_graph.append(positive_reward)
        negative_reward_graph.append(negative_reward)



        total_reward=0
        if now_log>=log_interval:
            now_log-=log_interval
            
            policy_network.eval()  # 切换到评估模式

            

            total_reward=0
            # test the policy and save as the first test as gif
            frames = []
            for _ in range(num_test):
                state,_ = env.reset()
                done = False

                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(mu)   
                        action.squeeze_()

                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/greedy/"+image_path, frames)

            greedy_score=total_reward/num_test
            total_reward=0
            frames = []
            # test the policy and save as the first test as gif
            for _ in range(num_test):
                state,_ = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(Normal(mu,std).sample())
                        action.squeeze_()
                       
                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/sample/"+image_path, frames)

            sample_score=total_reward/num_test
            greedy_rewards.append(greedy_score)
            sample_rewards.append(sample_score)
            policy_network.train()  # 切换回训练模式
        pbar.set_postfix({"loss":loss.detach().item(), "positive_reward": positive_reward, "negative_reward": negative_reward, "margin": positive_reward - negative_reward,"greedy_score":greedy_score,"sample_score":sample_score})
    prev.load_state_dict(policy_network.state_dict())
    prev.eval()
         

env.close()
# Out:
# Epoch [1/100]:  72%|███████▏  | 23/32 [00:00<00:00, 51.48it/s, loss=0.681, positive_reward=0.203, negative_reward=-.042, margin=0.245, greedy_score=0, sample_score=0]    /tmp/ipykernel_2594730/3577099866.py:117: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025847094/work/torch/csrc/utils/tensor_new.cpp:275.)
#   state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
# Epoch [1/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.678, positive_reward=0.332, negative_reward=0.0129, margin=0.319, greedy_score=1.18e+3, sample_score=914]
# Epoch [2/100]: 100%|██████████| 32/32 [00:29<00:00,  1.09it/s, loss=0.686, positive_reward=0.145, negative_reward=-.00868, margin=0.154, greedy_score=1.17e+3, sample_score=934]
# Epoch [3/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.691, positive_reward=0.531, negative_reward=0.481, margin=0.0502, greedy_score=1.17e+3, sample_score=966]
# Epoch [4/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.692, positive_reward=0.593, negative_reward=0.561, margin=0.0321, greedy_score=1.17e+3, sample_score=914]
# Epoch [5/100]: 100%|██████████| 32/32 [00:24<00:00,  1.33it/s, loss=0.692, positive_reward=0.144, negative_reward=0.127, margin=0.017, greedy_score=1.17e+3, sample_score=989]
# Epoch [6/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=0.693, positive_reward=0.0914, negative_reward=0.0875, margin=0.00394, greedy_score=1.17e+3, sample_score=1.02e+3]
# Epoch [7/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.691, positive_reward=0.549, negative_reward=0.503, margin=0.0462, greedy_score=1.17e+3, sample_score=972]
# Epoch [8/100]: 100%|██████████| 32/32 [00:24<00:00,  1.29it/s, loss=0.694, positive_reward=0.377, negative_reward=0.398, margin=-.0206, greedy_score=1.17e+3, sample_score=1.06e+3]
# Epoch [9/100]: 100%|██████████| 32/32 [00:24<00:00,  1.32it/s, loss=0.693, positive_reward=0.168, negative_reward=0.165, margin=0.00331, greedy_score=1.17e+3, sample_score=992]
# Epoch [10/100]: 100%|██████████| 32/32 [00:22<00:00,  1.41it/s, loss=0.693, positive_reward=0.165, negative_reward=0.163, margin=0.00272, greedy_score=1.17e+3, sample_score=1.07e+3]
# Epoch [11/100]: 100%|██████████| 32/32 [00:22<00:00,  1.44it/s, loss=0.693, positive_reward=0.529, negative_reward=0.523, margin=0.00569, greedy_score=1.18e+3, sample_score=1.05e+3]
# Epoch [12/100]: 100%|██████████| 32/32 [00:23<00:00,  1.38it/s, loss=0.693, positive_reward=0.208, negative_reward=0.213, margin=-.00557, greedy_score=1.18e+3, sample_score=962]
# Epoch [13/100]: 100%|██████████| 32/32 [00:20<00:00,  1.55it/s, loss=0.693, positive_reward=0.586, negative_reward=0.576, margin=0.0102, greedy_score=1.17e+3, sample_score=1.1e+3]
# Epoch [14/100]: 100%|██████████| 32/32 [00:19<00:00,  1.63it/s, loss=0.692, positive_reward=0.653, negative_reward=0.63, margin=0.0232, greedy_score=1.17e+3, sample_score=1.03e+3]
# Epoch [15/100]: 100%|██████████| 32/32 [00:18<00:00,  1.75it/s, loss=0.693, positive_reward=0.56, negative_reward=0.561, margin=-.00122, greedy_score=1.18e+3, sample_score=1.12e+3]
# Epoch [16/100]: 100%|██████████| 32/32 [00:20<00:00,  1.58it/s, loss=0.693, positive_reward=0.294, negative_reward=0.29, margin=0.00361, greedy_score=1.19e+3, sample_score=1.08e+3]
# Epoch [17/100]: 100%|██████████| 32/32 [00:18<00:00,  1.73it/s, loss=0.691, positive_reward=0.432, negative_reward=0.396, margin=0.036, greedy_score=1.18e+3, sample_score=993]
# Epoch [18/100]: 100%|██████████| 32/32 [00:18<00:00,  1.74it/s, loss=0.692, positive_reward=0.462, negative_reward=0.442, margin=0.0202, greedy_score=1.18e+3, sample_score=1.17e+3]
# Epoch [19/100]: 100%|██████████| 32/32 [00:19<00:00,  1.60it/s, loss=0.693, positive_reward=0.563, negative_reward=0.567, margin=-.00428, greedy_score=1.19e+3, sample_score=1.09e+3]
# Epoch [20/100]: 100%|██████████| 32/32 [00:19<00:00,  1.61it/s, loss=0.692, positive_reward=0.275, negative_reward=0.259, margin=0.0157, greedy_score=1.19e+3, sample_score=1.03e+3]
# Epoch [21/100]: 100%|██████████| 32/32 [00:18<00:00,  1.72it/s, loss=0.693, positive_reward=0.517, negative_reward=0.519, margin=-.00208, greedy_score=1.18e+3, sample_score=1.06e+3]
# Epoch [22/100]: 100%|██████████| 32/32 [00:20<00:00,  1.53it/s, loss=0.693, positive_reward=0.0875, negative_reward=0.0837, margin=0.00376, greedy_score=1.18e+3, sample_score=1.14e+3]
# Epoch [23/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=0.693, positive_reward=0.707, negative_reward=0.696, margin=0.0109, greedy_score=1.19e+3, sample_score=1.12e+3]
# Epoch [24/100]: 100%|██████████| 32/32 [00:23<00:00,  1.38it/s, loss=0.693, positive_reward=0.366, negative_reward=0.359, margin=0.00733, greedy_score=1.2e+3, sample_score=1.13e+3]
# Epoch [25/100]: 100%|██████████| 32/32 [00:23<00:00,  1.39it/s, loss=0.695, positive_reward=0.401, negative_reward=0.431, margin=-.0307, greedy_score=1.18e+3, sample_score=1.06e+3]
# Epoch [26/100]: 100%|██████████| 32/32 [00:23<00:00,  1.36it/s, loss=0.693, positive_reward=0.333, negative_reward=0.331, margin=0.00264, greedy_score=1.21e+3, sample_score=1.21e+3]
# Epoch [27/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=0.693, positive_reward=0.337, negative_reward=0.337, margin=0.000222, greedy_score=1.21e+3, sample_score=1.02e+3]
# Epoch [28/100]: 100%|██████████| 32/32 [00:22<00:00,  1.42it/s, loss=0.693, positive_reward=0.641, negative_reward=0.634, margin=0.00697, greedy_score=1.17e+3, sample_score=1.07e+3]
# Epoch [29/100]: 100%|██████████| 32/32 [00:22<00:00,  1.41it/s, loss=0.694, positive_reward=0.327, negative_reward=0.336, margin=-.00872, greedy_score=1.21e+3, sample_score=994]
# Epoch [30/100]: 100%|██████████| 32/32 [00:24<00:00,  1.33it/s, loss=0.693, positive_reward=0.188, negative_reward=0.186, margin=0.00178, greedy_score=1.19e+3, sample_score=1.07e+3]
# Epoch [31/100]: 100%|██████████| 32/32 [00:23<00:00,  1.37it/s, loss=0.692, positive_reward=0.16, negative_reward=0.146, margin=0.0141, greedy_score=1.21e+3, sample_score=999]
# Epoch [32/100]: 100%|██████████| 32/32 [00:22<00:00,  1.42it/s, loss=0.693, positive_reward=0.579, negative_reward=0.578, margin=0.000799, greedy_score=1.18e+3, sample_score=1.12e+3]
# Epoch [33/100]: 100%|██████████| 32/32 [00:21<00:00,  1.46it/s, loss=0.693, positive_reward=0.326, negative_reward=0.327, margin=-.00123, greedy_score=1.19e+3, sample_score=952]
# Epoch [34/100]: 100%|██████████| 32/32 [00:24<00:00,  1.33it/s, loss=0.696, positive_reward=0.825, negative_reward=0.887, margin=-.0626, greedy_score=1.18e+3, sample_score=1.1e+3]
# Epoch [35/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=0.693, positive_reward=0.405, negative_reward=0.393, margin=0.0124, greedy_score=1.16e+3, sample_score=1.12e+3]
# Epoch [36/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.693, positive_reward=0.165, negative_reward=0.17, margin=-.0053, greedy_score=1.16e+3, sample_score=1.11e+3]
# Epoch [37/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.693, positive_reward=0.342, negative_reward=0.33, margin=0.0127, greedy_score=1.19e+3, sample_score=1.1e+3]
# Epoch [38/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.693, positive_reward=0.281, negative_reward=0.287, margin=-.00649, greedy_score=1.21e+3, sample_score=1.18e+3]
# Epoch [39/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.692, positive_reward=0.219, negative_reward=0.205, margin=0.0144, greedy_score=1.21e+3, sample_score=1.1e+3]
# Epoch [40/100]: 100%|██████████| 32/32 [00:31<00:00,  1.02it/s, loss=0.694, positive_reward=0.465, negative_reward=0.476, margin=-.0114, greedy_score=1.18e+3, sample_score=1.11e+3]
# Epoch [41/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.694, positive_reward=0.398, negative_reward=0.407, margin=-.00927, greedy_score=1.21e+3, sample_score=1.07e+3]
# Epoch [42/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.693, positive_reward=0.415, negative_reward=0.411, margin=0.00413, greedy_score=1.19e+3, sample_score=1.12e+3]
# Epoch [43/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.693, positive_reward=0.21, negative_reward=0.211, margin=-.00126, greedy_score=1.2e+3, sample_score=931]
# Epoch [44/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.691, positive_reward=0.807, negative_reward=0.757, margin=0.05, greedy_score=1.19e+3, sample_score=1.11e+3]
# Epoch [45/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.693, positive_reward=0.368, negative_reward=0.363, margin=0.00514, greedy_score=1.19e+3, sample_score=1.08e+3]
# Epoch [46/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.696, positive_reward=0.337, negative_reward=0.385, margin=-.0485, greedy_score=1.2e+3, sample_score=1.11e+3]
# Epoch [47/100]: 100%|██████████| 32/32 [00:28<00:00,  1.11it/s, loss=0.692, positive_reward=0.623, negative_reward=0.6, margin=0.0223, greedy_score=1.17e+3, sample_score=999]
# Epoch [48/100]: 100%|██████████| 32/32 [00:29<00:00,  1.09it/s, loss=0.693, positive_reward=0.431, negative_reward=0.428, margin=0.00381, greedy_score=1.17e+3, sample_score=1.2e+3]
# Epoch [49/100]: 100%|██████████| 32/32 [00:29<00:00,  1.09it/s, loss=0.695, positive_reward=0.484, negative_reward=0.513, margin=-.0297, greedy_score=1.19e+3, sample_score=1.12e+3]
# Epoch [50/100]: 100%|██████████| 32/32 [00:29<00:00,  1.09it/s, loss=0.694, positive_reward=0.259, negative_reward=0.27, margin=-.0103, greedy_score=1.19e+3, sample_score=1.02e+3]
# Epoch [51/100]: 100%|██████████| 32/32 [00:31<00:00,  1.02it/s, loss=0.691, positive_reward=0.804, negative_reward=0.77, margin=0.0345, greedy_score=1.2e+3, sample_score=1.16e+3]
# Epoch [52/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.693, positive_reward=0.414, negative_reward=0.41, margin=0.00406, greedy_score=1.17e+3, sample_score=1.1e+3]
# Epoch [53/100]: 100%|██████████| 32/32 [00:31<00:00,  1.03it/s, loss=0.692, positive_reward=0.58, negative_reward=0.552, margin=0.0274, greedy_score=1.23e+3, sample_score=982]
# Epoch [54/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.694, positive_reward=0.576, negative_reward=0.591, margin=-.0153, greedy_score=1.22e+3, sample_score=1.1e+3]
# Epoch [55/100]: 100%|██████████| 32/32 [00:30<00:00,  1.03it/s, loss=0.694, positive_reward=0.251, negative_reward=0.269, margin=-.0184, greedy_score=1.14e+3, sample_score=968]
# Epoch [56/100]: 100%|██████████| 32/32 [00:28<00:00,  1.13it/s, loss=0.694, positive_reward=0.541, negative_reward=0.556, margin=-.0152, greedy_score=1.22e+3, sample_score=1e+3]
# Epoch [57/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.694, positive_reward=0.295, negative_reward=0.308, margin=-.0132, greedy_score=1.21e+3, sample_score=1.05e+3]
# Epoch [58/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.693, positive_reward=0.722, negative_reward=0.724, margin=-.00176, greedy_score=1.24e+3, sample_score=1.07e+3]
# Epoch [59/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.693, positive_reward=0.3, negative_reward=0.301, margin=-.000519, greedy_score=1.18e+3, sample_score=1.01e+3]
# Epoch [60/100]: 100%|██████████| 32/32 [00:27<00:00,  1.14it/s, loss=0.693, positive_reward=0.416, negative_reward=0.406, margin=0.00959, greedy_score=1.23e+3, sample_score=989]
# Epoch [61/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.694, positive_reward=0.443, negative_reward=0.469, margin=-.0257, greedy_score=1.23e+3, sample_score=1.08e+3]
# Epoch [62/100]: 100%|██████████| 32/32 [00:28<00:00,  1.13it/s, loss=0.693, positive_reward=0.689, negative_reward=0.686, margin=0.00252, greedy_score=1.2e+3, sample_score=957]
# Epoch [63/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.693, positive_reward=0.593, negative_reward=0.597, margin=-.00465, greedy_score=1.27e+3, sample_score=1.18e+3]
# Epoch [64/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.693, positive_reward=0.396, negative_reward=0.397, margin=-.000678, greedy_score=1.3e+3, sample_score=991]
# Epoch [65/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.696, positive_reward=0.442, negative_reward=0.5, margin=-.0575, greedy_score=1.2e+3, sample_score=933]
# Epoch [66/100]: 100%|██████████| 32/32 [00:29<00:00,  1.09it/s, loss=0.693, positive_reward=0.516, negative_reward=0.51, margin=0.00562, greedy_score=1.26e+3, sample_score=1.09e+3]
# Epoch [67/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.693, positive_reward=0.449, negative_reward=0.451, margin=-.00187, greedy_score=1.27e+3, sample_score=1.02e+3]
# Epoch [68/100]: 100%|██████████| 32/32 [00:30<00:00,  1.07it/s, loss=0.694, positive_reward=0.672, negative_reward=0.686, margin=-.0142, greedy_score=1.2e+3, sample_score=1.18e+3]
# Epoch [69/100]: 100%|██████████| 32/32 [00:29<00:00,  1.10it/s, loss=0.692, positive_reward=0.426, negative_reward=0.396, margin=0.0301, greedy_score=1.26e+3, sample_score=1.13e+3]
# Epoch [70/100]: 100%|██████████| 32/32 [00:30<00:00,  1.03it/s, loss=0.693, positive_reward=0.773, negative_reward=0.771, margin=0.00191, greedy_score=1.25e+3, sample_score=1.22e+3]
# Epoch [71/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.693, positive_reward=0.599, negative_reward=0.597, margin=0.00129, greedy_score=1.19e+3, sample_score=1.05e+3]
# Epoch [72/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.693, positive_reward=0.635, negative_reward=0.633, margin=0.0022, greedy_score=1.25e+3, sample_score=1.02e+3]
# Epoch [73/100]: 100%|██████████| 32/32 [00:28<00:00,  1.13it/s, loss=0.694, positive_reward=0.186, negative_reward=0.205, margin=-.0191, greedy_score=1.28e+3, sample_score=1.19e+3]
# Epoch [74/100]: 100%|██████████| 32/32 [00:31<00:00,  1.01it/s, loss=0.694, positive_reward=0.611, negative_reward=0.636, margin=-.0259, greedy_score=1.24e+3, sample_score=985]
# Epoch [75/100]: 100%|██████████| 32/32 [00:27<00:00,  1.15it/s, loss=0.697, positive_reward=0.405, negative_reward=0.473, margin=-.0673, greedy_score=1.25e+3, sample_score=1.01e+3]
# Epoch [76/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.693, positive_reward=0.805, negative_reward=0.806, margin=-.00123, greedy_score=1.29e+3, sample_score=1.03e+3]
# Epoch [77/100]: 100%|██████████| 32/32 [00:27<00:00,  1.16it/s, loss=0.695, positive_reward=0.667, negative_reward=0.697, margin=-.0303, greedy_score=1.2e+3, sample_score=992]
# Epoch [78/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.693, positive_reward=0.704, negative_reward=0.698, margin=0.00516, greedy_score=1.25e+3, sample_score=1.19e+3]
# Epoch [79/100]: 100%|██████████| 32/32 [00:28<00:00,  1.13it/s, loss=0.693, positive_reward=0.236, negative_reward=0.232, margin=0.00406, greedy_score=1.28e+3, sample_score=1.16e+3]
# Epoch [80/100]: 100%|██████████| 32/32 [00:29<00:00,  1.09it/s, loss=0.695, positive_reward=0.639, negative_reward=0.667, margin=-.0277, greedy_score=1.23e+3, sample_score=1.02e+3]
# Epoch [81/100]: 100%|██████████| 32/32 [00:28<00:00,  1.11it/s, loss=0.693, positive_reward=0.4, negative_reward=0.398, margin=0.00195, greedy_score=1.26e+3, sample_score=1.19e+3]
# Epoch [82/100]: 100%|██████████| 32/32 [00:28<00:00,  1.13it/s, loss=0.694, positive_reward=0.372, negative_reward=0.395, margin=-.0228, greedy_score=1.27e+3, sample_score=1.14e+3]
# Epoch [83/100]: 100%|██████████| 32/32 [00:29<00:00,  1.09it/s, loss=0.693, positive_reward=0.295, negative_reward=0.296, margin=-.00114, greedy_score=1.21e+3, sample_score=1.11e+3]
# Epoch [84/100]: 100%|██████████| 32/32 [00:30<00:00,  1.07it/s, loss=0.694, positive_reward=0.117, negative_reward=0.124, margin=-.00706, greedy_score=1.26e+3, sample_score=1.04e+3]
# Epoch [85/100]: 100%|██████████| 32/32 [00:28<00:00,  1.13it/s, loss=0.693, positive_reward=0.629, negative_reward=0.618, margin=0.0112, greedy_score=1.19e+3, sample_score=1.07e+3]
# Epoch [86/100]: 100%|██████████| 32/32 [00:30<00:00,  1.07it/s, loss=0.693, positive_reward=0.809, negative_reward=0.807, margin=0.00199, greedy_score=1.21e+3, sample_score=1.09e+3]
# Epoch [87/100]: 100%|██████████| 32/32 [00:30<00:00,  1.07it/s, loss=0.692, positive_reward=0.462, negative_reward=0.44, margin=0.0218, greedy_score=1.19e+3, sample_score=1.19e+3]
# Epoch [88/100]: 100%|██████████| 32/32 [00:30<00:00,  1.07it/s, loss=0.694, positive_reward=1.02, negative_reward=1.04, margin=-.0268, greedy_score=1.24e+3, sample_score=1.16e+3]
# Epoch [89/100]: 100%|██████████| 32/32 [00:29<00:00,  1.09it/s, loss=0.693, positive_reward=0.411, negative_reward=0.416, margin=-.00506, greedy_score=1.22e+3, sample_score=1.08e+3]
# Epoch [90/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.693, positive_reward=0.695, negative_reward=0.69, margin=0.00504, greedy_score=1.29e+3, sample_score=1.06e+3]
# Epoch [91/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.695, positive_reward=0.275, negative_reward=0.306, margin=-.0319, greedy_score=1.39e+3, sample_score=1.15e+3]
# Epoch [92/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.694, positive_reward=0.139, negative_reward=0.158, margin=-.019, greedy_score=1.35e+3, sample_score=1.06e+3]
# Epoch [93/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.693, positive_reward=0.509, negative_reward=0.496, margin=0.0125, greedy_score=1.24e+3, sample_score=1.26e+3]
# Epoch [94/100]: 100%|██████████| 32/32 [00:28<00:00,  1.11it/s, loss=0.693, positive_reward=0.236, negative_reward=0.238, margin=-.00153, greedy_score=1.19e+3, sample_score=1.15e+3]
# Epoch [95/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.694, positive_reward=0.572, negative_reward=0.587, margin=-.0146, greedy_score=1.26e+3, sample_score=1.14e+3]
# Epoch [96/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.693, positive_reward=0.236, negative_reward=0.227, margin=0.00867, greedy_score=1.26e+3, sample_score=1.06e+3]
# Epoch [97/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.695, positive_reward=0.207, negative_reward=0.245, margin=-.0377, greedy_score=1.32e+3, sample_score=1.04e+3]
# Epoch [98/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.695, positive_reward=0.711, negative_reward=0.748, margin=-.0371, greedy_score=1.17e+3, sample_score=998]
# Epoch [99/100]: 100%|██████████| 32/32 [00:28<00:00,  1.14it/s, loss=0.692, positive_reward=0.426, negative_reward=0.408, margin=0.0174, greedy_score=1.27e+3, sample_score=1.09e+3]
# Epoch [100/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.693, positive_reward=0.322, negative_reward=0.316, margin=0.00585, greedy_score=1.23e+3, sample_score=1.14e+3]

# %%
# save all png to /mnt/nfs/work/albertliu/RL/CartPole-v1/DPO

# draw the loss graph
import matplotlib.pyplot as plt
plt.plot(loss_graph)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss vs Iteration")
# plt.savefig("./loss.png")

plt.show()



# draw the reward graph
plt.plot(greedy_rewards)
plt.xlabel("Iteration")
plt.ylabel("Greedy Reward")
plt.title("Greedy Reward vs Iteration")
# plt.savefig("./greedy_reward.png")
plt.show()

# draw the reward graph
plt.plot(sample_rewards)
plt.xlabel("Iteration")
plt.ylabel("Sample Reward")
plt.title("Sample Reward vs Iteration")
# plt.savefig("./sample_reward.png")
plt.show()


# drqw the margin graph
plt.plot(margin_graph)
plt.xlabel("Iteration")
plt.ylabel("Margin")
plt.title("Margin vs Iteration")
# plt.savefig("./margin.png")
plt.show()

# draw the positive reward graph
plt.plot(positive_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Positive Reward")
plt.title("Positive Reward vs Iteration")
# plt.savefig("./positive_reward.png")
plt.show()

# draw the negative reward graph
plt.plot(negative_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Negative Reward")
# plt.title("Negative Reward vs Iteration")

plt.savefig("./negative_reward.png")
plt.show()

# %%
# from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
# from stable_baselines3.common.vec_env import VecEnv
# import gymnasium as gym
# from imitation.policies.serialize import load_policy
# from imitation.util.util import make_vec_env
# import numpy as np
# import torch
# import os

# # 创建环境
# env = make_vec_env(
#     "seals:seals/Walker2d-v1",
#     rng=np.random.default_rng(),
#     n_envs=1,
#     env_make_kwargs={"render_mode": "rgb_array"},
# )

# # 使用 VecVideoRecorder 包装环境以启用视频记录，指定视频保存的路径
# video_folder = './videos'
# video_length = 200  # 设置视频长度
# env = VecVideoRecorder(env, video_folder,
#                        record_video_trigger=lambda step: step == 0, video_length=video_length,
#                        name_prefix="Walker2d-video")

# # 创建模型，这里以从 Hugging Face 加载预训练的 PPO 模型为例
# model = load_policy(
#     "ppo-huggingface",
#     organization="HumanCompatibleAI",
#     env_name="seals/Walker2d-v1",
#     venv=env,
# )

# # 训练模型
# # 注意: 此处假定模型已经预训练，无需再次训练

# # 测试模型，生成视频
# obs = env.reset()
# done = False
# while not done:
#     action, _states = model.predict(obs, deterministic=True)
#     obs, rewards, dones, info = env.step(action)
#     done = dones.any()

# env.close()

# # 如果需要手动保存视频（有时候视频不会在关闭时自动保存）
# env.record_video_trigger(video_length)
