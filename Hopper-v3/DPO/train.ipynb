# %%
import gymnasium as gym
import numpy as np
from stable_baselines3.common.env_util import make_vec_env as make_vec_env_sb3
from copy import deepcopy
import torch
from torch.distributions import Normal,MultivariateNormal
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.utils.data import Dataset, DataLoader
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
import imageio
import pandas as pd
from tqdm import tqdm
from PIL import Image
from stable_baselines3.dqn.policies import MlpPolicy
import matplotlib.pyplot as plt
import os

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !nvidia-smi
# clean up memory forcefully
torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# Mon May 13 00:52:11 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  | 00000000:01:00.0 Off |                  N/A |
# | 17%   56C    P2              90W / 250W |   3304MiB / 11264MiB |     96%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    228304      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    229850      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    277377      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    280712      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    319688      C   ...iu/miniconda3/envs/myenv/bin/python      300MiB |
# |    0   N/A  N/A    328416      C   ...iu/miniconda3/envs/myenv/bin/python      204MiB |
# |    0   N/A  N/A    377684      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   1475780      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   2544023      C   ...u/miniconda3/envs/myenv2/bin/python      184MiB |
# |    0   N/A  N/A   2546464      C   ...u/miniconda3/envs/myenv2/bin/python      192MiB |
# |    0   N/A  N/A   2573624      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2573704      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2584185      C   ...181/miniconda3/envs/copy/bin/python      194MiB |
# |    0   N/A  N/A   2587643      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2588031      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2591397    C+G   ...181/miniconda3/envs/copy/bin/python      217MiB |
# +---------------------------------------------------------------------------------------+
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
class CustomDataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32,device=device)
        self.actions = torch.tensor(actions, dtype=torch.float32,device=device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, output_dim,init_w=3e-3,log_std_min=-20,log_std_max=2):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 32)


        self.fc2 = nn.Linear(32, 32)
        self.log_std = nn.Linear(32, output_dim)
        self.mu=nn.Linear(32,output_dim)
        self.log_std_min=log_std_min
        self.log_std_max=log_std_max
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        torch.nn.init.kaiming_normal_(self.fc2.weight)
        self.mu.weight.data.uniform_(-init_w,init_w)
        self.mu.bias.data.uniform_(-init_w,init_w)
        self.log_std.weight.data.uniform_(-init_w,init_w)
        self.log_std.bias.data.uniform_(-init_w,init_w)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = self.mu(x) # Only apply if action bounds are [-1, 1]
        log_std = self.log_std(x)  # Ensure std is positive
        log_std=torch.clamp(log_std,self.log_std_min,self.log_std_max)

        return mu, log_std
# Out:
# Using device: cuda

# %%
# from imitation.util.util import make_vec_env

# observations= np.load("../dataset/obs.npy", allow_pickle=True)
# actions = np.load("../dataset/actions.npy", allow_pickle=True)

# observations=observations.squeeze()
# actions=actions.squeeze()

# print(observations.shape, actions.shape)
# print(observations[0], actions[0])
import pickle
import numpy as np
#　read /mnt/nfs/work/c98181/TDIL/saved_expert_transition/Walker2d-v3/sac/episode_num1_6123.pkl
# "states", "actions", "rewards", "next_states", "dones".
with open("/mnt/nfs/work/c98181/TDIL/saved_expert_transition/Hopper-v3/sac/episode_num1_4534.pkl", "rb") as f:
    data = pickle.load(f)

    obs_list = data["states"]
    actions_list = data["actions"]
    observations=np.array(obs_list)
    actions=np.array(actions_list)
    # shape
    print(observations.shape)
    print(actions.shape)

# env=gym.make("Walker2d-v3",exclude_current_positions_from_observation=False,render_mode="rgb_array")
env=gym.make("Hopper-v3",render_mode="rgb_array")
# Out:
# (1000, 11)
# (1000, 3)
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Hopper-v3 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_env.py:211: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(

# %%
class mydataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32).to(device)
        self.actions = torch.tensor(actions, dtype=torch.float32).to(device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

# %%
policy_network = PolicyNetwork(11,3).to(device)
prev = PolicyNetwork(11,3).to(device)
prev.load_state_dict(policy_network.state_dict())
prev.eval()

optimizer = torch.optim.Adam(policy_network.parameters(), lr=0.0003,weight_decay=1e-4)

# Training loop
num_epochs = 100
batch_size = 32

dataset = mydataset(observations=observations, actions=actions)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

loss_graph=[]
greedy_rewards=[]
sample_rewards=[]
margin_graph=[]
positive_reward_graph=[]
negative_reward_graph=[]
log_interval = len(observations)//1
num_test = 10
now_log=0
now_pos=0
greedy_score=0
sample_score=0
for epoch in range(num_epochs):
    policy_network.train()

    # Compute the log probabilities of the actions
    pbar=tqdm(dataloader,position=0,leave=True)
    now_log=0

    for step, (obs_batch,act_batch) in enumerate(pbar):
        # obs_batch = torch.tensor(np.array(obs_batch), dtype=torch.float32).to(device)
        # act_batch = torch.tensor(np.array(act_batch), dtype=torch.float32).to(device)

        now_log+=obs_batch.shape[0]
        now_pos+=obs_batch.shape[0]
        
        mu, log_std = policy_network(obs_batch)
        std=log_std.exp()
        dist = Normal(mu, std)
        z_model=dist.rsample()
        model_action=torch.tanh(z_model)
        z_expert=torch.atanh(torch.clamp(act_batch, -0.999999, 0.999999))
        epsilon=1e-6


        policy_rejected_logps =dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
        policy_chosen_logps = dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        with torch.no_grad():
          prev_mu, prev_log_std = prev(obs_batch)
          prev_std=prev_log_std.exp()
          prev_dist = Normal(prev_mu, prev_std)

          reference_rejected_logps =prev_dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
          reference_chosen_logps = prev_dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        pi_logratios = policy_chosen_logps - policy_rejected_logps
        ref_logratios = reference_chosen_logps - reference_rejected_logps

        chosen_KL = (policy_chosen_logps - reference_chosen_logps).mean().clamp(min=0)
        reject_KL = (policy_rejected_logps - reference_rejected_logps).mean().clamp(min=0)

       

        chosen_logratios = policy_chosen_logps - reference_chosen_logps
        reject_logratios = policy_rejected_logps - reference_rejected_logps

        # logits = chosen_logratios - reject_logratios

        if epoch < -1:
          loss = - (policy_chosen_logps).mean()
        else:
          beta = 1
          losses=torch.pow(chosen_logratios-0.5,2)+torch.pow(reject_logratios+0.5,2)
          loss = losses.mean()
        #   losses = torch.cat((1 - F.logsigmoid(beta * (chosen_logratios - reject_KL)), 1 - F.logsigmoid(beta * (chosen_KL - reject_logratios))), 0)
        #   loss = losses.mean()
        # Optimize the policy
        optimizer.zero_grad()



        loss.backward()

        optimizer.step()
        pbar.set_description((f"Epoch [{epoch+1}/{num_epochs}]"))
        positive_reward = pi_logratios.detach().mean().item()
        negative_reward = ref_logratios.detach().mean().item()
        margin = positive_reward - negative_reward
        loss_graph.append(loss.detach().item())
        margin_graph.append(margin)
        positive_reward_graph.append(positive_reward)
        negative_reward_graph.append(negative_reward)



        total_reward=0
        if now_log>=log_interval:
            now_log-=log_interval
            
            policy_network.eval()  # 切换到评估模式

            

            total_reward=0
            # test the policy and save as the first test as gif
            # frames = []
            for _ in range(num_test):
                state,_ = env.reset()
                done = False

                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(mu)   
                        action.squeeze_()

                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/greedy/"+image_path, frames)

            greedy_score=total_reward/num_test
            total_reward=0
            frames = []
            # test the policy and save as the first test as gif
            for _ in range(num_test):
                state,_ = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(Normal(mu,std).sample())
                        action.squeeze_()
                       
                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/sample/"+image_path, frames)

            sample_score=total_reward/num_test
            greedy_rewards.append(greedy_score)
            sample_rewards.append(sample_score)
            policy_network.train()  # 切换回训练模式
        pbar.set_postfix({"loss":loss.detach().item(), "positive_reward": positive_reward, "negative_reward": negative_reward, "margin": positive_reward - negative_reward,"greedy_score":greedy_score,"sample_score":sample_score})
    # prev.load_state_dict(policy_network.state_dict())
    # prev.eval()
         

env.close()
# Out:
# Epoch [1/100]:  72%|███████▏  | 23/32 [00:00<00:00, 54.64it/s, loss=0.42, positive_reward=0.131, negative_reward=-.0165, margin=0.147, greedy_score=0, sample_score=0]    /tmp/ipykernel_2594108/1387221882.py:117: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025847094/work/torch/csrc/utils/tensor_new.cpp:275.)
#   state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
# Epoch [1/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.424, positive_reward=0.185, negative_reward=0.0584, margin=0.126, greedy_score=972, sample_score=827]
# Epoch [2/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.4, positive_reward=0.0377, negative_reward=-.102, margin=0.14, greedy_score=1.17e+3, sample_score=944]
# Epoch [3/100]: 100%|██████████| 32/32 [00:26<00:00,  1.19it/s, loss=0.465, positive_reward=-.0191, negative_reward=-.0816, margin=0.0626, greedy_score=1.13e+3, sample_score=945]
# Epoch [4/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.446, positive_reward=0.0414, negative_reward=-.0955, margin=0.137, greedy_score=1.17e+3, sample_score=863]
# Epoch [5/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.422, positive_reward=0.0749, negative_reward=-.0997, margin=0.175, greedy_score=1.17e+3, sample_score=927]
# Epoch [6/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.366, positive_reward=0.196, negative_reward=-.00363, margin=0.2, greedy_score=1.1e+3, sample_score=1.02e+3]
# Epoch [7/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.355, positive_reward=0.245, negative_reward=0.028, margin=0.217, greedy_score=1.17e+3, sample_score=988]
# Epoch [8/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.456, positive_reward=0.151, negative_reward=0.0167, margin=0.135, greedy_score=1.17e+3, sample_score=1.01e+3]
# Epoch [9/100]: 100%|██████████| 32/32 [00:25<00:00,  1.28it/s, loss=0.443, positive_reward=-.0129, negative_reward=-.112, margin=0.0996, greedy_score=1.17e+3, sample_score=918]
# Epoch [10/100]: 100%|██████████| 32/32 [00:21<00:00,  1.50it/s, loss=0.399, positive_reward=0.224, negative_reward=0.0166, margin=0.207, greedy_score=1.17e+3, sample_score=959]
# Epoch [11/100]: 100%|██████████| 32/32 [00:22<00:00,  1.45it/s, loss=0.414, positive_reward=0.07, negative_reward=-.106, margin=0.176, greedy_score=1.17e+3, sample_score=963]
# Epoch [12/100]: 100%|██████████| 32/32 [00:24<00:00,  1.32it/s, loss=0.454, positive_reward=0.0264, negative_reward=-.0574, margin=0.0837, greedy_score=1.17e+3, sample_score=946]
# Epoch [13/100]: 100%|██████████| 32/32 [00:23<00:00,  1.38it/s, loss=0.487, positive_reward=0.154, negative_reward=-.0171, margin=0.171, greedy_score=1.17e+3, sample_score=941]
# Epoch [14/100]: 100%|██████████| 32/32 [00:17<00:00,  1.86it/s, loss=0.455, positive_reward=0.0505, negative_reward=-.0692, margin=0.12, greedy_score=1.17e+3, sample_score=953]
# Epoch [15/100]: 100%|██████████| 32/32 [00:17<00:00,  1.83it/s, loss=0.427, positive_reward=0.13, negative_reward=-.0278, margin=0.158, greedy_score=1.17e+3, sample_score=966]
# Epoch [16/100]: 100%|██████████| 32/32 [00:21<00:00,  1.51it/s, loss=0.455, positive_reward=0.0739, negative_reward=-.0388, margin=0.113, greedy_score=1.17e+3, sample_score=811]
# Epoch [17/100]: 100%|██████████| 32/32 [00:17<00:00,  1.81it/s, loss=0.379, positive_reward=0.228, negative_reward=-.0123, margin=0.24, greedy_score=1.17e+3, sample_score=940]
# Epoch [18/100]: 100%|██████████| 32/32 [00:19<00:00,  1.67it/s, loss=0.416, positive_reward=0.185, negative_reward=-.0288, margin=0.214, greedy_score=1.17e+3, sample_score=938]
# Epoch [19/100]: 100%|██████████| 32/32 [00:19<00:00,  1.65it/s, loss=0.421, positive_reward=0.15, negative_reward=0.00703, margin=0.143, greedy_score=1.17e+3, sample_score=990]
# Epoch [20/100]: 100%|██████████| 32/32 [00:19<00:00,  1.67it/s, loss=0.475, positive_reward=0.124, negative_reward=0.0467, margin=0.0774, greedy_score=1.17e+3, sample_score=868]
# Epoch [21/100]: 100%|██████████| 32/32 [00:20<00:00,  1.56it/s, loss=0.403, positive_reward=0.132, negative_reward=-.0483, margin=0.18, greedy_score=1.17e+3, sample_score=924]
# Epoch [22/100]: 100%|██████████| 32/32 [00:21<00:00,  1.46it/s, loss=0.394, positive_reward=0.258, negative_reward=0.0731, margin=0.185, greedy_score=1.17e+3, sample_score=1.01e+3]
# Epoch [23/100]: 100%|██████████| 32/32 [00:23<00:00,  1.35it/s, loss=0.426, positive_reward=0.119, negative_reward=-.00682, margin=0.125, greedy_score=1.17e+3, sample_score=860]
# Epoch [24/100]: 100%|██████████| 32/32 [00:22<00:00,  1.42it/s, loss=0.455, positive_reward=0.174, negative_reward=0.00848, margin=0.166, greedy_score=1.17e+3, sample_score=956]
# Epoch [25/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=0.411, positive_reward=0.117, negative_reward=-.0265, margin=0.143, greedy_score=1.17e+3, sample_score=888]
# Epoch [26/100]: 100%|██████████| 32/32 [00:20<00:00,  1.53it/s, loss=0.423, positive_reward=0.0949, negative_reward=-.0435, margin=0.138, greedy_score=1.17e+3, sample_score=895]
# Epoch [27/100]: 100%|██████████| 32/32 [00:21<00:00,  1.47it/s, loss=0.423, positive_reward=0.151, negative_reward=0.000469, margin=0.151, greedy_score=1.17e+3, sample_score=901]
# Epoch [28/100]: 100%|██████████| 32/32 [00:23<00:00,  1.38it/s, loss=0.424, positive_reward=0.136, negative_reward=-.0103, margin=0.146, greedy_score=1.17e+3, sample_score=942]
# Epoch [29/100]: 100%|██████████| 32/32 [00:24<00:00,  1.33it/s, loss=0.472, positive_reward=0.111, negative_reward=0.0137, margin=0.0975, greedy_score=1.17e+3, sample_score=953]
# Epoch [30/100]: 100%|██████████| 32/32 [00:23<00:00,  1.39it/s, loss=0.433, positive_reward=0.124, negative_reward=-.0111, margin=0.136, greedy_score=1.18e+3, sample_score=936]
# Epoch [31/100]: 100%|██████████| 32/32 [00:23<00:00,  1.35it/s, loss=0.406, positive_reward=0.103, negative_reward=-.0739, margin=0.177, greedy_score=1.18e+3, sample_score=911]
# Epoch [32/100]: 100%|██████████| 32/32 [00:23<00:00,  1.37it/s, loss=0.366, positive_reward=0.0753, negative_reward=-.152, margin=0.227, greedy_score=1.17e+3, sample_score=976]
# Epoch [33/100]: 100%|██████████| 32/32 [00:23<00:00,  1.36it/s, loss=0.422, positive_reward=0.116, negative_reward=-.0265, margin=0.143, greedy_score=1.18e+3, sample_score=946]
# Epoch [34/100]: 100%|██████████| 32/32 [00:23<00:00,  1.37it/s, loss=0.399, positive_reward=0.198, negative_reward=0.00205, margin=0.196, greedy_score=1.17e+3, sample_score=1.04e+3]
# Epoch [35/100]: 100%|██████████| 32/32 [00:23<00:00,  1.34it/s, loss=0.474, positive_reward=0.0965, negative_reward=-.0153, margin=0.112, greedy_score=1.18e+3, sample_score=922]
# Epoch [36/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.4, positive_reward=0.164, negative_reward=-.0136, margin=0.178, greedy_score=1.17e+3, sample_score=890]
# Epoch [37/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.445, positive_reward=0.137, negative_reward=0.00798, margin=0.129, greedy_score=1.17e+3, sample_score=929]
# Epoch [38/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.437, positive_reward=0.0165, negative_reward=-.126, margin=0.142, greedy_score=1.18e+3, sample_score=971]
# Epoch [39/100]: 100%|██████████| 32/32 [00:31<00:00,  1.01it/s, loss=0.403, positive_reward=0.12, negative_reward=-.0376, margin=0.157, greedy_score=1.18e+3, sample_score=964]
# Epoch [40/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.425, positive_reward=0.0959, negative_reward=-.0408, margin=0.137, greedy_score=1.18e+3, sample_score=886]
# Epoch [41/100]: 100%|██████████| 32/32 [00:31<00:00,  1.03it/s, loss=0.445, positive_reward=0.165, negative_reward=0.0454, margin=0.12, greedy_score=1.17e+3, sample_score=1e+3]
# Epoch [42/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.508, positive_reward=-.0535, negative_reward=-.0891, margin=0.0356, greedy_score=1.17e+3, sample_score=882]
# Epoch [43/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.429, positive_reward=0.0737, negative_reward=-.0678, margin=0.141, greedy_score=1.17e+3, sample_score=949]
# Epoch [44/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.422, positive_reward=0.0851, negative_reward=-.0601, margin=0.145, greedy_score=1.18e+3, sample_score=938]
# Epoch [45/100]: 100%|██████████| 32/32 [00:31<00:00,  1.01it/s, loss=0.386, positive_reward=0.186, negative_reward=-.031, margin=0.217, greedy_score=1.18e+3, sample_score=902]
# Epoch [46/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.364, positive_reward=0.239, negative_reward=0.0243, margin=0.215, greedy_score=1.18e+3, sample_score=901]
# Epoch [47/100]: 100%|██████████| 32/32 [00:31<00:00,  1.02it/s, loss=0.436, positive_reward=0.0841, negative_reward=-.0412, margin=0.125, greedy_score=1.17e+3, sample_score=962]
# Epoch [48/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.402, positive_reward=0.188, negative_reward=0.0229, margin=0.165, greedy_score=1.17e+3, sample_score=941]
# Epoch [49/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.356, positive_reward=0.115, negative_reward=-.109, margin=0.224, greedy_score=1.18e+3, sample_score=953]
# Epoch [50/100]: 100%|██████████| 32/32 [00:28<00:00,  1.11it/s, loss=0.387, positive_reward=0.145, negative_reward=-.0563, margin=0.201, greedy_score=1.17e+3, sample_score=937]
# Epoch [51/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.425, positive_reward=0.0519, negative_reward=-.0795, margin=0.131, greedy_score=1.17e+3, sample_score=962]
# Epoch [52/100]: 100%|██████████| 32/32 [00:27<00:00,  1.17it/s, loss=0.447, positive_reward=0.14, negative_reward=0.00531, margin=0.134, greedy_score=1.17e+3, sample_score=966]
# Epoch [53/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.438, positive_reward=0.138, negative_reward=0.000207, margin=0.138, greedy_score=1.17e+3, sample_score=924]
# Epoch [54/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.418, positive_reward=0.0243, negative_reward=-.144, margin=0.168, greedy_score=1.17e+3, sample_score=984]
# Epoch [55/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.417, positive_reward=0.116, negative_reward=-.0498, margin=0.165, greedy_score=1.17e+3, sample_score=968]
# Epoch [56/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.452, positive_reward=-.000167, negative_reward=-.0944, margin=0.0942, greedy_score=1.17e+3, sample_score=875]
# Epoch [57/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.434, positive_reward=0.118, negative_reward=-.0406, margin=0.158, greedy_score=1.17e+3, sample_score=923]
# Epoch [58/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.452, positive_reward=0.0907, negative_reward=-.0167, margin=0.107, greedy_score=1.17e+3, sample_score=982]
# Epoch [59/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.419, positive_reward=0.122, negative_reward=-.0711, margin=0.193, greedy_score=1.17e+3, sample_score=940]
# Epoch [60/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.445, positive_reward=0.0911, negative_reward=-.0218, margin=0.113, greedy_score=1.17e+3, sample_score=1.01e+3]
# Epoch [61/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.416, positive_reward=0.122, negative_reward=-.0245, margin=0.147, greedy_score=1.17e+3, sample_score=955]
# Epoch [62/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.341, positive_reward=0.165, negative_reward=-.0888, margin=0.254, greedy_score=1.17e+3, sample_score=1.05e+3]
# Epoch [63/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.435, positive_reward=0.134, negative_reward=0.0246, margin=0.109, greedy_score=1.18e+3, sample_score=965]
# Epoch [64/100]: 100%|██████████| 32/32 [00:29<00:00,  1.10it/s, loss=0.458, positive_reward=0.145, negative_reward=0.0474, margin=0.0976, greedy_score=1.17e+3, sample_score=863]
# Epoch [65/100]: 100%|██████████| 32/32 [00:29<00:00,  1.10it/s, loss=0.408, positive_reward=0.248, negative_reward=0.0852, margin=0.163, greedy_score=1.17e+3, sample_score=967]
# Epoch [66/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.449, positive_reward=0.0226, negative_reward=-.13, margin=0.153, greedy_score=1.17e+3, sample_score=967]
# Epoch [67/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.494, positive_reward=0.0859, negative_reward=-.00483, margin=0.0907, greedy_score=1.17e+3, sample_score=1.01e+3]
# Epoch [68/100]: 100%|██████████| 32/32 [00:32<00:00,  1.00s/it, loss=0.391, positive_reward=0.113, negative_reward=-.0516, margin=0.165, greedy_score=1.17e+3, sample_score=962]
# Epoch [69/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.437, positive_reward=0.0571, negative_reward=-.111, margin=0.168, greedy_score=1.17e+3, sample_score=924]
# Epoch [70/100]: 100%|██████████| 32/32 [00:30<00:00,  1.07it/s, loss=0.378, positive_reward=0.121, negative_reward=-.111, margin=0.232, greedy_score=1.17e+3, sample_score=919]
# Epoch [71/100]: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s, loss=0.453, positive_reward=0.12, negative_reward=0.00319, margin=0.117, greedy_score=1.17e+3, sample_score=945]
# Epoch [72/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.437, positive_reward=0.0695, negative_reward=-.064, margin=0.133, greedy_score=1.17e+3, sample_score=929]
# Epoch [73/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.434, positive_reward=0.0221, negative_reward=-.133, margin=0.155, greedy_score=1.17e+3, sample_score=964]
# Epoch [74/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.408, positive_reward=0.162, negative_reward=-.0187, margin=0.181, greedy_score=1.17e+3, sample_score=952]
# Epoch [75/100]: 100%|██████████| 32/32 [00:29<00:00,  1.10it/s, loss=0.442, positive_reward=0.122, negative_reward=0.0116, margin=0.11, greedy_score=1.17e+3, sample_score=1.06e+3]
# Epoch [76/100]: 100%|██████████| 32/32 [00:31<00:00,  1.02it/s, loss=0.478, positive_reward=-.00222, negative_reward=-.0723, margin=0.0701, greedy_score=1.17e+3, sample_score=938]
# Epoch [77/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.434, positive_reward=0.12, negative_reward=-.015, margin=0.135, greedy_score=1.17e+3, sample_score=900]
# Epoch [78/100]: 100%|██████████| 32/32 [00:31<00:00,  1.03it/s, loss=0.442, positive_reward=0.241, negative_reward=0.111, margin=0.13, greedy_score=1.17e+3, sample_score=946]
# Epoch [79/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.429, positive_reward=0.0442, negative_reward=-.0833, margin=0.127, greedy_score=1.17e+3, sample_score=1.02e+3]
# Epoch [80/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.492, positive_reward=0.0459, negative_reward=-.0337, margin=0.0796, greedy_score=1.17e+3, sample_score=965]
# Epoch [81/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.425, positive_reward=0.186, negative_reward=0.0554, margin=0.131, greedy_score=1.17e+3, sample_score=928]
# Epoch [82/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.437, positive_reward=0.0716, negative_reward=-.0825, margin=0.154, greedy_score=1.17e+3, sample_score=960]
# Epoch [83/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.438, positive_reward=0.19, negative_reward=0.0631, margin=0.127, greedy_score=1.17e+3, sample_score=1.04e+3]
# Epoch [84/100]: 100%|██████████| 32/32 [00:29<00:00,  1.09it/s, loss=0.409, positive_reward=0.0702, negative_reward=-.0934, margin=0.164, greedy_score=1.17e+3, sample_score=933]
# Epoch [85/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.44, positive_reward=0.143, negative_reward=0.00715, margin=0.136, greedy_score=1.17e+3, sample_score=1e+3]
# Epoch [86/100]: 100%|██████████| 32/32 [00:29<00:00,  1.08it/s, loss=0.414, positive_reward=0.209, negative_reward=0.023, margin=0.186, greedy_score=1.17e+3, sample_score=1.05e+3]
# Epoch [87/100]: 100%|██████████| 32/32 [00:31<00:00,  1.02it/s, loss=0.413, positive_reward=0.139, negative_reward=-.0145, margin=0.154, greedy_score=1.17e+3, sample_score=1.03e+3]
# Epoch [88/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.422, positive_reward=0.132, negative_reward=-.0176, margin=0.149, greedy_score=1.17e+3, sample_score=1.01e+3]
# Epoch [89/100]: 100%|██████████| 32/32 [00:31<00:00,  1.03it/s, loss=0.421, positive_reward=0.176, negative_reward=0.0392, margin=0.137, greedy_score=1.17e+3, sample_score=924]
# Epoch [90/100]: 100%|██████████| 32/32 [00:31<00:00,  1.02it/s, loss=0.44, positive_reward=0.113, negative_reward=-.0124, margin=0.125, greedy_score=1.17e+3, sample_score=990]
# Epoch [91/100]: 100%|██████████| 32/32 [00:29<00:00,  1.07it/s, loss=0.481, positive_reward=0.134, negative_reward=0.0555, margin=0.0785, greedy_score=1.17e+3, sample_score=1.02e+3]
# Epoch [92/100]: 100%|██████████| 32/32 [00:31<00:00,  1.03it/s, loss=0.42, positive_reward=0.142, negative_reward=0.00583, margin=0.136, greedy_score=1.17e+3, sample_score=897]
# Epoch [93/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.455, positive_reward=0.174, negative_reward=0.0145, margin=0.16, greedy_score=1.17e+3, sample_score=1.02e+3]
# Epoch [94/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.4, positive_reward=0.168, negative_reward=-.0665, margin=0.234, greedy_score=1.17e+3, sample_score=943]
# Epoch [95/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.449, positive_reward=0.19, negative_reward=0.0559, margin=0.134, greedy_score=1.18e+3, sample_score=1.07e+3]
# Epoch [96/100]: 100%|██████████| 32/32 [00:30<00:00,  1.06it/s, loss=0.451, positive_reward=0.162, negative_reward=0.0417, margin=0.12, greedy_score=1.17e+3, sample_score=937]
# Epoch [97/100]: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s, loss=0.389, positive_reward=0.329, negative_reward=0.0752, margin=0.254, greedy_score=1.17e+3, sample_score=981]
# Epoch [98/100]: 100%|██████████| 32/32 [00:29<00:00,  1.10it/s, loss=0.424, positive_reward=0.191, negative_reward=0.0134, margin=0.177, greedy_score=1.17e+3, sample_score=923]
# Epoch [99/100]: 100%|██████████| 32/32 [00:30<00:00,  1.04it/s, loss=0.434, positive_reward=0.117, negative_reward=-.0144, margin=0.131, greedy_score=1.17e+3, sample_score=918]
# Epoch [100/100]: 100%|██████████| 32/32 [00:26<00:00,  1.19it/s, loss=0.488, positive_reward=0.206, negative_reward=-.0181, margin=0.224, greedy_score=1.17e+3, sample_score=970]

# %%
# save all png to /mnt/nfs/work/albertliu/RL/CartPole-v1/DPO

# draw the loss graph
import matplotlib.pyplot as plt
plt.plot(loss_graph)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss vs Iteration")
plt.savefig("./loss.png")

plt.show()



# draw the reward graph
plt.plot(greedy_rewards)
plt.xlabel("Iteration")
plt.ylabel("Greedy Reward")
plt.title("Greedy Reward vs Iteration")
plt.savefig("./greedy_reward.png")
plt.show()

# draw the reward graph
plt.plot(sample_rewards)
plt.xlabel("Iteration")
plt.ylabel("Sample Reward")
plt.title("Sample Reward vs Iteration")
plt.savefig("./sample_reward.png")
plt.show()


# drqw the margin graph
plt.plot(margin_graph)
plt.xlabel("Iteration")
plt.ylabel("Margin")
plt.title("Margin vs Iteration")
plt.savefig("./margin.png")
plt.show()

# draw the positive reward graph
plt.plot(positive_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Positive Reward")
plt.title("Positive Reward vs Iteration")
plt.savefig("./positive_reward.png")
plt.show()

# draw the negative reward graph
plt.plot(negative_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Negative Reward")
plt.title("Negative Reward vs Iteration")

plt.savefig("./negative_reward.png")
plt.show()

# %%
# from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
# from stable_baselines3.common.vec_env import VecEnv
# import gymnasium as gym
# from imitation.policies.serialize import load_policy
# from imitation.util.util import make_vec_env
# import numpy as np
# import torch
# import os

# # 创建环境
# env = make_vec_env(
#     "seals:seals/Walker2d-v1",
#     rng=np.random.default_rng(),
#     n_envs=1,
#     env_make_kwargs={"render_mode": "rgb_array"},
# )

# # 使用 VecVideoRecorder 包装环境以启用视频记录，指定视频保存的路径
# video_folder = './videos'
# video_length = 200  # 设置视频长度
# env = VecVideoRecorder(env, video_folder,
#                        record_video_trigger=lambda step: step == 0, video_length=video_length,
#                        name_prefix="Walker2d-video")

# # 创建模型，这里以从 Hugging Face 加载预训练的 PPO 模型为例
# model = load_policy(
#     "ppo-huggingface",
#     organization="HumanCompatibleAI",
#     env_name="seals/Walker2d-v1",
#     venv=env,
# )

# # 训练模型
# # 注意: 此处假定模型已经预训练，无需再次训练

# # 测试模型，生成视频
# obs = env.reset()
# done = False
# while not done:
#     action, _states = model.predict(obs, deterministic=True)
#     obs, rewards, dones, info = env.step(action)
#     done = dones.any()

# env.close()

# # 如果需要手动保存视频（有时候视频不会在关闭时自动保存）
# env.record_video_trigger(video_length)
