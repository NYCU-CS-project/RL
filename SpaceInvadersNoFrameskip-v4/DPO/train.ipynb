# %%
# !pip install stable_baselines3==2.2.1
# !apt-get update
# !apt-get install -y python3-dev python3-pip python3-setuptools libswig-dev libpython3-dev libpython3-all-dev
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]

# %%
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.env_util import make_vec_env,make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
import os
env_id = "SpaceInvadersNoFrameskip-v4"
# get the current directory

# model_path = os.path.join(os.path.dirname(__file__), env_id+".zip")
# print(model_path)
import torch
from stable_baselines3.common.vec_env import VecTransposeImage, DummyVecEnv
from stable_baselines3.common.preprocessing import is_image_space
env = make_atari_env(env_id, n_envs=1)
env = VecTransposeImage(env)            # 确保图像通道在前

env=VecFrameStack(env, n_stack=4)

model = DQN("CnnPolicy", env, optimize_memory_usage=False, buffer_size=10)
model.policy.load_state_dict(torch.load("../dataset/policy.pth"))



print(model.policy)

import numpy as np
from tqdm import tqdm
obs = env.reset()
done = False
# sample 1M steps
n_steps = 100000
# num_episodes = 100

obs_list = []
next_obs_list = []
actions_list = []
rewards_list = []
dones_list = []
info_list = []
score_list=[]
reward_sum = 0
for i in tqdm(range(n_steps)):
    action, _states = model.predict(obs, deterministic=True)
    next_obs, reward, done, info = env.step(action)
    reward_sum += reward
    obs_list.append(obs)
    next_obs_list.append(next_obs)
    actions_list.append(action)
    rewards_list.append(reward)
    dones_list.append(done)
    info_list.append(info)
    obs = next_obs
    if done:
        obs = env.reset()
        score_list.append(reward_sum)
        reward_sum = 0

obs_list = np.array(obs_list)
actions_list = np.array(actions_list)
rewards_list = np.array(rewards_list)
dones_list = np.array(dones_list)
np.save(("obs.npy"), obs_list)
np.save(("actions.npy"), actions_list)
np.save(("rewards.npy"), rewards_list)
np.save(("dones.npy"), dones_list)
np.save(("info.npy"), info_list)
np.save(("next_obs.npy"), next_obs_list)

#　plot the score
import matplotlib.pyplot as plt
plt.plot(score_list)
plt.xlabel("Episodes")

plt.ylabel("Rewards")
plt.title("Rewards of sample on "+env_id)
plt.savefig("rewards.png")
plt.show()

# import agc.dataset as ds
# import agc.util as util

# # DATA_DIR is the directory, which contains the 'trajectories' and 'screens' folders
# dataset = ds.AtariDataset(DATA_DIR)


# # dataset.trajectories returns the dictionary with all the trajs from the dataset
# all_trajectories = dataset.trajectories
# Out:
# CnnPolicy(
#   (q_net): QNetwork(
#     (features_extractor): NatureCNN(
#       (cnn): Sequential(
#         (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#         (1): ReLU()
#         (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#         (3): ReLU()
#         (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         (5): ReLU()
#         (6): Flatten(start_dim=1, end_dim=-1)
#       )
#       (linear): Sequential(
#         (0): Linear(in_features=3136, out_features=512, bias=True)
#         (1): ReLU()
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=512, out_features=6, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): NatureCNN(
#       (cnn): Sequential(
#         (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#         (1): ReLU()
#         (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#         (3): ReLU()
#         (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         (5): ReLU()
#         (6): Flatten(start_dim=1, end_dim=-1)
#       )
#       (linear): Sequential(
#         (0): Linear(in_features=3136, out_features=512, bias=True)
#         (1): ReLU()
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=512, out_features=6, bias=True)
#     )
#   )
# )
# 100%|██████████| 100000/100000 [02:20<00:00, 714.21it/s]

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3.common.env_util import make_vec_env as make_vec_env_sb3
from copy import deepcopy
import torch
from torch.distributions import Normal
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.utils.data import Dataset, DataLoader
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
import imageio
import pandas as pd
from tqdm import tqdm
from PIL import Image
from stable_baselines3.dqn.policies import MlpPolicy
import matplotlib.pyplot as plt

# %%
import gc
gc.collect()
# Out:
# 3496

# %%
# !nvidia-smi
# clean up memory forcefully
torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# Mon Apr 15 13:36:50 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  | 00000000:01:00.0 Off |                  N/A |
# |  0%   47C    P8              17W / 250W |    220MiB / 11264MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A   2590786      C   ...181/miniconda3/envs/copy/bin/python      216MiB |
# +---------------------------------------------------------------------------------------+
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
class CustomDataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32,device=device)
        self.actions = torch.tensor(actions, dtype=torch.float32,device=device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

class PolicyNetwork(nn.Module):
    def __init__(self,  output_dim):
        super(PolicyNetwork, self).__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(3136, 512)
        self.fc2 = nn.Linear(512, output_dim)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.fc1(x.view(x.size(0), -1)))
        x = self.fc2(x)
        return x
# Out:
# Using device: cuda

# %%
from stable_baselines3.common.env_util import make_atari_env
env_id="SpaceInvadersNoFrameskip-v4"
#env = make_vec_env_sb3(env_id, n_envs=1)
observations= np.load("../dataset/obs.npy", allow_pickle=True)
actions = np.load("../dataset/actions.npy", allow_pickle=True)
rewards = np.load("../dataset/rewards.npy", allow_pickle=True)
dones = np.load("../dataset/dones.npy", allow_pickle=True)
info = np.load("../dataset/info.npy", allow_pickle=True)
next_obs = np.load("../dataset/next_obs.npy", allow_pickle=True)
observations=observations.squeeze()
actions=actions.squeeze()
rewards=rewards.squeeze()
dones=dones.squeeze()
info=info.squeeze()
next_obs=next_obs.squeeze()
# observations = observations[:1000]
# actions = actions[:1000]
print(observations.shape, actions.shape, rewards.shape, dones.shape, info.shape, next_obs.shape)
# print(observations[0], actions[0], rewards[0], dones[0], info[0], next_obs[0])
print(info[0])
env = make_atari_env(env_id, n_envs=1)
from stable_baselines3.common.vec_env import VecFrameStack, VecTransposeImage
env = VecTransposeImage(env)            # 确保图像通道在前
env = VecFrameStack(env, n_stack=4)     # 堆叠4帧
obs = env.reset()
print(obs.shape)

# print(env.action_space.n)
# print(env.observation_space.shape[0])
# Out:
# (100000, 4, 84, 84) (100000,) (100000,) (100000,) (100000,) (100000, 4, 84, 84)
# {'lives': 3, 'episode_frame_number': 34, 'frame_number': 34, 'TimeLimit.truncated': False}
# (1, 4, 84, 84)

# %%
class mydataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32)
        self.actions = torch.tensor(actions, dtype=torch.float32)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

# %%
# 导入IPython显示控制模块


policy_network = PolicyNetwork(env.action_space.n).to(device)
# nn init kaiming
torch.nn.init.kaiming_normal_(policy_network.conv1.weight)
torch.nn.init.kaiming_normal_(policy_network.conv2.weight)
torch.nn.init.kaiming_normal_(policy_network.conv3.weight)
torch.nn.init.kaiming_normal_(policy_network.fc1.weight)
torch.nn.init.kaiming_normal_(policy_network.fc2.weight)

prev = PolicyNetwork(env.action_space.n).to(device)
prev.load_state_dict(policy_network.state_dict())
prev.eval()

optimizer = torch.optim.Adam(policy_network.parameters(), lr=1e-4,weight_decay=1e-5)

# Training loop
num_epochs = 30
batch_size = 32

dataset = mydataset(observations=observations, actions=actions)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

loss_graph=[]
eval_rewards2=[]
eval_rewards1=[]
margin_graph=[]
positive_reward_graph=[]
negative_reward_graph=[]
log_interval = len(observations)//10
num_test = 5
prev_load_freq = 1000
now_log=0
now_pos=0
test_score1=0
test_score2=0
env.close()
for epoch in range(num_epochs):
    policy_network.train()

    # Compute the log probabilities of the actions
    pbar=tqdm(dataloader,position=0,leave=True)
    now_log=0

    for step, (obs_batch,act_batch) in enumerate(pbar):
        obs_batch = torch.tensor(np.array(obs_batch), dtype=torch.float32).to(device)
        act_batch = torch.tensor(np.array(act_batch), dtype=torch.float32).to(device)

        now_log+=obs_batch.shape[0]
        now_pos+=obs_batch.shape[0]

        logits = policy_network(obs_batch)
        model_dist = Categorical(logits=logits)
        model_act_sample = model_dist.sample()
        policy_chosen_logps = model_dist.log_prob(act_batch)
        policy_rejected_logps = model_dist.log_prob(model_act_sample)
        with torch.no_grad():
            prev_dist = Categorical(logits=prev(obs_batch))
            reference_chosen_logps = prev_dist.log_prob(act_batch)
            reference_rejected_logps = prev_dist.log_prob(model_act_sample)


        pi_logratios = policy_chosen_logps - policy_rejected_logps
        ref_logratios = reference_chosen_logps - reference_rejected_logps

        logits = pi_logratios - ref_logratios

        chosen_logratios = policy_chosen_logps - reference_chosen_logps
        reject_logratios = policy_rejected_logps - reference_rejected_logps


        beta = 1
        losses = (-F.logsigmoid(beta * logits))
        loss = losses.mean()
        # Optimize the policy
        optimizer.zero_grad()

        if (step+1) % prev_load_freq == 0:
            prev.load_state_dict(policy_network.state_dict())
            prev.eval()

        loss.backward()

        optimizer.step()
        pbar.set_description((f"Epoch [{epoch+1}/{num_epochs}]"))
        positive_reward = chosen_logratios.detach().mean().item()
        negative_reward = reject_logratios.detach().mean().item()
        margin = positive_reward - negative_reward
        loss_graph.append(loss.detach().item())
        margin_graph.append(margin)
        positive_reward_graph.append(positive_reward)
        negative_reward_graph.append(negative_reward)
        pbar.set_postfix({"loss":loss.detach().item(), "positive_reward": positive_reward, "negative_reward": negative_reward, "margin": positive_reward - negative_reward, "test_score_highest_action": test_score1,"test_score_sample_action": test_score2})


        total_reward=0
        if now_log>=log_interval:
            env = make_atari_env(env_id, n_envs=1)
            env = VecTransposeImage(env)            # 确保图像通道在前
            env = VecFrameStack(env, n_stack=4)     # 堆叠4帧

            now_log-=log_interval

            policy_network.eval()  # 切换到评估模式



            total_reward=0
            # test the policy and save as the first test as gif
            frames = []
            saved_frame = False
            for _ in range(num_test):

                state = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor(state, dtype=torch.float32).to(device)
                    with torch.no_grad():
                        action = Categorical(logits=(policy_network(state_tensor))).sample().cpu().numpy()

                    state, reward, done, _ = env.step(action)  # 执行动作
                    total_reward += reward
                    if not saved_frame:
                        frame = env.render(mode="rgb_array")
                        frames.append(frame)  # 添加到帧列表中
                # 保存为GIF
                if not saved_frame:
                    saved_frame = True
                    image_path = f"sample_epoch_{epoch+1}_iteration_{now_pos}.gif"
                    imageio.mimsave("./gif/"+image_path, frames)
            test_score2 = total_reward/num_test
            eval_rewards1.append(total_reward/num_test)
            total_reward=0
            # test the policy and save as the first test as gif
            frames = []
            saved_frame = False
            for _ in range(num_test):

                state = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor(state, dtype=torch.float32).to(device)
                    with torch.no_grad():
                        logits = policy_network(state_tensor)
                        probabilities = torch.nn.functional.softmax(logits, dim=-1)
                        action = probabilities.argmax().item()
                    state, reward, done, _ = env.step([action])  # 执行动作
                    total_reward += reward
                    if not saved_frame:
                        frame = env.render(mode="rgb_array")
                        frames.append(frame)  # 添加到帧列表中
                # 保存为GIF
                if not saved_frame:
                    saved_frame = True
                    image_path = f"highest_epoch_{epoch+1}_iteration_{now_pos}.gif"
                    imageio.mimsave("./gif/"+image_path, frames)
            test_score1 = total_reward/num_test
            env.close()
            # print(total_reward/num_test)

            eval_rewards2.append(total_reward/num_test)
            policy_network.train()  # 切换回训练模式
# Out:
# Epoch [1/30]:  10%|▉         | 309/3125 [00:03<00:18, 148.49it/s, loss=1.09, positive_reward=14.6, negative_reward=3.67, margin=11, test_score_highest_action=0, test_score_sample_action=0]    /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Epoch [1/30]: 100%|██████████| 3125/3125 [01:04<00:00, 48.39it/s, loss=0.777, positive_reward=0.0759, negative_reward=0.0582, margin=0.0177, test_score_highest_action=[7.4], test_score_sample_action=[4.8]]
# Epoch [2/30]: 100%|██████████| 3125/3125 [01:04<00:00, 48.52it/s, loss=0.693, positive_reward=0.0205, negative_reward=0.0205, margin=0, test_score_highest_action=[5.2], test_score_sample_action=[5.8]]
# Epoch [3/30]: 100%|██████████| 3125/3125 [01:04<00:00, 48.67it/s, loss=0.693, positive_reward=0.000884, negative_reward=0.000884, margin=0, test_score_highest_action=[9.2], test_score_sample_action=[4.2]]
# Epoch [4/30]: 100%|██████████| 3125/3125 [01:06<00:00, 47.26it/s, loss=0.693, positive_reward=-.0138, negative_reward=-.0138, margin=0, test_score_highest_action=[10.8], test_score_sample_action=[8.]]
# Epoch [5/30]: 100%|██████████| 3125/3125 [01:16<00:00, 41.01it/s, loss=0.693, positive_reward=-.0101, negative_reward=-.0101, margin=0, test_score_highest_action=[9.6], test_score_sample_action=[6.]]
# Epoch [6/30]: 100%|██████████| 3125/3125 [01:14<00:00, 42.11it/s, loss=0.69, positive_reward=0.00197, negative_reward=-.0037, margin=0.00567, test_score_highest_action=[11.4], test_score_sample_action=[9.]]
# Epoch [7/30]: 100%|██████████| 3125/3125 [01:16<00:00, 40.62it/s, loss=0.693, positive_reward=-.0021, negative_reward=-.0021, margin=0, test_score_highest_action=[9.6], test_score_sample_action=[8.2]]
# Epoch [8/30]: 100%|██████████| 3125/3125 [01:25<00:00, 36.56it/s, loss=0.676, positive_reward=0.0562, negative_reward=-.00586, margin=0.062, test_score_highest_action=[11.8], test_score_sample_action=[16.6]]
# Epoch [9/30]: 100%|██████████| 3125/3125 [01:24<00:00, 37.08it/s, loss=0.693, positive_reward=-1.3e-5, negative_reward=-1.3e-5, margin=0, test_score_highest_action=[9.], test_score_sample_action=[8.2]]
# Epoch [10/30]: 100%|██████████| 3125/3125 [01:23<00:00, 37.35it/s, loss=0.693, positive_reward=0.000142, negative_reward=0.000142, margin=0, test_score_highest_action=[16.6], test_score_sample_action=[13.6]]
# Epoch [11/30]: 100%|██████████| 3125/3125 [01:17<00:00, 40.17it/s, loss=0.693, positive_reward=8.54e-5, negative_reward=8.54e-5, margin=0, test_score_highest_action=[4.], test_score_sample_action=[8.2]]
# Epoch [12/30]: 100%|██████████| 3125/3125 [01:31<00:00, 34.32it/s, loss=0.693, positive_reward=0.000538, negative_reward=0.000538, margin=0, test_score_highest_action=[12.8], test_score_sample_action=[6.8]]
# Epoch [13/30]: 100%|██████████| 3125/3125 [01:36<00:00, 32.29it/s, loss=0.693, positive_reward=7.64e-6, negative_reward=7.64e-6, margin=0, test_score_highest_action=[7.4], test_score_sample_action=[16.]]
# Epoch [14/30]: 100%|██████████| 3125/3125 [01:30<00:00, 34.40it/s, loss=0.693, positive_reward=4.62e-5, negative_reward=4.62e-5, margin=0, test_score_highest_action=[11.], test_score_sample_action=[13.]]
# Epoch [15/30]: 100%|██████████| 3125/3125 [01:34<00:00, 33.03it/s, loss=0.693, positive_reward=-.0001, negative_reward=-.0001, margin=0, test_score_highest_action=[18.2], test_score_sample_action=[17.2]]
# Epoch [16/30]: 100%|██████████| 3125/3125 [01:32<00:00, 33.65it/s, loss=0.693, positive_reward=-.016, negative_reward=-.016, margin=0, test_score_highest_action=[13.2], test_score_sample_action=[8.8]]
# Epoch [17/30]: 100%|██████████| 3125/3125 [01:31<00:00, 34.25it/s, loss=0.693, positive_reward=-.00391, negative_reward=-.00391, margin=0, test_score_highest_action=[19.4], test_score_sample_action=[13.8]]
# Epoch [18/30]: 100%|██████████| 3125/3125 [01:34<00:00, 33.15it/s, loss=0.672, positive_reward=0.157, negative_reward=-.00102, margin=0.158, test_score_highest_action=[10.], test_score_sample_action=[11.2]]
# Epoch [19/30]: 100%|██████████| 3125/3125 [01:32<00:00, 33.96it/s, loss=0.693, positive_reward=0.000284, negative_reward=0.000284, margin=0, test_score_highest_action=[10.], test_score_sample_action=[11.6]]
# Epoch [20/30]: 100%|██████████| 3125/3125 [01:28<00:00, 35.16it/s, loss=0.693, positive_reward=-.000419, negative_reward=-.000419, margin=0, test_score_highest_action=[14.2], test_score_sample_action=[3.]]
# Epoch [21/30]: 100%|██████████| 3125/3125 [01:26<00:00, 36.31it/s, loss=0.693, positive_reward=1.36e-5, negative_reward=1.36e-5, margin=0, test_score_highest_action=[13.8], test_score_sample_action=[10.]]
# Epoch [22/30]: 100%|██████████| 3125/3125 [01:30<00:00, 34.56it/s, loss=0.693, positive_reward=-.00289, negative_reward=-.00289, margin=0, test_score_highest_action=[13.], test_score_sample_action=[19.6]]
# Epoch [23/30]: 100%|██████████| 3125/3125 [01:27<00:00, 35.91it/s, loss=0.693, positive_reward=-.000107, negative_reward=-.000107, margin=0, test_score_highest_action=[11.8], test_score_sample_action=[10.]]
# Epoch [24/30]: 100%|██████████| 3125/3125 [01:33<00:00, 33.47it/s, loss=0.693, positive_reward=-.00377, negative_reward=-.00377, margin=0, test_score_highest_action=[12.8], test_score_sample_action=[8.2]]
# Epoch [25/30]: 100%|██████████| 3125/3125 [01:44<00:00, 29.91it/s, loss=0.693, positive_reward=0.000131, negative_reward=0.000131, margin=0, test_score_highest_action=[12.4], test_score_sample_action=[17.2]]
# Epoch [26/30]: 100%|██████████| 3125/3125 [01:31<00:00, 33.98it/s, loss=0.693, positive_reward=-2.86e-5, negative_reward=-2.86e-5, margin=0, test_score_highest_action=[12.], test_score_sample_action=[24.6]]
# Epoch [27/30]: 100%|██████████| 3125/3125 [01:36<00:00, 32.36it/s, loss=0.693, positive_reward=0.000409, negative_reward=0.000409, margin=0, test_score_highest_action=[20.8], test_score_sample_action=[10.8]]
# Epoch [28/30]: 100%|██████████| 3125/3125 [01:35<00:00, 32.77it/s, loss=0.693, positive_reward=0.000366, negative_reward=0.000366, margin=0, test_score_highest_action=[20.], test_score_sample_action=[20.4]]
# Epoch [29/30]: 100%|██████████| 3125/3125 [01:34<00:00, 33.01it/s, loss=0.693, positive_reward=-.000233, negative_reward=-.000233, margin=0, test_score_highest_action=[10.], test_score_sample_action=[20.2]]
# Epoch [30/30]: 100%|██████████| 3125/3125 [01:40<00:00, 31.09it/s, loss=0.693, positive_reward=-.016, negative_reward=-.016, margin=0, test_score_highest_action=[13.], test_score_sample_action=[17.4]]

# %%
# save model
torch.save(policy_network.state_dict(), "./model.pth")
# draw the loss graph
import matplotlib.pyplot as plt
plt.plot(loss_graph)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss vs Iteration")
plt.savefig("./loss.png")

plt.show()



# draw the reward graph

plt.plot(eval_rewards2)
plt.xlabel("Iteration")
plt.ylabel("Reward")
plt.title("Reward1 vs Iteration")
plt.savefig("./highest_reward.png")
plt.show()
plt.plot(eval_rewards1)
plt.xlabel("Iteration")
plt.ylabel("Reward1")
plt.title("Reward1 vs Iteration")
plt.savefig("./sample_reward.png")
plt.show()

# drqw the margin graph
plt.plot(margin_graph)
plt.xlabel("Iteration")
plt.ylabel("Margin")
plt.title("Margin vs Iteration")
plt.savefig("./margin.png")
plt.show()

# draw the positive reward graph
plt.plot(positive_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Positive Reward")
plt.title("Positive Reward vs Iteration")
plt.savefig("./positive_reward.png")
plt.show()

# draw the negative reward graph
plt.plot(negative_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Negative Reward")
plt.title("Negative Reward vs Iteration")

plt.savefig("./negative_reward.png")
plt.show()

# %%
# !zip -r g /content/gif
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# updating: content/gif/ (stored 0%)
#   adding: content/gif/highest_epoch_1_iteration_20000.gif (deflated 32%)
#   adding: content/gif/sample_epoch_14_iteration_1310016.gif (deflated 29%)
#   adding: content/gif/sample_epoch_8_iteration_800000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_19_iteration_1870016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_25_iteration_2490016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_10_iteration_1000000.gif (deflated 32%)
#   adding: content/gif/sample_epoch_6_iteration_560000.gif (deflated 33%)
#   adding: content/gif/highest_epoch_4_iteration_350016.gif (deflated 28%)
#   adding: content/gif/highest_epoch_3_iteration_270016.gif (deflated 27%)
#   adding: content/gif/highest_epoch_19_iteration_1850016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_1_iteration_80000.gif (deflated 27%)
#   adding: content/gif/sample_epoch_23_iteration_2250016.gif (deflated 28%)
#   adding: content/gif/sample_epoch_16_iteration_1560000.gif (deflated 28%)
#   adding: content/gif/sample_epoch_26_iteration_2580000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_24_iteration_2370016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_27_iteration_2640000.gif (deflated 33%)
#   adding: content/gif/highest_epoch_13_iteration_1240000.gif (deflated 36%)
#   adding: content/gif/sample_epoch_30_iteration_2930016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_15_iteration_1490016.gif (deflated 38%)
#   adding: content/gif/sample_epoch_23_iteration_2280000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_22_iteration_2110016.gif (deflated 41%)
#   adding: content/gif/highest_epoch_12_iteration_1110016.gif (deflated 22%)
#   adding: content/gif/sample_epoch_11_iteration_1100000.gif (deflated 28%)
#   adding: content/gif/sample_epoch_16_iteration_1580000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_11_iteration_1010016.gif (deflated 25%)
#   adding: content/gif/sample_epoch_12_iteration_1110016.gif (deflated 32%)
#   adding: content/gif/highest_epoch_2_iteration_170016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_20_iteration_1930016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_10_iteration_980000.gif (deflated 41%)
#   adding: content/gif/highest_epoch_6_iteration_510016.gif (deflated 45%)
#   adding: content/gif/sample_epoch_2_iteration_130016.gif (deflated 32%)
#   adding: content/gif/sample_epoch_12_iteration_1120000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_26_iteration_2510016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_7_iteration_680000.gif (deflated 33%)
#   adding: content/gif/highest_epoch_30_iteration_2940000.gif (deflated 45%)
#   adding: content/gif/sample_epoch_19_iteration_1880000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_26_iteration_2520000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_10_iteration_940000.gif (deflated 27%)
#   adding: content/gif/highest_epoch_6_iteration_560000.gif (deflated 39%)
#   adding: content/gif/highest_epoch_26_iteration_2570016.gif (deflated 39%)
#   adding: content/gif/highest_epoch_18_iteration_1760000.gif (deflated 48%)
#   adding: content/gif/highest_epoch_26_iteration_2600000.gif (deflated 40%)
#   adding: content/gif/highest_epoch_22_iteration_2200000.gif (deflated 39%)
#   adding: content/gif/sample_epoch_7_iteration_630016.gif (deflated 37%)
#   adding: content/gif/sample_epoch_27_iteration_2680000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_24_iteration_2310016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_11_iteration_1090016.gif (deflated 36%)
#   adding: content/gif/sample_epoch_12_iteration_1150016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_17_iteration_1660000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_16_iteration_1520000.gif (deflated 32%)
#   adding: content/gif/highest_epoch_7_iteration_630016.gif (deflated 39%)
#   adding: content/gif/highest_epoch_10_iteration_960000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_25_iteration_2410016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_6_iteration_550016.gif (deflated 40%)
#   adding: content/gif/highest_epoch_22_iteration_2180000.gif (deflated 32%)
#   adding: content/gif/highest_epoch_29_iteration_2810016.gif (deflated 38%)
#   adding: content/gif/sample_epoch_16_iteration_1590016.gif (deflated 29%)
#   adding: content/gif/sample_epoch_23_iteration_2230016.gif (deflated 36%)
#   adding: content/gif/sample_epoch_17_iteration_1700000.gif (deflated 29%)
#   adding: content/gif/highest_epoch_1_iteration_70016.gif (deflated 33%)
#   adding: content/gif/highest_epoch_7_iteration_700000.gif (deflated 38%)
#   adding: content/gif/sample_epoch_10_iteration_910016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_15_iteration_1420000.gif (deflated 29%)
#   adding: content/gif/highest_epoch_18_iteration_1730016.gif (deflated 24%)
#   adding: content/gif/sample_epoch_16_iteration_1570016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_12_iteration_1190016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_4_iteration_320000.gif (deflated 41%)
#   adding: content/gif/highest_epoch_9_iteration_890016.gif (deflated 40%)
#   adding: content/gif/sample_epoch_28_iteration_2800000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_23_iteration_2280000.gif (deflated 42%)
#   adding: content/gif/sample_epoch_5_iteration_470016.gif (deflated 45%)
#   adding: content/gif/sample_epoch_27_iteration_2700000.gif (deflated 35%)
#   adding: content/gif/sample_epoch_4_iteration_400000.gif (deflated 37%)
#   adding: content/gif/sample_epoch_1_iteration_40000.gif (deflated 29%)
#   adding: content/gif/highest_epoch_8_iteration_720000.gif (deflated 33%)
#   adding: content/gif/sample_epoch_23_iteration_2300000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_6_iteration_530016.gif (deflated 44%)
#   adding: content/gif/sample_epoch_2_iteration_180000.gif (deflated 38%)
#   adding: content/gif/sample_epoch_4_iteration_330016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_27_iteration_2700000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_30_iteration_2970016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_16_iteration_1540000.gif (deflated 36%)
#   adding: content/gif/highest_epoch_19_iteration_1860000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_24_iteration_2380000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_18_iteration_1760000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_14_iteration_1320000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_13_iteration_1220000.gif (deflated 34%)
#   adding: content/gif/highest_epoch_30_iteration_3000000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_9_iteration_810016.gif (deflated 35%)
#   adding: content/gif/highest_epoch_12_iteration_1140000.gif (deflated 33%)
#   adding: content/gif/sample_epoch_27_iteration_2650016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_26_iteration_2590016.gif (deflated 38%)
#   adding: content/gif/sample_epoch_8_iteration_710016.gif (deflated 40%)
#   adding: content/gif/highest_epoch_16_iteration_1590016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_8_iteration_780000.gif (deflated 21%)
#   adding: content/gif/sample_epoch_24_iteration_2340000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_6_iteration_590016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_9_iteration_880000.gif (deflated 39%)
#   adding: content/gif/sample_epoch_8_iteration_770016.gif (deflated 26%)
#   adding: content/gif/sample_epoch_12_iteration_1130016.gif (deflated 33%)
#   adding: content/gif/highest_epoch_7_iteration_610016.gif (deflated 36%)
#   adding: content/gif/sample_epoch_12_iteration_1170016.gif (deflated 26%)
#   adding: content/gif/sample_epoch_25_iteration_2440000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_5_iteration_420000.gif (deflated 45%)
#   adding: content/gif/sample_epoch_27_iteration_2690016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_7_iteration_620000.gif (deflated 33%)
#   adding: content/gif/highest_epoch_25_iteration_2450016.gif (deflated 41%)
#   adding: content/gif/sample_epoch_19_iteration_1840000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_17_iteration_1690016.gif (deflated 21%)
#   adding: content/gif/sample_epoch_10_iteration_930016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_29_iteration_2850016.gif (deflated 39%)
#   adding: content/gif/sample_epoch_12_iteration_1190016.gif (deflated 27%)
#   adding: content/gif/highest_epoch_8_iteration_730016.gif (deflated 26%)
#   adding: content/gif/highest_epoch_21_iteration_2050016.gif (deflated 23%)
#   adding: content/gif/sample_epoch_20_iteration_1950016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_22_iteration_2200000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_23_iteration_2250016.gif (deflated 32%)
#   adding: content/gif/sample_epoch_18_iteration_1790016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_11_iteration_1080000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_15_iteration_1500000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_18_iteration_1780000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_5_iteration_450016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_15_iteration_1440000.gif (deflated 34%)
#   adding: content/gif/highest_epoch_13_iteration_1280000.gif (deflated 29%)
#   adding: content/gif/highest_epoch_17_iteration_1670016.gif (deflated 34%)
#   adding: content/gif/sample_epoch_16_iteration_1530016.gif (deflated 28%)
#   adding: content/gif/sample_epoch_26_iteration_2530016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_25_iteration_2420000.gif (deflated 36%)
#   adding: content/gif/sample_epoch_21_iteration_2080000.gif (deflated 27%)
#   adding: content/gif/highest_epoch_10_iteration_970016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_5_iteration_500000.gif (deflated 42%)
#   adding: content/gif/sample_epoch_12_iteration_1180000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_11_iteration_1030016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_17_iteration_1640000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_22_iteration_2140000.gif (deflated 40%)
#   adding: content/gif/sample_epoch_19_iteration_1890016.gif (deflated 27%)
#   adding: content/gif/sample_epoch_21_iteration_2060000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_17_iteration_1660000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_24_iteration_2370016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_3_iteration_280000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_22_iteration_2170016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_27_iteration_2660000.gif (deflated 38%)
#   adding: content/gif/highest_epoch_28_iteration_2710016.gif (deflated 27%)
#   adding: content/gif/sample_epoch_15_iteration_1470016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_19_iteration_1870016.gif (deflated 38%)
#   adding: content/gif/highest_epoch_10_iteration_930016.gif (deflated 29%)
#   adding: content/gif/sample_epoch_7_iteration_670016.gif (deflated 32%)
#   adding: content/gif/sample_epoch_7_iteration_700000.gif (deflated 33%)
#   adding: content/gif/sample_epoch_24_iteration_2330016.gif (deflated 27%)
#   adding: content/gif/sample_epoch_20_iteration_1920000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_14_iteration_1320000.gif (deflated 38%)
#   adding: content/gif/highest_epoch_21_iteration_2100000.gif (deflated 39%)
#   adding: content/gif/highest_epoch_25_iteration_2460000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_4_iteration_330016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_23_iteration_2290016.gif (deflated 41%)
#   adding: content/gif/highest_epoch_29_iteration_2820000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_14_iteration_1400000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_6_iteration_550016.gif (deflated 34%)
#   adding: content/gif/sample_epoch_3_iteration_300000.gif (deflated 46%)
#   adding: content/gif/sample_epoch_29_iteration_2880000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_6_iteration_540000.gif (deflated 25%)
#   adding: content/gif/highest_epoch_28_iteration_2760000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_28_iteration_2740000.gif (deflated 39%)
#   adding: content/gif/sample_epoch_22_iteration_2110016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_29_iteration_2820000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_26_iteration_2510016.gif (deflated 41%)
#   adding: content/gif/sample_epoch_21_iteration_2050016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_21_iteration_2040000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_20_iteration_2000000.gif (deflated 45%)
#   adding: content/gif/highest_epoch_21_iteration_2020000.gif (deflated 38%)
#   adding: content/gif/highest_epoch_18_iteration_1790016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_28_iteration_2710016.gif (deflated 38%)
#   adding: content/gif/highest_epoch_19_iteration_1890016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_15_iteration_1450016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_30_iteration_2970016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_18_iteration_1750016.gif (deflated 29%)
#   adding: content/gif/sample_epoch_28_iteration_2750016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_7_iteration_680000.gif (deflated 47%)
#   adding: content/gif/highest_epoch_1_iteration_80000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_22_iteration_2140000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_30_iteration_2920000.gif (deflated 38%)
#   adding: content/gif/highest_epoch_9_iteration_820000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_25_iteration_2450016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_26_iteration_2530016.gif (deflated 36%)
#   adding: content/gif/sample_epoch_21_iteration_2030016.gif (deflated 41%)
#   adding: content/gif/sample_epoch_30_iteration_2940000.gif (deflated 28%)
#   adding: content/gif/highest_epoch_11_iteration_1040000.gif (deflated 32%)
#   adding: content/gif/sample_epoch_28_iteration_2790016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_4_iteration_390016.gif (deflated 45%)
#   adding: content/gif/highest_epoch_9_iteration_870016.gif (deflated 28%)
#   adding: content/gif/highest_epoch_26_iteration_2580000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_18_iteration_1720000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_30_iteration_2910016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_4_iteration_320000.gif (deflated 25%)
#   adding: content/gif/sample_epoch_1_iteration_60000.gif (deflated 42%)
#   adding: content/gif/highest_epoch_16_iteration_1510016.gif (deflated 41%)
#   adding: content/gif/sample_epoch_30_iteration_2990016.gif (deflated 32%)
#   adding: content/gif/sample_epoch_9_iteration_880000.gif (deflated 29%)
#   adding: content/gif/highest_epoch_2_iteration_200000.gif (deflated 24%)
#   adding: content/gif/highest_epoch_17_iteration_1700000.gif (deflated 47%)
#   adding: content/gif/sample_epoch_17_iteration_1690016.gif (deflated 27%)
#   adding: content/gif/sample_epoch_14_iteration_1390016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_2_iteration_160000.gif (deflated 27%)
#   adding: content/gif/highest_epoch_20_iteration_1990016.gif (deflated 38%)
#   adding: content/gif/highest_epoch_21_iteration_2090016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_24_iteration_2360000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_22_iteration_2190016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_28_iteration_2740000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_10_iteration_990016.gif (deflated 27%)
#   adding: content/gif/highest_epoch_3_iteration_290016.gif (deflated 32%)
#   adding: content/gif/sample_epoch_11_iteration_1060000.gif (deflated 26%)
#   adding: content/gif/highest_epoch_19_iteration_1900000.gif (deflated 36%)
#   adding: content/gif/highest_epoch_4_iteration_340000.gif (deflated 27%)
#   adding: content/gif/sample_epoch_7_iteration_690016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_5_iteration_460000.gif (deflated 43%)
#   adding: content/gif/highest_epoch_27_iteration_2620000.gif (deflated 35%)
#   adding: content/gif/sample_epoch_26_iteration_2600000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_22_iteration_2170016.gif (deflated 41%)
#   adding: content/gif/sample_epoch_2_iteration_150016.gif (deflated 26%)
#   adding: content/gif/sample_epoch_15_iteration_1440000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_5_iteration_420000.gif (deflated 34%)
#   adding: content/gif/highest_epoch_24_iteration_2390016.gif (deflated 44%)
#   adding: content/gif/sample_epoch_21_iteration_2090016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_20_iteration_1960000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_18_iteration_1800000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_13_iteration_1300000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_5_iteration_410016.gif (deflated 33%)
#   adding: content/gif/highest_epoch_11_iteration_1100000.gif (deflated 18%)
#   adding: content/gif/sample_epoch_3_iteration_220000.gif (deflated 26%)
#   adding: content/gif/highest_epoch_22_iteration_2150016.gif (deflated 36%)
#   adding: content/gif/highest_epoch_30_iteration_2990016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_13_iteration_1210016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_25_iteration_2430016.gif (deflated 39%)
#   adding: content/gif/sample_epoch_25_iteration_2430016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_29_iteration_2830016.gif (deflated 29%)
#   adding: content/gif/sample_epoch_30_iteration_2960000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_2_iteration_140000.gif (deflated 41%)
#   adding: content/gif/sample_epoch_8_iteration_740000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_14_iteration_1370016.gif (deflated 38%)
#   adding: content/gif/sample_epoch_15_iteration_1490016.gif (deflated 26%)
#   adding: content/gif/highest_epoch_27_iteration_2680000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_8_iteration_790016.gif (deflated 32%)
#   adding: content/gif/sample_epoch_15_iteration_1480000.gif (deflated 26%)
#   adding: content/gif/sample_epoch_29_iteration_2830016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_30_iteration_2980000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_6_iteration_510016.gif (deflated 43%)
#   adding: content/gif/sample_epoch_30_iteration_3000000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_20_iteration_1920000.gif (deflated 29%)
#   adding: content/gif/highest_epoch_23_iteration_2270016.gif (deflated 24%)
#   adding: content/gif/sample_epoch_18_iteration_1750016.gif (deflated 28%)
#   adding: content/gif/sample_epoch_6_iteration_580000.gif (deflated 38%)
#   adding: content/gif/highest_epoch_11_iteration_1020000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_7_iteration_660000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_13_iteration_1290016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_11_iteration_1070016.gif (deflated 29%)
#   adding: content/gif/sample_epoch_30_iteration_2980000.gif (deflated 34%)
#   adding: content/gif/highest_epoch_7_iteration_660000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_13_iteration_1230016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_24_iteration_2390016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_4_iteration_380000.gif (deflated 38%)
#   adding: content/gif/sample_epoch_2_iteration_160000.gif (deflated 44%)
#   adding: content/gif/highest_epoch_15_iteration_1430016.gif (deflated 38%)
#   adding: content/gif/sample_epoch_19_iteration_1900000.gif (deflated 34%)
#   adding: content/gif/sample_epoch_25_iteration_2420000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_7_iteration_690016.gif (deflated 25%)
#   adding: content/gif/sample_epoch_4_iteration_310016.gif (deflated 28%)
#   adding: content/gif/sample_epoch_9_iteration_860000.gif (deflated 29%)
#   adding: content/gif/highest_epoch_9_iteration_840000.gif (deflated 25%)
#   adding: content/gif/highest_epoch_16_iteration_1570016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_16_iteration_1540000.gif (deflated 27%)
#   adding: content/gif/highest_epoch_5_iteration_450016.gif (deflated 28%)
#   adding: content/gif/highest_epoch_24_iteration_2340000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_9_iteration_890016.gif (deflated 35%)
#   adding: content/gif/sample_epoch_20_iteration_2000000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_3_iteration_260000.gif (deflated 23%)
#   adding: content/gif/highest_epoch_8_iteration_790016.gif (deflated 42%)
#   adding: content/gif/sample_epoch_23_iteration_2260000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_12_iteration_1200000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_18_iteration_1770016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_6_iteration_540000.gif (deflated 27%)
#   adding: content/gif/sample_epoch_8_iteration_720000.gif (deflated 26%)
#   adding: content/gif/highest_epoch_1_iteration_90016.gif (deflated 35%)
#   adding: content/gif/highest_epoch_15_iteration_1410016.gif (deflated 37%)
#   adding: content/gif/sample_epoch_25_iteration_2480000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_18_iteration_1710016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_11_iteration_1080000.gif (deflated 46%)
#   adding: content/gif/highest_epoch_24_iteration_2320000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_15_iteration_1500000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_1_iteration_10016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_16_iteration_1530016.gif (deflated 27%)
#   adding: content/gif/sample_epoch_24_iteration_2400000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_22_iteration_2160000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_14_iteration_1330016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_20_iteration_1940000.gif (deflated 33%)
#   adding: content/gif/highest_epoch_25_iteration_2440000.gif (deflated 23%)
#   adding: content/gif/highest_epoch_28_iteration_2780000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_1_iteration_40000.gif (deflated 33%)
#   adding: content/gif/highest_epoch_23_iteration_2240000.gif (deflated 51%)
#   adding: content/gif/sample_epoch_28_iteration_2760000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_4_iteration_370016.gif (deflated 33%)
#   adding: content/gif/sample_epoch_12_iteration_1160000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_8_iteration_740000.gif (deflated 27%)
#   adding: content/gif/highest_epoch_4_iteration_370016.gif (deflated 38%)
#   adding: content/gif/highest_epoch_2_iteration_110016.gif (deflated 38%)
#   adding: content/gif/sample_epoch_14_iteration_1360000.gif (deflated 47%)
#   adding: content/gif/sample_epoch_13_iteration_1270016.gif (deflated 27%)
#   adding: content/gif/highest_epoch_27_iteration_2670016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_9_iteration_900000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_5_iteration_490016.gif (deflated 35%)
#   adding: content/gif/highest_epoch_21_iteration_2030016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_7_iteration_670016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_28_iteration_2800000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_3_iteration_290016.gif (deflated 39%)
#   adding: content/gif/sample_epoch_2_iteration_170016.gif (deflated 40%)
#   adding: content/gif/sample_epoch_9_iteration_850016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_12_iteration_1140000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_5_iteration_460000.gif (deflated 29%)
#   adding: content/gif/sample_epoch_21_iteration_2010016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_7_iteration_640000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_11_iteration_1020000.gif (deflated 39%)
#   adding: content/gif/highest_epoch_15_iteration_1450016.gif (deflated 38%)
#   adding: content/gif/highest_epoch_28_iteration_2750016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_13_iteration_1260000.gif (deflated 34%)
#   adding: content/gif/sample_epoch_2_iteration_110016.gif (deflated 39%)
#   adding: content/gif/sample_epoch_27_iteration_2610016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_7_iteration_650016.gif (deflated 27%)
#   adding: content/gif/sample_epoch_7_iteration_620000.gif (deflated 35%)
#   adding: content/gif/highest_epoch_12_iteration_1130016.gif (deflated 38%)
#   adding: content/gif/highest_epoch_9_iteration_810016.gif (deflated 28%)
#   adding: content/gif/sample_epoch_2_iteration_190016.gif (deflated 34%)
#   adding: content/gif/sample_epoch_23_iteration_2210016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_18_iteration_1740000.gif (deflated 42%)
#   adding: content/gif/sample_epoch_11_iteration_1010016.gif (deflated 28%)
#   adding: content/gif/sample_epoch_19_iteration_1830016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_8_iteration_780000.gif (deflated 39%)
#   adding: content/gif/sample_epoch_13_iteration_1280000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_7_iteration_640000.gif (deflated 28%)
#   adding: content/gif/highest_epoch_23_iteration_2260000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_2_iteration_150016.gif (deflated 36%)
#   adding: content/gif/sample_epoch_13_iteration_1250016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_24_iteration_2310016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_29_iteration_2900000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_8_iteration_750016.gif (deflated 47%)
#   adding: content/gif/highest_epoch_17_iteration_1650016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_25_iteration_2410016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_13_iteration_1240000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_10_iteration_910016.gif (deflated 32%)
#   adding: content/gif/sample_epoch_9_iteration_840000.gif (deflated 28%)
#   adding: content/gif/sample_epoch_26_iteration_2540000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_17_iteration_1610016.gif (deflated 33%)
#   adding: content/gif/sample_epoch_21_iteration_2100000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_29_iteration_2850016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_3_iteration_240000.gif (deflated 36%)
#   adding: content/gif/sample_epoch_11_iteration_1070016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_23_iteration_2300000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_17_iteration_1680000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_22_iteration_2120000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_15_iteration_1470016.gif (deflated 28%)
#   adding: content/gif/sample_epoch_13_iteration_1220000.gif (deflated 32%)
#   adding: content/gif/highest_epoch_27_iteration_2690016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_23_iteration_2290016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_26_iteration_2590016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_1_iteration_90016.gif (deflated 36%)
#   adding: content/gif/highest_epoch_12_iteration_1160000.gif (deflated 37%)
#   adding: content/gif/sample_epoch_6_iteration_570016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_14_iteration_1310016.gif (deflated 35%)
#   adding: content/gif/sample_epoch_1_iteration_50016.gif (deflated 32%)
#   adding: content/gif/highest_epoch_28_iteration_2730016.gif (deflated 33%)
#   adding: content/gif/highest_epoch_20_iteration_1940000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_22_iteration_2180000.gif (deflated 43%)
#   adding: content/gif/highest_epoch_5_iteration_410016.gif (deflated 35%)
#   adding: content/gif/sample_epoch_3_iteration_270016.gif (deflated 37%)
#   adding: content/gif/highest_epoch_13_iteration_1250016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_17_iteration_1630016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_10_iteration_940000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_20_iteration_1930016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_9_iteration_830016.gif (deflated 36%)
#   adding: content/gif/highest_epoch_14_iteration_1350016.gif (deflated 38%)
#   adding: content/gif/highest_epoch_1_iteration_50016.gif (deflated 28%)
#   adding: content/gif/highest_epoch_21_iteration_2080000.gif (deflated 29%)
#   adding: content/gif/highest_epoch_30_iteration_2950016.gif (deflated 32%)
#   adding: content/gif/sample_epoch_21_iteration_2020000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_4_iteration_400000.gif (deflated 36%)
#   adding: content/gif/sample_epoch_2_iteration_200000.gif (deflated 46%)
#   adding: content/gif/highest_epoch_29_iteration_2860000.gif (deflated 38%)
#   adding: content/gif/sample_epoch_17_iteration_1650016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_23_iteration_2230016.gif (deflated 42%)
#   adding: content/gif/highest_epoch_5_iteration_430016.gif (deflated 37%)
#   adding: content/gif/highest_epoch_28_iteration_2770016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_2_iteration_190016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_6_iteration_570016.gif (deflated 15%)
#   adding: content/gif/highest_epoch_10_iteration_920000.gif (deflated 40%)
#   adding: content/gif/highest_epoch_22_iteration_2130016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_6_iteration_590016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_3_iteration_260000.gif (deflated 29%)
#   adding: content/gif/sample_epoch_10_iteration_920000.gif (deflated 44%)
#   adding: content/gif/sample_epoch_6_iteration_530016.gif (deflated 27%)
#   adding: content/gif/highest_epoch_28_iteration_2790016.gif (deflated 38%)
#   adding: content/gif/highest_epoch_26_iteration_2540000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_29_iteration_2900000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_20_iteration_1910016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_17_iteration_1610016.gif (deflated 28%)
#   adding: content/gif/highest_epoch_15_iteration_1480000.gif (deflated 38%)
#   adding: content/gif/highest_epoch_3_iteration_230016.gif (deflated 37%)
#   adding: content/gif/sample_epoch_5_iteration_490016.gif (deflated 45%)
#   adding: content/gif/highest_epoch_29_iteration_2870016.gif (deflated 37%)
#   adding: content/gif/highest_epoch_3_iteration_220000.gif (deflated 21%)
#   adding: content/gif/sample_epoch_20_iteration_1980000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_10_iteration_950016.gif (deflated 27%)
#   adding: content/gif/highest_epoch_3_iteration_300000.gif (deflated 39%)
#   adding: content/gif/highest_epoch_6_iteration_520000.gif (deflated 28%)
#   adding: content/gif/highest_epoch_20_iteration_1950016.gif (deflated 43%)
#   adding: content/gif/highest_epoch_4_iteration_380000.gif (deflated 41%)
#   adding: content/gif/sample_epoch_1_iteration_100000.gif (deflated 37%)
#   adding: content/gif/sample_epoch_18_iteration_1740000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_15_iteration_1460000.gif (deflated 39%)
#   adding: content/gif/sample_epoch_4_iteration_340000.gif (deflated 28%)
#   adding: content/gif/highest_epoch_22_iteration_2120000.gif (deflated 36%)
#   adding: content/gif/sample_epoch_19_iteration_1810016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_16_iteration_1600000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_14_iteration_1380000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_8_iteration_760000.gif (deflated 26%)
#   adding: content/gif/sample_epoch_26_iteration_2570016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_19_iteration_1810016.gif (deflated 25%)
#   adding: content/gif/highest_epoch_12_iteration_1170016.gif (deflated 41%)
#   adding: content/gif/sample_epoch_19_iteration_1860000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_5_iteration_480000.gif (deflated 38%)
#   adding: content/gif/sample_epoch_24_iteration_2350016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_13_iteration_1230016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_18_iteration_1770016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_19_iteration_1850016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_10_iteration_960000.gif (deflated 45%)
#   adding: content/gif/sample_epoch_28_iteration_2720000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_1_iteration_100000.gif (deflated 26%)
#   adding: content/gif/sample_epoch_1_iteration_70016.gif (deflated 37%)
#   adding: content/gif/sample_epoch_28_iteration_2770016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_2_iteration_120000.gif (deflated 28%)
#   adding: content/gif/sample_epoch_28_iteration_2730016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_9_iteration_860000.gif (deflated 33%)
#   adding: content/gif/highest_epoch_25_iteration_2490016.gif (deflated 35%)
#   adding: content/gif/highest_epoch_29_iteration_2880000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_22_iteration_2190016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_14_iteration_1400000.gif (deflated 39%)
#   adding: content/gif/highest_epoch_24_iteration_2330016.gif (deflated 34%)
#   adding: content/gif/highest_epoch_14_iteration_1340000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_2_iteration_130016.gif (deflated 42%)
#   adding: content/gif/sample_epoch_1_iteration_30016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_25_iteration_2470016.gif (deflated 45%)
#   adding: content/gif/sample_epoch_14_iteration_1370016.gif (deflated 39%)
#   adding: content/gif/highest_epoch_29_iteration_2840000.gif (deflated 6%)
#   adding: content/gif/highest_epoch_29_iteration_2890016.gif (deflated 44%)
#   adding: content/gif/sample_epoch_1_iteration_20000.gif (deflated 40%)
#   adding: content/gif/highest_epoch_28_iteration_2720000.gif (deflated 36%)
#   adding: content/gif/sample_epoch_29_iteration_2840000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_14_iteration_1350016.gif (deflated 32%)
#   adding: content/gif/sample_epoch_24_iteration_2320000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_10_iteration_1000000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_4_iteration_390016.gif (deflated 26%)
#   adding: content/gif/highest_epoch_8_iteration_760000.gif (deflated 24%)
#   adding: content/gif/highest_epoch_25_iteration_2480000.gif (deflated 34%)
#   adding: content/gif/sample_epoch_23_iteration_2270016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_1_iteration_60000.gif (deflated 28%)
#   adding: content/gif/sample_epoch_20_iteration_1990016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_23_iteration_2240000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_27_iteration_2630016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_22_iteration_2130016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_14_iteration_1380000.gif (deflated 42%)
#   adding: content/gif/sample_epoch_5_iteration_430016.gif (deflated 42%)
#   adding: content/gif/highest_epoch_26_iteration_2560000.gif (deflated 23%)
#   adding: content/gif/highest_epoch_11_iteration_1050016.gif (deflated 25%)
#   adding: content/gif/sample_epoch_25_iteration_2460000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_2_iteration_140000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_10_iteration_980000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_26_iteration_2550016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_30_iteration_2930016.gif (deflated 43%)
#   adding: content/gif/sample_epoch_11_iteration_1040000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_30_iteration_2910016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_16_iteration_1510016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_3_iteration_210016.gif (deflated 39%)
#   adding: content/gif/highest_epoch_12_iteration_1150016.gif (deflated 36%)
#   adding: content/gif/highest_epoch_7_iteration_650016.gif (deflated 25%)
#   adding: content/gif/highest_epoch_8_iteration_800000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_27_iteration_2660000.gif (deflated 29%)
#   adding: content/gif/sample_epoch_18_iteration_1710016.gif (deflated 28%)
#   adding: content/gif/highest_epoch_20_iteration_1960000.gif (deflated 41%)
#   adding: content/gif/sample_epoch_26_iteration_2560000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_27_iteration_2610016.gif (deflated 41%)
#   adding: content/gif/highest_epoch_20_iteration_1980000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_12_iteration_1180000.gif (deflated 48%)
#   adding: content/gif/sample_epoch_17_iteration_1640000.gif (deflated 38%)
#   adding: content/gif/sample_epoch_14_iteration_1340000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_3_iteration_210016.gif (deflated 35%)
#   adding: content/gif/sample_epoch_7_iteration_610016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_8_iteration_710016.gif (deflated 35%)
#   adding: content/gif/highest_epoch_14_iteration_1390016.gif (deflated 42%)
#   adding: content/gif/highest_epoch_6_iteration_580000.gif (deflated 32%)
#   adding: content/gif/sample_epoch_8_iteration_730016.gif (deflated 38%)
#   adding: content/gif/sample_epoch_16_iteration_1550016.gif (deflated 33%)
#   adding: content/gif/sample_epoch_18_iteration_1800000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_3_iteration_250016.gif (deflated 32%)
#   adding: content/gif/highest_epoch_14_iteration_1360000.gif (deflated 26%)
#   adding: content/gif/highest_epoch_16_iteration_1600000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_5_iteration_440000.gif (deflated 40%)
#   adding: content/gif/sample_epoch_29_iteration_2890016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_19_iteration_1840000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_4_iteration_350016.gif (deflated 47%)
#   adding: content/gif/highest_epoch_19_iteration_1820000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_5_iteration_440000.gif (deflated 45%)
#   adding: content/gif/sample_epoch_17_iteration_1670016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_24_iteration_2360000.gif (deflated 36%)
#   adding: content/gif/sample_epoch_19_iteration_1820000.gif (deflated 33%)
#   adding: content/gif/highest_epoch_11_iteration_1060000.gif (deflated 34%)
#   adding: content/gif/highest_epoch_4_iteration_310016.gif (deflated 27%)
#   adding: content/gif/highest_epoch_14_iteration_1330016.gif (deflated 38%)
#   adding: content/gif/sample_epoch_3_iteration_230016.gif (deflated 46%)
#   adding: content/gif/sample_epoch_6_iteration_520000.gif (deflated 39%)
#   adding: content/gif/sample_epoch_22_iteration_2150016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_30_iteration_2920000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_17_iteration_1680000.gif (deflated 40%)
#   adding: content/gif/highest_epoch_26_iteration_2550016.gif (deflated 40%)
#   adding: content/gif/sample_epoch_15_iteration_1430016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_1_iteration_30016.gif (deflated 28%)
#   adding: content/gif/highest_epoch_15_iteration_1420000.gif (deflated 33%)
#   adding: content/gif/sample_epoch_28_iteration_2780000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_21_iteration_2070016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_11_iteration_1090016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_27_iteration_2650016.gif (deflated 8%)
#   adding: content/gif/highest_epoch_16_iteration_1560000.gif (deflated 43%)
#   adding: content/gif/sample_epoch_6_iteration_600000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_16_iteration_1550016.gif (deflated 27%)
#   adding: content/gif/sample_epoch_27_iteration_2630016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_12_iteration_1200000.gif (deflated 39%)
#   adding: content/gif/sample_epoch_17_iteration_1620000.gif (deflated 36%)
#   adding: content/gif/highest_epoch_5_iteration_470016.gif (deflated 50%)
#   adding: content/gif/highest_epoch_19_iteration_1880000.gif (deflated 39%)
#   adding: content/gif/sample_epoch_2_iteration_120000.gif (deflated 37%)
#   adding: content/gif/highest_epoch_12_iteration_1120000.gif (deflated 31%)
#   adding: content/gif/highest_epoch_10_iteration_990016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_21_iteration_2060000.gif (deflated 29%)
#   adding: content/gif/sample_epoch_21_iteration_2040000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_13_iteration_1300000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_29_iteration_2870016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_20_iteration_1970016.gif (deflated 38%)
#   adding: content/gif/highest_epoch_6_iteration_600000.gif (deflated 33%)
#   adding: content/gif/highest_epoch_5_iteration_480000.gif (deflated 37%)
#   adding: content/gif/highest_epoch_9_iteration_900000.gif (deflated 38%)
#   adding: content/gif/sample_epoch_3_iteration_240000.gif (deflated 26%)
#   adding: content/gif/sample_epoch_1_iteration_10016.gif (deflated 41%)
#   adding: content/gif/sample_epoch_29_iteration_2860000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_23_iteration_2220000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_23_iteration_2210016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_16_iteration_1580000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_24_iteration_2400000.gif (deflated 33%)
#   adding: content/gif/sample_epoch_9_iteration_820000.gif (deflated 38%)
#   adding: content/gif/highest_epoch_19_iteration_1830016.gif (deflated 25%)
#   adding: content/gif/highest_epoch_5_iteration_500000.gif (deflated 37%)
#   adding: content/gif/sample_epoch_3_iteration_250016.gif (deflated 28%)
#   adding: content/gif/highest_epoch_13_iteration_1260000.gif (deflated 45%)
#   adding: content/gif/highest_epoch_15_iteration_1460000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_27_iteration_2620000.gif (deflated 26%)
#   adding: content/gif/sample_epoch_26_iteration_2520000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_8_iteration_750016.gif (deflated 40%)
#   adding: content/gif/sample_epoch_11_iteration_1050016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_27_iteration_2640000.gif (deflated 36%)
#   adding: content/gif/highest_epoch_24_iteration_2350016.gif (deflated 47%)
#   adding: content/gif/highest_epoch_23_iteration_2220000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_17_iteration_1620000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_9_iteration_850016.gif (deflated 35%)
#   adding: content/gif/sample_epoch_13_iteration_1210016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_20_iteration_1970016.gif (deflated 31%)
#   adding: content/gif/sample_epoch_22_iteration_2160000.gif (deflated 30%)
#   adding: content/gif/sample_epoch_18_iteration_1720000.gif (deflated 29%)
#   adding: content/gif/sample_epoch_25_iteration_2470016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_4_iteration_360000.gif (deflated 28%)
#   adding: content/gif/highest_epoch_8_iteration_770016.gif (deflated 37%)
#   adding: content/gif/highest_epoch_9_iteration_830016.gif (deflated 25%)
#   adding: content/gif/sample_epoch_15_iteration_1410016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_4_iteration_360000.gif (deflated 29%)
#   adding: content/gif/highest_epoch_13_iteration_1290016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_9_iteration_870016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_3_iteration_280000.gif (deflated 35%)
#   adding: content/gif/sample_epoch_17_iteration_1630016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_18_iteration_1780000.gif (deflated 26%)
#   adding: content/gif/highest_epoch_11_iteration_1030016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_25_iteration_2500000.gif (deflated 31%)
#   adding: content/gif/sample_epoch_10_iteration_970016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_30_iteration_2960000.gif (deflated 29%)
#   adding: content/gif/sample_epoch_27_iteration_2670016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_18_iteration_1730016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_21_iteration_2070016.gif (deflated 30%)
#   adding: content/gif/sample_epoch_24_iteration_2380000.gif (deflated 29%)
#   adding: content/gif/highest_epoch_16_iteration_1520000.gif (deflated 30%)
#   adding: content/gif/highest_epoch_21_iteration_2010016.gif (deflated 40%)
#   adding: content/gif/sample_epoch_30_iteration_2950016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_13_iteration_1270016.gif (deflated 30%)
#   adding: content/gif/highest_epoch_25_iteration_2500000.gif (deflated 35%)
#   adding: content/gif/sample_epoch_29_iteration_2810016.gif (deflated 31%)
#   adding: content/gif/highest_epoch_2_iteration_180000.gif (deflated 29%)
#   adding: content/gif/highest_epoch_10_iteration_950016.gif (deflated 29%)
#   adding: content/gif/highest_epoch_20_iteration_1910016.gif (deflated 36%)
