# %%
import gymnasium as gym
import numpy as np
from stable_baselines3.common.env_util import make_vec_env as make_vec_env_sb3
from copy import deepcopy
import torch
from torch.distributions import Normal,MultivariateNormal
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.utils.data import Dataset, DataLoader
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
import imageio
import pandas as pd
from tqdm import tqdm
from PIL import Image
from stable_baselines3.dqn.policies import MlpPolicy
import matplotlib.pyplot as plt
import os

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !nvidia-smi
# clean up memory forcefully
torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# Mon May 13 01:00:13 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  | 00000000:01:00.0 Off |                  N/A |
# | 17%   56C    P2              87W / 250W |   3496MiB / 11264MiB |     79%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    228304      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    229850      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    277377      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    280712      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    319688      C   ...iu/miniconda3/envs/myenv/bin/python      300MiB |
# |    0   N/A  N/A    328416      C   ...iu/miniconda3/envs/myenv/bin/python      204MiB |
# |    0   N/A  N/A    377684      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   1475780      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   2544023      C   ...u/miniconda3/envs/myenv2/bin/python      184MiB |
# |    0   N/A  N/A   2546464      C   ...u/miniconda3/envs/myenv2/bin/python      192MiB |
# |    0   N/A  N/A   2573704      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2584185      C   ...181/miniconda3/envs/copy/bin/python      194MiB |
# |    0   N/A  N/A   2587643      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2588031      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2591397    C+G   ...181/miniconda3/envs/copy/bin/python      217MiB |
# |    0   N/A  N/A   2594108      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2594730      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# +---------------------------------------------------------------------------------------+
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
class CustomDataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32,device=device)
        self.actions = torch.tensor(actions, dtype=torch.float32,device=device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, output_dim,init_w=3e-3,log_std_min=-20,log_std_max=2):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 32)


        self.fc2 = nn.Linear(32, 32)
        self.log_std = nn.Linear(32, output_dim)
        self.mu=nn.Linear(32,output_dim)
        self.log_std_min=log_std_min
        self.log_std_max=log_std_max
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        torch.nn.init.kaiming_normal_(self.fc2.weight)
        self.mu.weight.data.uniform_(-init_w,init_w)
        self.mu.bias.data.uniform_(-init_w,init_w)
        self.log_std.weight.data.uniform_(-init_w,init_w)
        self.log_std.bias.data.uniform_(-init_w,init_w)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = self.mu(x) # Only apply if action bounds are [-1, 1]
        log_std = self.log_std(x)  # Ensure std is positive
        log_std=torch.clamp(log_std,self.log_std_min,self.log_std_max)

        return mu, log_std
# Out:
# Using device: cuda

# %%
# from imitation.util.util import make_vec_env

# observations= np.load("../dataset/obs.npy", allow_pickle=True)
# actions = np.load("../dataset/actions.npy", allow_pickle=True)

# observations=observations.squeeze()
# actions=actions.squeeze()

# print(observations.shape, actions.shape)
# print(observations[0], actions[0])
import pickle
import numpy as np
#　read /mnt/nfs/work/c98181/TDIL/saved_expert_transition/Walker2d-v3/sac/episode_num1_6123.pkl
# "states", "actions", "rewards", "next_states", "dones".
with open("/mnt/nfs/work/c98181/TDIL/saved_expert_transition/HalfCheetah-v3/sac/episode_num1_15251.pkl", "rb") as f:
    data = pickle.load(f)

    obs_list = data["states"]
    actions_list = data["actions"]
    observations=np.array(obs_list)
    actions=np.array(actions_list)
    # shape
    print(observations.shape)
    print(actions.shape)

# env=gym.make("Walker2d-v3",exclude_current_positions_from_observation=False,render_mode="rgb_array")
env=gym.make("HalfCheetah-v3",render_mode="rgb_array")
# Out:
# (1000, 17)
# (1000, 6)
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment HalfCheetah-v3 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_env.py:211: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(

# %%
class mydataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32).to(device)
        self.actions = torch.tensor(actions, dtype=torch.float32).to(device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

# %%
policy_network = PolicyNetwork(17,6).to(device)
prev = PolicyNetwork(17,6).to(device)
prev.load_state_dict(policy_network.state_dict())
prev.eval()

optimizer = torch.optim.Adam(policy_network.parameters(), lr=0.0003,weight_decay=1e-4)

# Training loop
num_epochs = 100
batch_size = 32

dataset = mydataset(observations=observations, actions=actions)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

loss_graph=[]
greedy_rewards=[]
sample_rewards=[]
margin_graph=[]
positive_reward_graph=[]
negative_reward_graph=[]
log_interval = len(observations)//1
num_test = 10
now_log=0
now_pos=0
greedy_score=0
sample_score=0
for epoch in range(num_epochs):
    policy_network.train()

    # Compute the log probabilities of the actions
    pbar=tqdm(dataloader,position=0,leave=True)
    now_log=0

    for step, (obs_batch,act_batch) in enumerate(pbar):
        # obs_batch = torch.tensor(np.array(obs_batch), dtype=torch.float32).to(device)
        # act_batch = torch.tensor(np.array(act_batch), dtype=torch.float32).to(device)

        now_log+=obs_batch.shape[0]
        now_pos+=obs_batch.shape[0]
        
        mu, log_std = policy_network(obs_batch)
        std=log_std.exp()
        dist = Normal(mu, std)
        z_model=dist.rsample()
        model_action=torch.tanh(z_model)
        z_expert=torch.atanh(torch.clamp(act_batch, -0.999999, 0.999999))
        epsilon=1e-6


        policy_rejected_logps =dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
        policy_chosen_logps = dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        with torch.no_grad():
          prev_mu, prev_log_std = prev(obs_batch)
          prev_std=prev_log_std.exp()
          prev_dist = Normal(prev_mu, prev_std)

          reference_rejected_logps =prev_dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
          reference_chosen_logps = prev_dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        pi_logratios = policy_chosen_logps - policy_rejected_logps
        ref_logratios = reference_chosen_logps - reference_rejected_logps

        chosen_KL = (policy_chosen_logps - reference_chosen_logps).mean().clamp(min=0)
        reject_KL = (policy_rejected_logps - reference_rejected_logps).mean().clamp(min=0)

       

        chosen_logratios = policy_chosen_logps - reference_chosen_logps
        reject_logratios = policy_rejected_logps - reference_rejected_logps

        # logits = chosen_logratios - reject_logratios

        if epoch < -1:
          loss = - (policy_chosen_logps).mean()
        else:
          beta = 1
          losses=torch.pow(chosen_logratios-0.5,2)+torch.pow(reject_logratios+0.5,2)
          loss = losses.mean()
        #   losses = torch.cat((1 - F.logsigmoid(beta * (chosen_logratios - reject_KL)), 1 - F.logsigmoid(beta * (chosen_KL - reject_logratios))), 0)
        #   loss = losses.mean()
        # Optimize the policy
        optimizer.zero_grad()



        loss.backward()

        optimizer.step()
        pbar.set_description((f"Epoch [{epoch+1}/{num_epochs}]"))
        positive_reward = chosen_logratios.detach().mean().item()
        negative_reward = reject_logratios.detach().mean().item()
        margin = positive_reward - negative_reward
        loss_graph.append(loss.detach().item())
        margin_graph.append(margin)
        positive_reward_graph.append(positive_reward)
        negative_reward_graph.append(negative_reward)



        total_reward=0
        if now_log>=log_interval:
            now_log-=log_interval
            
            policy_network.eval()  # 切换到评估模式

            

            total_reward=0
            # test the policy and save as the first test as gif
            # frames = []
            for _ in range(num_test):
                state,_ = env.reset()
                done = False

                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(mu)   
                        action.squeeze_()

                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/greedy/"+image_path, frames)

            greedy_score=total_reward/num_test
            total_reward=0
            frames = []
            # test the policy and save as the first test as gif
            for _ in range(num_test):
                state,_ = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(Normal(mu,std).sample())
                        action.squeeze_()
                       
                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/sample/"+image_path, frames)

            sample_score=total_reward/num_test
            greedy_rewards.append(greedy_score)
            sample_rewards.append(sample_score)
            policy_network.train()  # 切换回训练模式
        pbar.set_postfix({"loss":loss.detach().item(), "positive_reward": positive_reward, "negative_reward": negative_reward, "margin": positive_reward - negative_reward,"greedy_score":greedy_score,"sample_score":sample_score})
    # prev.load_state_dict(policy_network.state_dict())
    # prev.eval()
         

env.close()
# Out:
# Epoch [1/100]:  81%|████████▏ | 26/32 [00:00<00:00, 65.06it/s, loss=0.402, positive_reward=0.209, negative_reward=-.00446, margin=0.213, greedy_score=0, sample_score=0] /tmp/ipykernel_2605031/4132790086.py:117: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025847094/work/torch/csrc/utils/tensor_new.cpp:275.)
#   state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
# Epoch [1/100]: 100%|██████████| 32/32 [00:18<00:00,  1.75it/s, loss=0.49, positive_reward=0.171, negative_reward=0.0608, margin=0.111, greedy_score=-.619, sample_score=-315]
# Epoch [2/100]: 100%|██████████| 32/32 [00:19<00:00,  1.68it/s, loss=0.376, positive_reward=0.247, negative_reward=0.0176, margin=0.229, greedy_score=-.371, sample_score=-300]
# Epoch [3/100]: 100%|██████████| 32/32 [00:18<00:00,  1.70it/s, loss=0.389, positive_reward=0.231, negative_reward=-.0133, margin=0.244, greedy_score=-.482, sample_score=-363]
# Epoch [4/100]: 100%|██████████| 32/32 [00:19<00:00,  1.66it/s, loss=0.391, positive_reward=0.189, negative_reward=0.0057, margin=0.183, greedy_score=-.31, sample_score=-349]
# Epoch [5/100]: 100%|██████████| 32/32 [00:19<00:00,  1.65it/s, loss=0.41, positive_reward=0.206, negative_reward=0.0098, margin=0.196, greedy_score=-.0473, sample_score=-235]
# Epoch [6/100]: 100%|██████████| 32/32 [00:20<00:00,  1.56it/s, loss=0.38, positive_reward=0.234, negative_reward=-.0165, margin=0.25, greedy_score=-.353, sample_score=-312]
# Epoch [7/100]: 100%|██████████| 32/32 [00:20<00:00,  1.53it/s, loss=0.398, positive_reward=0.208, negative_reward=0.0229, margin=0.185, greedy_score=-1.1, sample_score=-256]
# Epoch [8/100]: 100%|██████████| 32/32 [00:19<00:00,  1.65it/s, loss=0.394, positive_reward=0.236, negative_reward=0.0447, margin=0.192, greedy_score=-.262, sample_score=-269]
# Epoch [9/100]: 100%|██████████| 32/32 [00:17<00:00,  1.79it/s, loss=0.498, positive_reward=0.19, negative_reward=0.0914, margin=0.0984, greedy_score=-.495, sample_score=-236]
# Epoch [10/100]: 100%|██████████| 32/32 [00:18<00:00,  1.77it/s, loss=0.376, positive_reward=0.221, negative_reward=0.00432, margin=0.217, greedy_score=-.817, sample_score=-272]
# Epoch [11/100]: 100%|██████████| 32/32 [00:19<00:00,  1.61it/s, loss=0.374, positive_reward=0.223, negative_reward=-.00103, margin=0.224, greedy_score=-.328, sample_score=-341]
# Epoch [12/100]: 100%|██████████| 32/32 [00:19<00:00,  1.62it/s, loss=0.44, positive_reward=0.253, negative_reward=0.0773, margin=0.176, greedy_score=-.558, sample_score=-280]
# Epoch [13/100]: 100%|██████████| 32/32 [00:19<00:00,  1.61it/s, loss=0.446, positive_reward=0.231, negative_reward=0.0394, margin=0.192, greedy_score=-.0422, sample_score=-294]
# Epoch [14/100]: 100%|██████████| 32/32 [00:21<00:00,  1.51it/s, loss=0.374, positive_reward=0.244, negative_reward=0.0232, margin=0.22, greedy_score=-.501, sample_score=-290]
# Epoch [15/100]: 100%|██████████| 32/32 [00:21<00:00,  1.50it/s, loss=0.431, positive_reward=0.25, negative_reward=0.053, margin=0.197, greedy_score=-.318, sample_score=-287]
# Epoch [16/100]: 100%|██████████| 32/32 [00:21<00:00,  1.47it/s, loss=0.345, positive_reward=0.236, negative_reward=-.0354, margin=0.272, greedy_score=-.463, sample_score=-283]
# Epoch [17/100]: 100%|██████████| 32/32 [00:21<00:00,  1.50it/s, loss=0.376, positive_reward=0.237, negative_reward=0.0273, margin=0.21, greedy_score=-.222, sample_score=-288]
# Epoch [18/100]: 100%|██████████| 32/32 [00:21<00:00,  1.47it/s, loss=0.391, positive_reward=0.21, negative_reward=0.0301, margin=0.18, greedy_score=-.0977, sample_score=-258]
# Epoch [19/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=0.408, positive_reward=0.238, negative_reward=0.026, margin=0.212, greedy_score=-.611, sample_score=-299]
# Epoch [20/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=0.43, positive_reward=0.238, negative_reward=0.0127, margin=0.225, greedy_score=-.439, sample_score=-252]
# Epoch [21/100]: 100%|██████████| 32/32 [00:26<00:00,  1.19it/s, loss=0.344, positive_reward=0.259, negative_reward=-.0092, margin=0.268, greedy_score=-.497, sample_score=-301]
# Epoch [22/100]: 100%|██████████| 32/32 [00:27<00:00,  1.17it/s, loss=0.442, positive_reward=0.214, negative_reward=0.0603, margin=0.153, greedy_score=-.709, sample_score=-254]
# Epoch [23/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=0.368, positive_reward=0.242, negative_reward=-.00108, margin=0.243, greedy_score=-.267, sample_score=-288]
# Epoch [24/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.433, positive_reward=0.221, negative_reward=0.0371, margin=0.183, greedy_score=-.199, sample_score=-271]
# Epoch [25/100]: 100%|██████████| 32/32 [00:26<00:00,  1.21it/s, loss=0.4, positive_reward=0.229, negative_reward=0.0414, margin=0.188, greedy_score=-.469, sample_score=-315]
# Epoch [26/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.432, positive_reward=0.245, negative_reward=0.0781, margin=0.167, greedy_score=-.517, sample_score=-296]
# Epoch [27/100]: 100%|██████████| 32/32 [00:27<00:00,  1.18it/s, loss=0.374, positive_reward=0.227, negative_reward=0.0202, margin=0.207, greedy_score=-.21, sample_score=-261]
# Epoch [28/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.393, positive_reward=0.231, negative_reward=0.0293, margin=0.202, greedy_score=0.142, sample_score=-253]
# Epoch [29/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.368, positive_reward=0.242, negative_reward=0.00529, margin=0.237, greedy_score=-.252, sample_score=-262]
# Epoch [30/100]: 100%|██████████| 32/32 [00:26<00:00,  1.21it/s, loss=0.397, positive_reward=0.247, negative_reward=0.0518, margin=0.195, greedy_score=-.391, sample_score=-265]
# Epoch [31/100]: 100%|██████████| 32/32 [00:24<00:00,  1.29it/s, loss=0.422, positive_reward=0.231, negative_reward=0.0722, margin=0.159, greedy_score=-.482, sample_score=-272]
# Epoch [32/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.429, positive_reward=0.239, negative_reward=0.0611, margin=0.178, greedy_score=-.149, sample_score=-282]
# Epoch [33/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.373, positive_reward=0.226, negative_reward=0.00673, margin=0.219, greedy_score=-.0773, sample_score=-281]
# Epoch [34/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=0.392, positive_reward=0.219, negative_reward=0.0356, margin=0.183, greedy_score=-.36, sample_score=-272]
# Epoch [35/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.42, positive_reward=0.249, negative_reward=0.0672, margin=0.182, greedy_score=-.712, sample_score=-276]
# Epoch [36/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.361, positive_reward=0.242, negative_reward=0.00272, margin=0.24, greedy_score=-.457, sample_score=-282]
# Epoch [37/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.431, positive_reward=0.228, negative_reward=0.069, margin=0.159, greedy_score=-.159, sample_score=-323]
# Epoch [38/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.459, positive_reward=0.192, negative_reward=0.0585, margin=0.134, greedy_score=-.00484, sample_score=-259]
# Epoch [39/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.428, positive_reward=0.229, negative_reward=0.0685, margin=0.161, greedy_score=-.43, sample_score=-289]
# Epoch [40/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.368, positive_reward=0.228, negative_reward=-.000574, margin=0.229, greedy_score=-.113, sample_score=-283]
# Epoch [41/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.4, positive_reward=0.232, negative_reward=0.00465, margin=0.228, greedy_score=-.341, sample_score=-289]
# Epoch [42/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.413, positive_reward=0.213, negative_reward=0.0197, margin=0.193, greedy_score=-.327, sample_score=-300]
# Epoch [43/100]: 100%|██████████| 32/32 [00:24<00:00,  1.32it/s, loss=0.389, positive_reward=0.232, negative_reward=0.00845, margin=0.224, greedy_score=-.437, sample_score=-262]
# Epoch [44/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.347, positive_reward=0.206, negative_reward=-.0339, margin=0.24, greedy_score=0.138, sample_score=-267]
# Epoch [45/100]: 100%|██████████| 32/32 [00:23<00:00,  1.35it/s, loss=0.45, positive_reward=0.24, negative_reward=0.0578, margin=0.182, greedy_score=-.425, sample_score=-289]
# Epoch [46/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.422, positive_reward=0.232, negative_reward=0.0668, margin=0.165, greedy_score=-.139, sample_score=-291]
# Epoch [47/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=0.38, positive_reward=0.231, negative_reward=0.0134, margin=0.217, greedy_score=-.288, sample_score=-294]
# Epoch [48/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.446, positive_reward=0.206, negative_reward=0.0312, margin=0.175, greedy_score=-.391, sample_score=-265]
# Epoch [49/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.381, positive_reward=0.232, negative_reward=0.0205, margin=0.212, greedy_score=-.34, sample_score=-294]
# Epoch [50/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.424, positive_reward=0.245, negative_reward=0.036, margin=0.209, greedy_score=-.0834, sample_score=-289]
# Epoch [51/100]: 100%|██████████| 32/32 [00:27<00:00,  1.18it/s, loss=0.395, positive_reward=0.2, negative_reward=0.000839, margin=0.199, greedy_score=-.398, sample_score=-290]
# Epoch [52/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=0.415, positive_reward=0.228, negative_reward=-.00908, margin=0.237, greedy_score=-.31, sample_score=-266]
# Epoch [53/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.381, positive_reward=0.229, negative_reward=0.0112, margin=0.218, greedy_score=-.435, sample_score=-298]
# Epoch [54/100]: 100%|██████████| 32/32 [00:22<00:00,  1.42it/s, loss=0.38, positive_reward=0.221, negative_reward=-.00138, margin=0.223, greedy_score=-.342, sample_score=-270]
# Epoch [55/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.367, positive_reward=0.239, negative_reward=0.0185, margin=0.221, greedy_score=-.566, sample_score=-287]
# Epoch [56/100]: 100%|██████████| 32/32 [00:24<00:00,  1.29it/s, loss=0.38, positive_reward=0.233, negative_reward=0.0176, margin=0.215, greedy_score=-.62, sample_score=-281]
# Epoch [57/100]: 100%|██████████| 32/32 [00:26<00:00,  1.19it/s, loss=0.383, positive_reward=0.221, negative_reward=0.0191, margin=0.202, greedy_score=-.694, sample_score=-299]
# Epoch [58/100]: 100%|██████████| 32/32 [00:24<00:00,  1.30it/s, loss=0.352, positive_reward=0.229, negative_reward=-.00186, margin=0.231, greedy_score=-.152, sample_score=-276]
# Epoch [59/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.389, positive_reward=0.238, negative_reward=0.0388, margin=0.2, greedy_score=-.495, sample_score=-284]
# Epoch [60/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.434, positive_reward=0.23, negative_reward=0.0755, margin=0.155, greedy_score=-.496, sample_score=-262]
# Epoch [61/100]: 100%|██████████| 32/32 [00:24<00:00,  1.32it/s, loss=0.464, positive_reward=0.22, negative_reward=-.0254, margin=0.245, greedy_score=-.355, sample_score=-288]
# Epoch [62/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.417, positive_reward=0.21, negative_reward=0.0516, margin=0.158, greedy_score=-.601, sample_score=-261]
# Epoch [63/100]: 100%|██████████| 32/32 [00:22<00:00,  1.41it/s, loss=0.442, positive_reward=0.245, negative_reward=0.0495, margin=0.195, greedy_score=-.439, sample_score=-282]
# Epoch [64/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.402, positive_reward=0.221, negative_reward=0.0383, margin=0.182, greedy_score=-.866, sample_score=-291]
# Epoch [65/100]: 100%|██████████| 32/32 [00:24<00:00,  1.33it/s, loss=0.409, positive_reward=0.245, negative_reward=0.0606, margin=0.184, greedy_score=-.472, sample_score=-321]
# Epoch [66/100]: 100%|██████████| 32/32 [00:24<00:00,  1.29it/s, loss=0.383, positive_reward=0.263, negative_reward=0.00303, margin=0.26, greedy_score=-.446, sample_score=-271]
# Epoch [67/100]: 100%|██████████| 32/32 [00:24<00:00,  1.28it/s, loss=0.387, positive_reward=0.221, negative_reward=0.0162, margin=0.205, greedy_score=-.66, sample_score=-284]
# Epoch [68/100]: 100%|██████████| 32/32 [00:24<00:00,  1.30it/s, loss=0.348, positive_reward=0.22, negative_reward=-.0215, margin=0.241, greedy_score=-.278, sample_score=-283]
# Epoch [69/100]: 100%|██████████| 32/32 [00:26<00:00,  1.21it/s, loss=0.375, positive_reward=0.219, negative_reward=-.0396, margin=0.259, greedy_score=-.125, sample_score=-303]
# Epoch [70/100]: 100%|██████████| 32/32 [00:26<00:00,  1.19it/s, loss=0.376, positive_reward=0.241, negative_reward=0.0186, margin=0.222, greedy_score=-.282, sample_score=-285]
# Epoch [71/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.38, positive_reward=0.265, negative_reward=-.0281, margin=0.293, greedy_score=-.773, sample_score=-231]
# Epoch [72/100]: 100%|██████████| 32/32 [00:23<00:00,  1.36it/s, loss=0.394, positive_reward=0.213, negative_reward=0.0358, margin=0.177, greedy_score=-.388, sample_score=-305]
# Epoch [73/100]: 100%|██████████| 32/32 [00:27<00:00,  1.18it/s, loss=0.394, positive_reward=0.242, negative_reward=0.0159, margin=0.226, greedy_score=-.453, sample_score=-281]
# Epoch [74/100]: 100%|██████████| 32/32 [00:24<00:00,  1.33it/s, loss=0.426, positive_reward=0.216, negative_reward=0.0653, margin=0.151, greedy_score=-.11, sample_score=-307]
# Epoch [75/100]: 100%|██████████| 32/32 [00:26<00:00,  1.21it/s, loss=0.406, positive_reward=0.21, negative_reward=0.0227, margin=0.187, greedy_score=-.626, sample_score=-276]
# Epoch [76/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.419, positive_reward=0.249, negative_reward=0.0162, margin=0.233, greedy_score=-.432, sample_score=-249]
# Epoch [77/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.438, positive_reward=0.235, negative_reward=0.0741, margin=0.161, greedy_score=-.369, sample_score=-282]
# Epoch [78/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.369, positive_reward=0.233, negative_reward=-.0167, margin=0.25, greedy_score=-.363, sample_score=-253]
# Epoch [79/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.368, positive_reward=0.219, negative_reward=-.0238, margin=0.243, greedy_score=-.169, sample_score=-290]
# Epoch [80/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.393, positive_reward=0.241, negative_reward=0.0251, margin=0.216, greedy_score=-.241, sample_score=-337]
# Epoch [81/100]: 100%|██████████| 32/32 [00:24<00:00,  1.29it/s, loss=0.455, positive_reward=0.215, negative_reward=0.0505, margin=0.164, greedy_score=-.792, sample_score=-354]
# Epoch [82/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.359, positive_reward=0.212, negative_reward=-.00136, margin=0.213, greedy_score=-.0304, sample_score=-281]
# Epoch [83/100]: 100%|██████████| 32/32 [00:24<00:00,  1.30it/s, loss=0.409, positive_reward=0.224, negative_reward=-.0135, margin=0.237, greedy_score=-.544, sample_score=-319]
# Epoch [84/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.348, positive_reward=0.246, negative_reward=-.00208, margin=0.248, greedy_score=-.505, sample_score=-310]
# Epoch [85/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.418, positive_reward=0.213, negative_reward=0.0416, margin=0.171, greedy_score=-.636, sample_score=-247]
# Epoch [86/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.429, positive_reward=0.265, negative_reward=-.0227, margin=0.288, greedy_score=-.651, sample_score=-283]
# Epoch [87/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.356, positive_reward=0.23, negative_reward=-.00502, margin=0.235, greedy_score=-.481, sample_score=-269]
# Epoch [88/100]: 100%|██████████| 32/32 [00:24<00:00,  1.28it/s, loss=0.392, positive_reward=0.244, negative_reward=0.0318, margin=0.212, greedy_score=-.132, sample_score=-276]
# Epoch [89/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.38, positive_reward=0.228, negative_reward=-.00269, margin=0.231, greedy_score=0.013, sample_score=-305]
# Epoch [90/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.357, positive_reward=0.23, negative_reward=-.00598, margin=0.236, greedy_score=-.126, sample_score=-277]
# Epoch [91/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.376, positive_reward=0.221, negative_reward=0.0208, margin=0.2, greedy_score=-.862, sample_score=-319]
# Epoch [92/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=0.347, positive_reward=0.25, negative_reward=-.0171, margin=0.267, greedy_score=0.0438, sample_score=-314]
# Epoch [93/100]: 100%|██████████| 32/32 [00:23<00:00,  1.37it/s, loss=0.37, positive_reward=0.232, negative_reward=0.0081, margin=0.224, greedy_score=0.0258, sample_score=-313]
# Epoch [94/100]: 100%|██████████| 32/32 [00:18<00:00,  1.74it/s, loss=0.354, positive_reward=0.254, negative_reward=-.0147, margin=0.269, greedy_score=-.39, sample_score=-298]
# Epoch [95/100]: 100%|██████████| 32/32 [00:16<00:00,  1.99it/s, loss=0.392, positive_reward=0.231, negative_reward=0.0311, margin=0.2, greedy_score=0.0846, sample_score=-309]
# Epoch [96/100]: 100%|██████████| 32/32 [00:17<00:00,  1.85it/s, loss=0.395, positive_reward=0.247, negative_reward=0.0438, margin=0.203, greedy_score=-.471, sample_score=-314]
# Epoch [97/100]: 100%|██████████| 32/32 [00:15<00:00,  2.03it/s, loss=0.411, positive_reward=0.241, negative_reward=0.0539, margin=0.187, greedy_score=0.337, sample_score=-317]
# Epoch [98/100]: 100%|██████████| 32/32 [00:15<00:00,  2.11it/s, loss=0.406, positive_reward=0.229, negative_reward=0.0463, margin=0.183, greedy_score=-.368, sample_score=-306]
# Epoch [99/100]: 100%|██████████| 32/32 [00:13<00:00,  2.33it/s, loss=0.404, positive_reward=0.247, negative_reward=0.0389, margin=0.209, greedy_score=-.198, sample_score=-286]
# Epoch [100/100]: 100%|██████████| 32/32 [00:12<00:00,  2.55it/s, loss=0.357, positive_reward=0.24, negative_reward=0.00359, margin=0.236, greedy_score=-.648, sample_score=-273]

# %%
# save all png to /mnt/nfs/work/albertliu/RL/CartPole-v1/DPO

# draw the loss graph
import matplotlib.pyplot as plt
plt.plot(loss_graph)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss vs Iteration")
plt.savefig("./loss.png")

plt.show()



# draw the reward graph
plt.plot(greedy_rewards)
plt.xlabel("Iteration")
plt.ylabel("Greedy Reward")
plt.title("Greedy Reward vs Iteration")
plt.savefig("./greedy_reward.png")
plt.show()

# draw the reward graph
plt.plot(sample_rewards)
plt.xlabel("Iteration")
plt.ylabel("Sample Reward")
plt.title("Sample Reward vs Iteration")
plt.savefig("./sample_reward.png")
plt.show()


# drqw the margin graph
plt.plot(margin_graph)
plt.xlabel("Iteration")
plt.ylabel("Margin")
plt.title("Margin vs Iteration")
plt.savefig("./margin.png")
plt.show()

# draw the positive reward graph
plt.plot(positive_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Positive Reward")
plt.title("Positive Reward vs Iteration")
plt.savefig("./positive_reward.png")
plt.show()

# draw the negative reward graph
plt.plot(negative_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Negative Reward")
plt.title("Negative Reward vs Iteration")

plt.savefig("./negative_reward.png")
plt.show()

# %%
# from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
# from stable_baselines3.common.vec_env import VecEnv
# import gymnasium as gym
# from imitation.policies.serialize import load_policy
# from imitation.util.util import make_vec_env
# import numpy as np
# import torch
# import os

# # 创建环境
# env = make_vec_env(
#     "seals:seals/Walker2d-v1",
#     rng=np.random.default_rng(),
#     n_envs=1,
#     env_make_kwargs={"render_mode": "rgb_array"},
# )

# # 使用 VecVideoRecorder 包装环境以启用视频记录，指定视频保存的路径
# video_folder = './videos'
# video_length = 200  # 设置视频长度
# env = VecVideoRecorder(env, video_folder,
#                        record_video_trigger=lambda step: step == 0, video_length=video_length,
#                        name_prefix="Walker2d-video")

# # 创建模型，这里以从 Hugging Face 加载预训练的 PPO 模型为例
# model = load_policy(
#     "ppo-huggingface",
#     organization="HumanCompatibleAI",
#     env_name="seals/Walker2d-v1",
#     venv=env,
# )

# # 训练模型
# # 注意: 此处假定模型已经预训练，无需再次训练

# # 测试模型，生成视频
# obs = env.reset()
# done = False
# while not done:
#     action, _states = model.predict(obs, deterministic=True)
#     obs, rewards, dones, info = env.step(action)
#     done = dones.any()

# env.close()

# # 如果需要手动保存视频（有时候视频不会在关闭时自动保存）
# env.record_video_trigger(video_length)
