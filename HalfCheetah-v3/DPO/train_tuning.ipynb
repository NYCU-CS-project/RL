# %%
import gymnasium as gym
import numpy as np
from stable_baselines3.common.env_util import make_vec_env as make_vec_env_sb3
from copy import deepcopy
import torch
from torch.distributions import Normal,MultivariateNormal
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.utils.data import Dataset, DataLoader
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
import imageio
import pandas as pd
from tqdm import tqdm
from PIL import Image
from stable_baselines3.dqn.policies import MlpPolicy
import matplotlib.pyplot as plt

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !nvidia-smi
# clean up memory forcefully
torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# Mon May 13 01:00:19 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  | 00000000:01:00.0 Off |                  N/A |
# | 17%   56C    P2              89W / 250W |   3688MiB / 11264MiB |     93%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    228304      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    229850      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    277377      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    280712      C   ...iu/miniconda3/envs/myenv/bin/python      212MiB |
# |    0   N/A  N/A    319688      C   ...iu/miniconda3/envs/myenv/bin/python      300MiB |
# |    0   N/A  N/A    328416      C   ...iu/miniconda3/envs/myenv/bin/python      204MiB |
# |    0   N/A  N/A    377684      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   1475780      C   ...iu/miniconda3/envs/myenv/bin/python      194MiB |
# |    0   N/A  N/A   2544023      C   ...u/miniconda3/envs/myenv2/bin/python      184MiB |
# |    0   N/A  N/A   2546464      C   ...u/miniconda3/envs/myenv2/bin/python      192MiB |
# |    0   N/A  N/A   2573704      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2584185      C   ...181/miniconda3/envs/copy/bin/python      194MiB |
# |    0   N/A  N/A   2587643      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2588031      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2591397    C+G   ...181/miniconda3/envs/copy/bin/python      217MiB |
# |    0   N/A  N/A   2594108      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2594730      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# |    0   N/A  N/A   2605031      C   ...181/miniconda3/envs/copy/bin/python      192MiB |
# +---------------------------------------------------------------------------------------+
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
class CustomDataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32,device=device)
        self.actions = torch.tensor(actions, dtype=torch.float32,device=device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, output_dim,init_w=3e-3,log_std_min=-20,log_std_max=2):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 32)


        self.fc2 = nn.Linear(32, 32)
        self.log_std = nn.Linear(32, output_dim)
        self.mu=nn.Linear(32,output_dim)
        self.log_std_min=log_std_min
        self.log_std_max=log_std_max
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        torch.nn.init.kaiming_normal_(self.fc2.weight)
        self.mu.weight.data.uniform_(-init_w,init_w)
        self.mu.bias.data.uniform_(-init_w,init_w)
        self.log_std.weight.data.uniform_(-init_w,init_w)
        self.log_std.bias.data.uniform_(-init_w,init_w)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = self.mu(x) # Only apply if action bounds are [-1, 1]
        log_std = self.log_std(x)  # Ensure std is positive
        log_std=torch.clamp(log_std,self.log_std_min,self.log_std_max)

        return mu, log_std
# Out:
# Using device: cuda

# %%
# from imitation.util.util import make_vec_env

# observations= np.load("../dataset/obs.npy", allow_pickle=True)
# actions = np.load("../dataset/actions.npy", allow_pickle=True)

# observations=observations.squeeze()
# actions=actions.squeeze()

# print(observations.shape, actions.shape)
# print(observations[0], actions[0])
import pickle
import numpy as np
#　read /mnt/nfs/work/c98181/TDIL/saved_expert_transition/Walker2d-v3/sac/episode_num1_6123.pkl
# "states", "actions", "rewards", "next_states", "dones".
with open("/mnt/nfs/work/c98181/TDIL/saved_expert_transition/HalfCheetah-v3/sac/episode_num1_15251.pkl", "rb") as f:
    data = pickle.load(f)

    obs_list = data["states"]
    actions_list = data["actions"]
    observations=np.array(obs_list)
    actions=np.array(actions_list)
    # shape
    print(observations.shape)
    print(actions.shape)

# env=gym.make("Walker2d-v3",exclude_current_positions_from_observation=False,render_mode="rgb_array")
env=gym.make("HalfCheetah-v3",render_mode="rgb_array")
# Out:
# (1000, 17)
# (1000, 6)
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment HalfCheetah-v3 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /mnt/nfs/work/c98181/miniconda3/envs/copy/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_env.py:211: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(

# %%
class mydataset(Dataset):
    def __init__(self, observations, actions):
        self.observations = torch.tensor(observations, dtype=torch.float32).to(device)
        self.actions = torch.tensor(actions, dtype=torch.float32).to(device)

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        observation = self.observations[idx]
        action = self.actions[idx]
        return observation, action

# %%
policy_network = PolicyNetwork(17,6).to(device)
prev = PolicyNetwork(17,6).to(device)
prev.load_state_dict(policy_network.state_dict())
prev.eval()

optimizer = torch.optim.Adam(policy_network.parameters(), lr=0.0003,weight_decay=1e-4)

# Training loop
num_epochs = 100
batch_size = 32

dataset = mydataset(observations=observations, actions=actions)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

loss_graph=[]
greedy_rewards=[]
sample_rewards=[]
margin_graph=[]
positive_reward_graph=[]
negative_reward_graph=[]
log_interval = len(observations)//1
num_test = 10
prev_load_freq = 32
now_log=0
now_pos=0
greedy_score=0
sample_score=0
for epoch in range(num_epochs):
    policy_network.train()

    # Compute the log probabilities of the actions
    pbar=tqdm(dataloader,position=0,leave=True)
    now_log=0

    for step, (obs_batch,act_batch) in enumerate(pbar):
        # obs_batch = torch.tensor(np.array(obs_batch), dtype=torch.float32).to(device)
        # act_batch = torch.tensor(np.array(act_batch), dtype=torch.float32).to(device)

        now_log+=obs_batch.shape[0]
        now_pos+=obs_batch.shape[0]
        
        mu, log_std = policy_network(obs_batch)
        std=log_std.exp()
        dist = Normal(mu, std)
        z_model=dist.rsample()
        model_action=torch.tanh(z_model)
        z_expert=torch.atanh(torch.clamp(act_batch, -0.999999, 0.999999))
        epsilon=1e-6


        policy_rejected_logps =dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
        policy_chosen_logps = dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        with torch.no_grad():
          prev_mu, prev_log_std = prev(obs_batch)
          prev_std=prev_log_std.exp()
          prev_dist = Normal(prev_mu, prev_std)

          reference_rejected_logps =prev_dist.log_prob(z_model)-torch.log(1-model_action.pow(2)+epsilon)
          reference_chosen_logps = prev_dist.log_prob(z_expert)-torch.log(1-act_batch.pow(2)+epsilon)

        pi_logratios = policy_chosen_logps - policy_rejected_logps
        ref_logratios = reference_chosen_logps - reference_rejected_logps
        logits = pi_logratios - ref_logratios
        chosen_KL = (policy_chosen_logps - reference_chosen_logps).mean().clamp(min=0)
        reject_KL = (policy_rejected_logps - reference_rejected_logps).mean().clamp(min=0)

       

        chosen_logratios = policy_chosen_logps - reference_chosen_logps
        reject_logratios = policy_rejected_logps - reference_rejected_logps

        # logits = chosen_logratios - reject_logratios

        if epoch < -1:
          loss = - (policy_chosen_logps).mean()
        else:
          beta = 0.1
          losses=-F.logsigmoid(beta * logits)
          loss = losses.mean()
        #   losses = torch.cat((1 - F.logsigmoid(beta * (chosen_logratios - reject_KL)), 1 - F.logsigmoid(beta * (chosen_KL - reject_logratios))), 0)
        #   loss = losses.mean()
        # Optimize the policy
        optimizer.zero_grad()


        loss.backward()

        optimizer.step()
        pbar.set_description((f"Epoch [{epoch+1}/{num_epochs}]"))
        positive_reward = chosen_logratios.detach().mean().item()
        negative_reward = reject_logratios.detach().mean().item()
        margin = positive_reward - negative_reward
        loss_graph.append(loss.detach().item())
        margin_graph.append(margin)
        positive_reward_graph.append(positive_reward)
        negative_reward_graph.append(negative_reward)



        total_reward=0
        if now_log>=log_interval:
            now_log-=log_interval
            
            policy_network.eval()  # 切换到评估模式

            

            total_reward=0
            # test the policy and save as the first test as gif
            frames = []
            for _ in range(num_test):
                state,_ = env.reset()
                done = False

                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(mu)   
                        action.squeeze_()

                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/greedy/"+image_path, frames)

            greedy_score=total_reward/num_test
            total_reward=0
            frames = []
            # test the policy and save as the first test as gif
            for _ in range(num_test):
                state,_ = env.reset()
                done = False
                while not done:
                    state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
                    with torch.no_grad():
                        mu, log_std = policy_network(state_tensor)
                        std=log_std.exp()
                        action= torch.tanh(Normal(mu,std).sample())
                        action.squeeze_()
                       
                    state, reward,_, done, _ = env.step(action.cpu().numpy())  # 执行动作
                    total_reward += reward
                    # frames.append(env.render())
            image_path=f"{epoch}.gif"
            # imageio.mimsave("./gif/sample/"+image_path, frames)

            sample_score=total_reward/num_test
            greedy_rewards.append(greedy_score)
            sample_rewards.append(sample_score)
            policy_network.train()  # 切换回训练模式
        pbar.set_postfix({"loss":loss.detach().item(), "positive_reward": positive_reward, "negative_reward": negative_reward, "margin": positive_reward - negative_reward,"greedy_score":greedy_score,"sample_score":sample_score})
    prev.load_state_dict(policy_network.state_dict())
    prev.eval()
         

env.close()
# Out:
# Epoch [1/100]:  78%|███████▊  | 25/32 [00:00<00:00, 61.62it/s, loss=0.672, positive_reward=0.672, negative_reward=0.238, margin=0.434, greedy_score=0, sample_score=0]    /tmp/ipykernel_2605258/1817845473.py:117: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025847094/work/torch/csrc/utils/tensor_new.cpp:275.)
#   state_tensor = torch.tensor([state], dtype=torch.float32).to(device)
# Epoch [1/100]: 100%|██████████| 32/32 [00:20<00:00,  1.54it/s, loss=0.673, positive_reward=0.62, negative_reward=0.206, margin=0.414, greedy_score=-.00678, sample_score=-226]
# Epoch [2/100]: 100%|██████████| 32/32 [00:19<00:00,  1.67it/s, loss=0.684, positive_reward=0.216, negative_reward=0.0189, margin=0.197, greedy_score=-.389, sample_score=-168]
# Epoch [3/100]: 100%|██████████| 32/32 [00:21<00:00,  1.46it/s, loss=0.688, positive_reward=0.0602, negative_reward=-.0467, margin=0.107, greedy_score=-.605, sample_score=-208]
# Epoch [4/100]: 100%|██████████| 32/32 [00:20<00:00,  1.53it/s, loss=0.692, positive_reward=0.0428, negative_reward=0.0269, margin=0.0159, greedy_score=-.507, sample_score=-188]
# Epoch [5/100]: 100%|██████████| 32/32 [00:19<00:00,  1.64it/s, loss=0.692, positive_reward=-.002, negative_reward=-.0156, margin=0.0136, greedy_score=-.695, sample_score=-159]
# Epoch [6/100]: 100%|██████████| 32/32 [00:18<00:00,  1.76it/s, loss=0.693, positive_reward=0.0244, negative_reward=0.013, margin=0.0114, greedy_score=-.12, sample_score=-207]
# Epoch [7/100]: 100%|██████████| 32/32 [00:19<00:00,  1.66it/s, loss=0.695, positive_reward=0.00837, negative_reward=0.0365, margin=-.0281, greedy_score=-.537, sample_score=-238]
# Epoch [8/100]: 100%|██████████| 32/32 [00:21<00:00,  1.51it/s, loss=0.691, positive_reward=0.0393, negative_reward=0.000912, margin=0.0384, greedy_score=-.5, sample_score=-207]
# Epoch [9/100]: 100%|██████████| 32/32 [00:21<00:00,  1.47it/s, loss=0.694, positive_reward=0.00737, negative_reward=0.0291, margin=-.0218, greedy_score=-.667, sample_score=-173]
# Epoch [10/100]: 100%|██████████| 32/32 [00:20<00:00,  1.53it/s, loss=0.695, positive_reward=0.00385, negative_reward=0.0429, margin=-.039, greedy_score=-.369, sample_score=-221]
# Epoch [11/100]: 100%|██████████| 32/32 [00:20<00:00,  1.56it/s, loss=0.693, positive_reward=0.00466, negative_reward=0.000497, margin=0.00416, greedy_score=-.392, sample_score=-222]
# Epoch [12/100]: 100%|██████████| 32/32 [00:20<00:00,  1.53it/s, loss=0.693, positive_reward=0.0027, negative_reward=-.000221, margin=0.00292, greedy_score=-.365, sample_score=-227]
# Epoch [13/100]: 100%|██████████| 32/32 [00:19<00:00,  1.67it/s, loss=0.692, positive_reward=0.00378, negative_reward=-.0146, margin=0.0183, greedy_score=-.136, sample_score=-225]
# Epoch [14/100]: 100%|██████████| 32/32 [00:21<00:00,  1.50it/s, loss=0.693, positive_reward=0.00263, negative_reward=0.00457, margin=-.00194, greedy_score=-.451, sample_score=-229]
# Epoch [15/100]: 100%|██████████| 32/32 [00:21<00:00,  1.51it/s, loss=0.694, positive_reward=-.00142, negative_reward=0.0094, margin=-.0108, greedy_score=-.728, sample_score=-246]
# Epoch [16/100]: 100%|██████████| 32/32 [00:21<00:00,  1.50it/s, loss=0.693, positive_reward=0.00807, negative_reward=0.0131, margin=-.00508, greedy_score=-.124, sample_score=-219]
# Epoch [17/100]: 100%|██████████| 32/32 [00:22<00:00,  1.41it/s, loss=0.694, positive_reward=-.00564, negative_reward=0.00486, margin=-.0105, greedy_score=-.314, sample_score=-261]
# Epoch [18/100]: 100%|██████████| 32/32 [00:25<00:00,  1.23it/s, loss=0.692, positive_reward=0.0235, negative_reward=0.00297, margin=0.0205, greedy_score=-.436, sample_score=-219]
# Epoch [19/100]: 100%|██████████| 32/32 [00:27<00:00,  1.15it/s, loss=0.691, positive_reward=0.0369, negative_reward=-.000385, margin=0.0372, greedy_score=-.584, sample_score=-230]
# Epoch [20/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.693, positive_reward=0.0133, negative_reward=0.0196, margin=-.00632, greedy_score=-.0441, sample_score=-205]
# Epoch [21/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.7, positive_reward=-.0652, negative_reward=0.0615, margin=-.127, greedy_score=-.326, sample_score=-260]
# Epoch [22/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.693, positive_reward=0.045, negative_reward=0.0319, margin=0.013, greedy_score=-.348, sample_score=-208]
# Epoch [23/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=0.693, positive_reward=0.0102, negative_reward=0.0119, margin=-.00161, greedy_score=-.302, sample_score=-240]
# Epoch [24/100]: 100%|██████████| 32/32 [00:27<00:00,  1.18it/s, loss=0.693, positive_reward=0.0325, negative_reward=0.0378, margin=-.00523, greedy_score=-.445, sample_score=-233]
# Epoch [25/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.695, positive_reward=0.00152, negative_reward=0.0279, margin=-.0264, greedy_score=-.64, sample_score=-248]
# Epoch [26/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.693, positive_reward=0.00752, negative_reward=0.00583, margin=0.0017, greedy_score=-.403, sample_score=-247]
# Epoch [27/100]: 100%|██████████| 32/32 [00:27<00:00,  1.18it/s, loss=0.694, positive_reward=-.0282, negative_reward=-.00587, margin=-.0223, greedy_score=-.261, sample_score=-226]
# Epoch [28/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.692, positive_reward=0.0146, negative_reward=-.0105, margin=0.0251, greedy_score=-.219, sample_score=-206]
# Epoch [29/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.693, positive_reward=-.0129, negative_reward=-.0127, margin=-.000192, greedy_score=-.622, sample_score=-209]
# Epoch [30/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.693, positive_reward=0.00963, negative_reward=0.00378, margin=0.00585, greedy_score=-.653, sample_score=-265]
# Epoch [31/100]: 100%|██████████| 32/32 [00:26<00:00,  1.19it/s, loss=0.696, positive_reward=-.00925, negative_reward=0.0448, margin=-.054, greedy_score=-.726, sample_score=-220]
# Epoch [32/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.692, positive_reward=0.00657, negative_reward=-.0103, margin=0.0168, greedy_score=-.426, sample_score=-235]
# Epoch [33/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.693, positive_reward=-.019, negative_reward=-.017, margin=-.00202, greedy_score=-.83, sample_score=-218]
# Epoch [34/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.692, positive_reward=0.0236, negative_reward=0.00483, margin=0.0188, greedy_score=0.141, sample_score=-207]
# Epoch [35/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.693, positive_reward=0.00228, negative_reward=0.00385, margin=-.00157, greedy_score=-.0784, sample_score=-228]
# Epoch [36/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.692, positive_reward=0.00194, negative_reward=-.0188, margin=0.0208, greedy_score=-.209, sample_score=-212]
# Epoch [37/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.692, positive_reward=0.0188, negative_reward=0.0046, margin=0.0142, greedy_score=-.275, sample_score=-253]
# Epoch [38/100]: 100%|██████████| 32/32 [00:27<00:00,  1.18it/s, loss=0.694, positive_reward=-.0322, negative_reward=-.00708, margin=-.0251, greedy_score=-.34, sample_score=-234]
# Epoch [39/100]: 100%|██████████| 32/32 [00:24<00:00,  1.33it/s, loss=0.693, positive_reward=0.00505, negative_reward=-.00307, margin=0.00812, greedy_score=-.636, sample_score=-215]
# Epoch [40/100]: 100%|██████████| 32/32 [00:26<00:00,  1.19it/s, loss=0.694, positive_reward=0.00184, negative_reward=0.00918, margin=-.00734, greedy_score=-.425, sample_score=-255]
# Epoch [41/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=0.693, positive_reward=0.0193, negative_reward=0.014, margin=0.00526, greedy_score=-.138, sample_score=-259]
# Epoch [42/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.695, positive_reward=-.0487, negative_reward=-.00662, margin=-.0421, greedy_score=-.567, sample_score=-226]
# Epoch [43/100]: 100%|██████████| 32/32 [00:27<00:00,  1.17it/s, loss=0.694, positive_reward=0.00634, negative_reward=0.0208, margin=-.0144, greedy_score=-.613, sample_score=-229]
# Epoch [44/100]: 100%|██████████| 32/32 [00:23<00:00,  1.35it/s, loss=0.693, positive_reward=0.00163, negative_reward=-.005, margin=0.00663, greedy_score=-.685, sample_score=-251]
# Epoch [45/100]: 100%|██████████| 32/32 [00:26<00:00,  1.19it/s, loss=0.692, positive_reward=0.0142, negative_reward=-.00322, margin=0.0174, greedy_score=-.752, sample_score=-236]
# Epoch [46/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.693, positive_reward=0.0119, negative_reward=0.00443, margin=0.0075, greedy_score=-.0907, sample_score=-248]
# Epoch [47/100]: 100%|██████████| 32/32 [00:26<00:00,  1.21it/s, loss=0.694, positive_reward=-.0123, negative_reward=-.00222, margin=-.0101, greedy_score=-.613, sample_score=-197]
# Epoch [48/100]: 100%|██████████| 32/32 [00:24<00:00,  1.30it/s, loss=0.696, positive_reward=0.00586, negative_reward=0.0627, margin=-.0568, greedy_score=-.455, sample_score=-204]
# Epoch [49/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.692, positive_reward=0.00849, negative_reward=-.0169, margin=0.0253, greedy_score=-.663, sample_score=-255]
# Epoch [50/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.693, positive_reward=0.00716, negative_reward=-.00324, margin=0.0104, greedy_score=-.636, sample_score=-206]
# Epoch [51/100]: 100%|██████████| 32/32 [00:26<00:00,  1.21it/s, loss=0.692, positive_reward=0.0107, negative_reward=-.00813, margin=0.0188, greedy_score=-.655, sample_score=-246]
# Epoch [52/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.695, positive_reward=-.0141, negative_reward=0.0155, margin=-.0296, greedy_score=-.147, sample_score=-196]
# Epoch [53/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=0.696, positive_reward=-.0186, negative_reward=0.0395, margin=-.0581, greedy_score=-.854, sample_score=-266]
# Epoch [54/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.693, positive_reward=0.0364, negative_reward=0.0288, margin=0.0076, greedy_score=-.305, sample_score=-208]
# Epoch [55/100]: 100%|██████████| 32/32 [00:24<00:00,  1.30it/s, loss=0.694, positive_reward=-.0101, negative_reward=0.00221, margin=-.0123, greedy_score=-.522, sample_score=-217]
# Epoch [56/100]: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s, loss=0.692, positive_reward=0.0118, negative_reward=-.00217, margin=0.014, greedy_score=-.336, sample_score=-200]
# Epoch [57/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.691, positive_reward=0.0536, negative_reward=0.0081, margin=0.0455, greedy_score=-1.04, sample_score=-229]
# Epoch [58/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.695, positive_reward=-.0253, negative_reward=0.00516, margin=-.0305, greedy_score=0.134, sample_score=-240]
# Epoch [59/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.693, positive_reward=0.00754, negative_reward=0.0105, margin=-.00296, greedy_score=-.423, sample_score=-184]
# Epoch [60/100]: 100%|██████████| 32/32 [00:25<00:00,  1.27it/s, loss=0.693, positive_reward=0.0192, negative_reward=0.0103, margin=0.00894, greedy_score=-.479, sample_score=-209]
# Epoch [61/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.693, positive_reward=-.00226, negative_reward=-.00147, margin=-.000793, greedy_score=-.5, sample_score=-184]
# Epoch [62/100]: 100%|██████████| 32/32 [00:24<00:00,  1.31it/s, loss=0.694, positive_reward=-.00474, negative_reward=0.0062, margin=-.0109, greedy_score=-.393, sample_score=-256]
# Epoch [63/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.693, positive_reward=0.00701, negative_reward=-.000664, margin=0.00768, greedy_score=-.433, sample_score=-153]
# Epoch [64/100]: 100%|██████████| 32/32 [00:24<00:00,  1.30it/s, loss=0.693, positive_reward=0.0167, negative_reward=0.0209, margin=-.00421, greedy_score=-.247, sample_score=-253]
# Epoch [65/100]: 100%|██████████| 32/32 [00:26<00:00,  1.20it/s, loss=0.693, positive_reward=-.0065, negative_reward=-.000867, margin=-.00563, greedy_score=-.517, sample_score=-226]
# Epoch [66/100]: 100%|██████████| 32/32 [00:24<00:00,  1.30it/s, loss=0.694, positive_reward=-.015, negative_reward=-.00352, margin=-.0115, greedy_score=-.331, sample_score=-266]
# Epoch [67/100]: 100%|██████████| 32/32 [00:28<00:00,  1.13it/s, loss=0.694, positive_reward=-.00167, negative_reward=0.0107, margin=-.0124, greedy_score=-.289, sample_score=-217]
# Epoch [68/100]: 100%|██████████| 32/32 [00:24<00:00,  1.32it/s, loss=0.695, positive_reward=-.0132, negative_reward=0.0246, margin=-.0378, greedy_score=-1.04, sample_score=-197]
# Epoch [69/100]: 100%|██████████| 32/32 [00:27<00:00,  1.17it/s, loss=0.696, positive_reward=-.0147, negative_reward=0.0394, margin=-.0542, greedy_score=-.326, sample_score=-219]
# Epoch [70/100]: 100%|██████████| 32/32 [00:26<00:00,  1.19it/s, loss=0.694, positive_reward=0.0106, negative_reward=0.0292, margin=-.0186, greedy_score=0.0755, sample_score=-216]
# Epoch [71/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.696, positive_reward=-.0257, negative_reward=0.0334, margin=-.0591, greedy_score=-.45, sample_score=-223]
# Epoch [72/100]: 100%|██████████| 32/32 [00:24<00:00,  1.28it/s, loss=0.694, positive_reward=-.018, negative_reward=0.00678, margin=-.0248, greedy_score=-.41, sample_score=-306]
# Epoch [73/100]: 100%|██████████| 32/32 [00:27<00:00,  1.15it/s, loss=0.693, positive_reward=-.0158, negative_reward=-.0177, margin=0.00191, greedy_score=-.38, sample_score=-269]
# Epoch [74/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.691, positive_reward=0.0222, negative_reward=-.0279, margin=0.0501, greedy_score=-.639, sample_score=-232]
# Epoch [75/100]: 100%|██████████| 32/32 [00:23<00:00,  1.34it/s, loss=0.695, positive_reward=-.00749, negative_reward=0.0266, margin=-.0341, greedy_score=-.24, sample_score=-195]
# Epoch [76/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.691, positive_reward=0.00949, negative_reward=-.0423, margin=0.0518, greedy_score=-.542, sample_score=-261]
# Epoch [77/100]: 100%|██████████| 32/32 [00:24<00:00,  1.30it/s, loss=0.695, positive_reward=-.00806, negative_reward=0.02, margin=-.0281, greedy_score=-.56, sample_score=-221]
# Epoch [78/100]: 100%|██████████| 32/32 [00:27<00:00,  1.18it/s, loss=0.691, positive_reward=0.0437, negative_reward=0.00956, margin=0.0341, greedy_score=-.48, sample_score=-210]
# Epoch [79/100]: 100%|██████████| 32/32 [00:25<00:00,  1.24it/s, loss=0.695, positive_reward=-.0127, negative_reward=0.0263, margin=-.039, greedy_score=-.591, sample_score=-218]
# Epoch [80/100]: 100%|██████████| 32/32 [00:26<00:00,  1.23it/s, loss=0.694, positive_reward=0.00536, negative_reward=0.0298, margin=-.0245, greedy_score=-.359, sample_score=-269]
# Epoch [81/100]: 100%|██████████| 32/32 [00:24<00:00,  1.30it/s, loss=0.693, positive_reward=0.00474, negative_reward=0.00354, margin=0.00121, greedy_score=-.357, sample_score=-164]
# Epoch [82/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.692, positive_reward=0.014, negative_reward=-.00877, margin=0.0228, greedy_score=-.589, sample_score=-221]
# Epoch [83/100]: 100%|██████████| 32/32 [00:27<00:00,  1.18it/s, loss=0.694, positive_reward=-.0275, negative_reward=-.00275, margin=-.0248, greedy_score=-.086, sample_score=-235]
# Epoch [84/100]: 100%|██████████| 32/32 [00:26<00:00,  1.21it/s, loss=0.695, positive_reward=-.0111, negative_reward=0.021, margin=-.0321, greedy_score=-1, sample_score=-229]
# Epoch [85/100]: 100%|██████████| 32/32 [00:26<00:00,  1.21it/s, loss=0.695, positive_reward=0.0033, negative_reward=0.0342, margin=-.0309, greedy_score=-.63, sample_score=-268]
# Epoch [86/100]: 100%|██████████| 32/32 [00:24<00:00,  1.28it/s, loss=0.693, positive_reward=0.0148, negative_reward=0.0144, margin=0.000368, greedy_score=-.282, sample_score=-200]
# Epoch [87/100]: 100%|██████████| 32/32 [00:26<00:00,  1.22it/s, loss=0.693, positive_reward=-.00576, negative_reward=-.0135, margin=0.00772, greedy_score=-.259, sample_score=-206]
# Epoch [88/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.694, positive_reward=0.0038, negative_reward=0.0139, margin=-.0101, greedy_score=-.768, sample_score=-204]
# Epoch [89/100]: 100%|██████████| 32/32 [00:27<00:00,  1.17it/s, loss=0.692, positive_reward=0.00283, negative_reward=-.0122, margin=0.015, greedy_score=-1.01, sample_score=-204]
# Epoch [90/100]: 100%|██████████| 32/32 [00:25<00:00,  1.25it/s, loss=0.694, positive_reward=-.000602, negative_reward=0.0154, margin=-.016, greedy_score=-.524, sample_score=-234]
# Epoch [91/100]: 100%|██████████| 32/32 [00:22<00:00,  1.40it/s, loss=0.692, positive_reward=0.0139, negative_reward=-.0104, margin=0.0244, greedy_score=-.398, sample_score=-207]
# Epoch [92/100]: 100%|██████████| 32/32 [00:17<00:00,  1.81it/s, loss=0.695, positive_reward=-.00992, negative_reward=0.0184, margin=-.0283, greedy_score=-.777, sample_score=-144]
# Epoch [93/100]: 100%|██████████| 32/32 [00:14<00:00,  2.16it/s, loss=0.69, positive_reward=0.0344, negative_reward=-.0222, margin=0.0566, greedy_score=-.557, sample_score=-219]
# Epoch [94/100]: 100%|██████████| 32/32 [00:17<00:00,  1.80it/s, loss=0.695, positive_reward=-.0182, negative_reward=0.0172, margin=-.0354, greedy_score=-.204, sample_score=-216]
# Epoch [95/100]: 100%|██████████| 32/32 [00:15<00:00,  2.08it/s, loss=0.694, positive_reward=-.0066, negative_reward=0.00519, margin=-.0118, greedy_score=-.76, sample_score=-190]
# Epoch [96/100]: 100%|██████████| 32/32 [00:17<00:00,  1.81it/s, loss=0.693, positive_reward=0.00471, negative_reward=0.00396, margin=0.000747, greedy_score=-.378, sample_score=-217]
# Epoch [97/100]: 100%|██████████| 32/32 [00:16<00:00,  1.93it/s, loss=0.692, positive_reward=0.00158, negative_reward=-.0211, margin=0.0226, greedy_score=-.575, sample_score=-219]
# Epoch [98/100]: 100%|██████████| 32/32 [00:12<00:00,  2.66it/s, loss=0.692, positive_reward=0.0115, negative_reward=-.00704, margin=0.0186, greedy_score=-.252, sample_score=-219]
# Epoch [99/100]: 100%|██████████| 32/32 [00:10<00:00,  2.92it/s, loss=0.697, positive_reward=-.024, negative_reward=0.0596, margin=-.0836, greedy_score=-.544, sample_score=-261]
# Epoch [100/100]: 100%|██████████| 32/32 [00:10<00:00,  2.97it/s, loss=0.692, positive_reward=0.0241, negative_reward=0.000761, margin=0.0233, greedy_score=-.679, sample_score=-181]

# %%
# save all png to /mnt/nfs/work/albertliu/RL/CartPole-v1/DPO

# draw the loss graph
import matplotlib.pyplot as plt
plt.plot(loss_graph)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss vs Iteration")
# plt.savefig("./loss.png")

plt.show()



# draw the reward graph
plt.plot(greedy_rewards)
plt.xlabel("Iteration")
plt.ylabel("Greedy Reward")
plt.title("Greedy Reward vs Iteration")
# plt.savefig("./greedy_reward.png")
plt.show()

# draw the reward graph
plt.plot(sample_rewards)
plt.xlabel("Iteration")
plt.ylabel("Sample Reward")
plt.title("Sample Reward vs Iteration")
# plt.savefig("./sample_reward.png")
plt.show()


# drqw the margin graph
plt.plot(margin_graph)
plt.xlabel("Iteration")
plt.ylabel("Margin")
plt.title("Margin vs Iteration")
# plt.savefig("./margin.png")
plt.show()

# draw the positive reward graph
plt.plot(positive_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Positive Reward")
plt.title("Positive Reward vs Iteration")
# plt.savefig("./positive_reward.png")
plt.show()

# draw the negative reward graph
plt.plot(negative_reward_graph)
plt.xlabel("Iteration")
plt.ylabel("Negative Reward")
# plt.title("Negative Reward vs Iteration")

plt.savefig("./negative_reward.png")
plt.show()

# %%
# from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
# from stable_baselines3.common.vec_env import VecEnv
# import gymnasium as gym
# from imitation.policies.serialize import load_policy
# from imitation.util.util import make_vec_env
# import numpy as np
# import torch
# import os

# # 创建环境
# env = make_vec_env(
#     "seals:seals/Walker2d-v1",
#     rng=np.random.default_rng(),
#     n_envs=1,
#     env_make_kwargs={"render_mode": "rgb_array"},
# )

# # 使用 VecVideoRecorder 包装环境以启用视频记录，指定视频保存的路径
# video_folder = './videos'
# video_length = 200  # 设置视频长度
# env = VecVideoRecorder(env, video_folder,
#                        record_video_trigger=lambda step: step == 0, video_length=video_length,
#                        name_prefix="Walker2d-video")

# # 创建模型，这里以从 Hugging Face 加载预训练的 PPO 模型为例
# model = load_policy(
#     "ppo-huggingface",
#     organization="HumanCompatibleAI",
#     env_name="seals/Walker2d-v1",
#     venv=env,
# )

# # 训练模型
# # 注意: 此处假定模型已经预训练，无需再次训练

# # 测试模型，生成视频
# obs = env.reset()
# done = False
# while not done:
#     action, _states = model.predict(obs, deterministic=True)
#     obs, rewards, dones, info = env.step(action)
#     done = dones.any()

# env.close()

# # 如果需要手动保存视频（有时候视频不会在关闭时自动保存）
# env.record_video_trigger(video_length)
